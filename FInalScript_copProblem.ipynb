# %%
import time
import board
import busio
import pandas as pd
from pandas import DataFrame
from matplotlib import pylab
import matplotlib.pyplot as plt
from pylab import *
import pylab
import numpy as np
import matplotlib.colors as clrs
import matplotlib.cm as cm
import matplotlib
from collections import deque
import os.path
import datetime
import time
import math
import struct
from struct import *
from pyModbusTCP.client import ModbusClient

#matplotlib.use('TkAgg')
# %matplotlib notebook
#%matplotlib inline


#import time
import sys
import sqlite3
#from time import sleep

#import adafruit_ads1x15.ads1015 as ADS
import adafruit_ads1x15.ads1115 as ADS
from adafruit_ads1x15.analog_in import AnalogIn

import MySQLdb as db

HOST = "10.208.8.122"
PORT = 3306
USER = "yogi"
PASSWORD = "bittoo"
DB = "TemaccessToRemoteRp2"
'''
try:
    connection = db.Connection(host=HOST, port=PORT,
                               user=USER, passwd=PASSWORD, db=DB)

    c = connection.cursor()
    c.execute("SELECT * from temSensor")
    result = c.fetchall()
    for item in result:
        print (item)

except Exception as e:
    print (e)
'''
connectionL = db.connect(host="10.208.8.121",
                     user="yogi",
                     passwd="bittoo",
                     db="allSensors")

#c = conn.cursor()
connectionR = db.Connection(host=HOST, port=PORT,user=USER, passwd=PASSWORD, db=DB)

cR = connectionR.cursor()
cL =connectionL.cursor()

i2c = busio.I2C(board.SCL, board.SDA)

# Create the ADC object using the I2C bus
ads = ADS.ADS1115(i2c)

ads.gain = 1


cL.execute('DROP TABLE IF EXISTS flowReadings;')
print ('table flowReadings deleted')


cL.execute('CREATE TABLE flowReadings(id INT AUTO_INCREMENT PRIMARY KEY,  \
ts TIMESTAMP DEFAULT CURRENT_TIMESTAMP, \
flowHP FLOAT, flowLoad FLOAT, watt FLOAT) ENGINE=MyISAM;')

#cvsFileName = import os.path
#os.path.exists(file_path)

lol=[[], [], [], [], []]
flowRateLoad  = []
wattMeterKw = []
################################
##Cop functions, takes Tiem stamp of both Wattmegter and Tem values
###
###############################
def flatten_watt(l_of_l):
    '''this to flatten the watt tuple/list  whish is 
    present in lol[1]
    '''
    T = l_of_l[1]
    flattend_l = [val for sublist in T for val in sublist]
    #print ('flattened list is =', flattend_l)
    return flattend_l


timePeriod_watt = []
def timeStampCreator_watt(Lol):
    '''calculating timestamp of wattmeter'''
    mHP = Lol[2]
    T = flatten_watt(Lol)
    if len(mHP) == 1:
        timeStamp = 2/3600
        timePeriod_watt.append(timeStamp)
    elif len(mHP) > 1:
        timeLast = T[-1][1]
        timeSecondLast = T[-2][1]
        timeStamp = timeLast -timeSecondLast
        timeStamp = timeStamp.total_seconds()/3600
        timePeriod_watt.append(timeStamp)
    return 

def flatten_tem(l_of_l):
    '''flatting the time lol to calculate time stamp b/w each'''
    T = l_of_l[0]
    flattend_l = [val for sublist in T for val in sublist]
    #print ('flattened list is =', flattend_l)
    return flattend_l

timePeriod_tem = []
def timeStampCreator_cop(Lol):
    '''calculatng tem time stamp to calculate accuractly the mCT '''
    mHP = Lol[2]
    T = flatten_tem(Lol)
    if len(mHP) == 1:
        timeStamp = 2/3600
        timePeriod_tem.append(timeStamp)
    elif len(mHP) > 1:
        timeLast = T[-1][1]
        timeSecondLast = T[-2][1]
        timeStamp = timeLast -timeSecondLast
        timeStamp = timeStamp.total_seconds()/3600
        timePeriod_tem.append(timeStamp)
    return 


#@@@@@@@@@@@@@@@@@@
###@@@@@@@@@@@@@@@@
###COP@@@@@@@@@@@@@
#@@@@@@@@@@@@@@@@@@
#@@@@@@@@@@@@@@@@@@


copPlotterList = []
def Cop(Lol, time_stamp_tem, time_stamp_watt):
    '''this function takes both time stamp Tem and Watt
     because both Tem and watt are running at different timetamps
    '''
    mHP = Lol[2]
    T = flatten_tem(Lol)
    mL = Lol[3]
    watt_kW = Lol[4]
    p_LperH = [999.8473664794213 + 6.29265190e-02*x[2] - 8.42930922e-03*x[2]**2 + 6.77190849e-05*x[2]**3 \
 - 4.40840180e-07*x[2]**4 + 1.29302849e-09*x[2]**5 for x in T]
    mF_kgPerS =[ x*2.7777e-07*y for x, y in zip(p_LperH, mHP)]
    cP_kjPerkgK = [4.253264761904763 - 0.00470305*b[2] for b in T]
    mCT_kW = [c*a*(b[3]-b[4]) for c, a, b in zip(cP_kjPerkgK,mF_kgPerS, T)]
    mCT_kWh_l = [x*y for x,y in zip (time_stamp_tem, mCT_kW)]
    mCT_kWh = sum(mCT_kWh_l)
    #electricty consumed:
    watt_kW_l = [x*y for x,y in zip (time_stamp_watt,  watt_kW)]
    watt_kWh = sum(watt_kW_l)
    #cop 
    
    #print ('XXXXXXXXXXXXXXXXXXX watt_kW is:',  watt_kW)
    #print ('XXXXXXXXXXXXXXXXXXX mCT_kW is:',  mCT_kW)
    ccop_list = [x/y for x, y in zip(mCT_kW, watt_kW)]
    #print ('XXXXXXXXXXXXXXXXXX COP is:', ccop_list)
    cop_lastValue = ccop_list[-1]
    print ('XXXXXXXXXXXXXXXXXX COP with kW is:', cop_lastValue)
    #copPlotterList.append(cop_lastValue)
    
    cop =mCT_kWh/watt_kWh
    copPlotterList.append(cop)
    
    
    #print ('cop of system is:', cop)
    #print ('kwh heat addition is :', mCT_kWh)
    #print ('whole kW list is:', mCT_kW)
    print ('electricity in khW is:', watt_kWh)
    
    #print ('electricity consumption kW :', watt_kW)
    return cop
############################################################

def MCT_timeStamp(Lol, time_stamp_tem):
    mHP = Lol[2]
    T = flatten_tem(Lol)
    mL = Lol[3]
    watt_kW = Lol[4]
    p_LperH = [999.8473664794213 + 6.29265190e-02*x[2] - 8.42930922e-03*x[2]**2 + 6.77190849e-05*x[2]**3 \
 - 4.40840180e-07*x[2]**4 + 1.29302849e-09*x[2]**5 for x in T]
    mF_kgPerS =[ x*2.7777e-07*y for x, y in zip(p_LperH, mHP)]
    cP_kjPerkgK = [4.253264761904763 - 0.00470305*b[2] for b in T]
    mCT_kW = [c*a*(b[3]-b[4]) for c, a, b in zip(cP_kjPerkgK,mF_kgPerS, T)]
    mCT_kWh_l = [x*y for x,y in zip (time_stamp_tem, mCT_kW)]
    mCT_kWh = sum(mCT_kWh_l)
    print ('heat addition in kwh is:', mCT_kWh)
    return mCT_kW

l_id = []
def idGenerator(Id, l_id):
    if Id not in l_id:
       l_id.append(Id) 
    #print (l_id)
    return l_id

#df_conc= None
def dfs(Lol):
    mHP = Lol[2]
    T = flatten_tem(Lol)
    mL = Lol[3]
    StartTemTestingtank = [ 'id', 'dateTime', 'Tamb', 'TtopTestTankHPCir', 'TbottomTestTankHpCir', 'TtopSourceTank', \
'TloadTankMix','TTopTestTankLoadCir', 'TloadMix', 'TbottomSourceTank', 'TbottomTestTankLoadCir']
    l_T = ['T{}'.format(x) for x in range(0,10)]
    L = StartTemTestingtank +l_T
    df_mHP = DataFrame(mHP, columns=['flowHP'])
    df_mL = DataFrame(mL, columns=['flowLoad'])
    df_tem = DataFrame(T, columns = L)
    df_conc = pd.concat([df_tem, df_mHP, df_mL], axis=1)
    return df_conc

def list2df(lis, column_name = None):
    df  = pd.DataFrame(lis, columns = [column_name]) 
    return df


def toCsv(df_full, load_kW, heatCapacity_kW, electrictyUsed_kW, COP, nDis, timePeriod_tem, timePeriod_watt ,\
         entropy_kjPerK, entropy_kJ, nStratCharging, TankEnergyTotal_kJ,\
         DisEntropy_kjPerK, DisEntropy_kJ, nStratDis, DisTankEnergyTotal_kJ):
    df_Tem_Flow_Load_capacity_conc = pd.concat([df_full, load_kW, heatCapacity_kW, electrictyUsed_kW, \
                                                COP, nDis, timePeriod_tem , \
                                                timePeriod_watt, entropy_kjPerK,\
                                               entropy_kJ,nStratCharging, \
                                               TankEnergyTotal_kJ, \
                                               DisEntropy_kjPerK, \
                                                DisEntropy_kJ, \
                                                nStratDis, \
                                                DisTankEnergyTotal_kJ], axis=1)

    file_name = 'csvFile_{}'.format(datetime.datetime.now().strftime("%Y_%m_%d"))
    suffix = '.csv'
    filePath = os.path.join(os.getcwd(), file_name + suffix)
    df_Tem_Flow_Load_capacity_conc.to_csv(filePath, header=True, na_rep=np.nan)
    #print ('gross df with NAN is: ', df_Tem_Flow_Load_capacity_conc )
    return df_Tem_Flow_Load_capacity_conc

def Load_kWh(Lol, time_stamp_tem):
    
    #mHP = Lol[2]
    T = flatten_tem(Lol)
    #d = [x[10] for x in T]
    #print ('XXXXTem tem diagnosis is :', d)
    mL = Lol[3]
    #this is density as polynomial function of T
    p_LperH = [999.8473664794213 + 6.29265190e-02*x[7] - 8.42930922e-03*x[7]**2 + 6.77190849e-05*x[7]**3 \
 - 4.40840180e-07*x[7]**4 + 1.29302849e-09*x[7]**5 for x in T]
    #print ('denisty is:', p_LperH )
    #print ('Tem is:', [x[10] for x in T])
    # this is mass flow  in kg/S =  density*V(flow rate in m^3/sec)= d * (1000^-3/3600)
    mF_kgPerS =[ x*2.7777e-07*y for x, y in zip(p_LperH, mL)]
    #this is Cp as functiono of T linear function
    cP_kjPerkgK = [4.253264761904763 - 0.00470305*b[7] for b in T]
    #print ('Cp if load function is:')
    #print ('Cp is:', cP_kjPerkgK)
    #Cp*M*deltaT
    load_mCT_kW = [c*a*(b[7]-b[10]) for c, a, b in zip(cP_kjPerkgK,mF_kgPerS, T)]
    load_mCT_kW_l = [x*y for x,y in zip (time_stamp_tem, load_mCT_kW )]
    load_mCT_kWh = sum(load_mCT_kW_l)
    print ('Load in kWh is:', load_mCT_kWh)
    #print ('Load in kW:', load_mCT_kW)
    return load_mCT_kW

def tankStrat(df):
    dfT = df.iloc[:, 11:-2]
    #print (dfT.columns)
    #print (dfT)
    dfT = dfT[['T4', 'T3', 'T2', 'T1', 'T0', 'T9', 'T8', 'T7', 'T6', 'T5']]
    dfT = dfT.rename({'T4':'T0', 'T3':'T1', 'T2':'T2', 'T1':'T3', 'T0':'T4', 'T9':'T5', 'T8':'T6',\
              'T7':'T7','T6':'T8','T5':'T9'}, axis='columns')

    return dfT
#tankStratTem = tankStrat(df_conc)

def create_color_step_obj(cmap_name, n):
    """
    Return scalarMap object with n colors in gradient from color map
    given in cmap_name.
    """
    cmap = plt.get_cmap(cmap_name)
    values = range(n)
    cNorm  = clrs.Normalize(vmin=values[0], vmax=values[-1])
    scalarMap = cm.ScalarMappable(norm=cNorm, cmap=cmap)
    return scalarMap

#import logging
#logging.getLogger().setLevel(logging.CRITICAL)

# colors
cmap_name = "jet"
scm = create_color_step_obj(cmap_name, 10)
plt.ion()
#plt.rcParams["figure.figsize"]=5,5
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 8
fig_size[1] = 3
def plotObject(df, ax, fig, alpha =0.7, scm=None):
    ax.clear()
    for i in range (0, df.shape[1]):
        ax.plot(df.index, df.iloc[:, i], color= scm.to_rgba(i, alpha=alpha),\
                label = 'Layer ' + str(i))
        ax.legend(bbox_to_anchor=(0.4,0.8))
    fig.canvas.draw()
    ax.legend()
    #plt.legend(loc='upper left')
    return fig, ax
    
# initialize figure and interactivity
fig = plt.figure(1)
fig2 = plt.figure(2)
fig3 = plt.figure(3)
fig4 = plt.figure(4)

#Figure 1 and 2 axes initialise
ax = fig.add_subplot(121)
ax_2 = fig.add_subplot(122)
ax2 = fig2.add_subplot(122)
ax2_1 = fig2.add_subplot(121)
axTwin = ax2.twinx()

#Figure 3 axis initialies
ax3 = fig3.add_subplot(122)
ax3_1 = fig3.add_subplot(121)
ax3Twin = ax3.twinx()
fig.canvas.draw()
#plt.ion()

#Figure 4 Axes initialise
ax4 = fig4.add_subplot(122)
ax4_1 = fig4.add_subplot(121)
ax4Twin = ax4.twinx()

#fig.show()

ax.legend(loc='best')
ax.set_xlabel('Index')
ax.set_ylabel('Tem, C', color='r')
#################################
#Plot for HPin, Hpout, TmixL tem.

fig.show()
fig.canvas.draw()
ax_2.legend(loc='best')
ax_2.set_xlabel('Index')
ax_2.set_ylabel('Load in kW', color='r')
def plotObject_Tem_HpAndLoad(df, ax_2, fig):
    ax_2.clear()
    ax_2.plot(df.index, df.iloc[:, 3], label = 'Hp to Testing tank top')
    ax_2.plot(df.index, df.iloc[:, 4], label = 'Testing tank to HP Bottom')
    ax_2.plot(df.index, df.iloc[:, 8], label = 'load tem Mixed')
    
    ax_2.legend(bbox_to_anchor=(0.4,0.8))
    fig.canvas.draw()
    ax_2.legend()
    fig.savefig('Temperatures3.png')
    #plt.legend(loc='upper left')
    return fig, ax_2
##################################

#fig2 = plt.figure(2)

#plt.ion()

fig2.show()
fig2.canvas.draw()
ax2.legend(loc='best')
ax2.set_xlabel('Index')
ax2.set_ylabel('Load in kW', color='r')
def plotObject_Load(df, ax2, fig2):
    ax2.clear()
    axTwin.clear()
    ax2.plot(df.index, df.iloc[:, -15],label = 'Load in kW')
    #axTwin.plot(df.index, Nan2Zero(df).iloc[:, -11]*100, label = 'Discharge Efficiency', color = 'b')
    axTwin.plot(df.index, df.iloc[:, -11]*100, label = 'Discharge Efficiency', color = 'b')
    axTwin.set_ylabel('nDischarge',color ='b')
    #ax2.plot(df.index, COP, label = 'cop')
    #print (df.index)
    ax2.legend(bbox_to_anchor=(0.4,0.8))
    fig2.canvas.draw()
    ax2.legend()
    fig2.savefig('LoadNDiscCopHeatCapacityAndElectricty.png')
    #plt.legend(loc='upper left')
    return fig2, ax2
    
# initialize figure and interactivity
####Plot for heat_Capacity:

def Nan2Zero(df):
    #df.replace('NaN', 0)
     return df.fillna(0) 

fig2.show()
fig2.canvas.draw()
ax2_1.legend(loc='best')
ax2_1.set_xlabel('Index')
ax2_1.set_ylabel('Heat_Capacity in kW', color='r')
def plotObject_Heat_Capacity(df, ax2_1, fig2):
    ax2_1.clear()
    #axTwin = ax2_1.twinx()
    #axTwin.clear()
    
    ax2_1.plot(df.index, df.iloc[:, -14], label = 'heat_Capacity in kW')
    ax2_1.plot(df.index, df.iloc[:, -13], label = 'electrcity_kW')
    ax2_1.plot(df.index, df.iloc[:, -12], label = 'cop of system')
    #axTwin.plot(df.index, Nan2Zero(df).iloc[:, -2]*100, label = 'Discharge Efficiency', color = 'b')
    #axTwin.set_ylabel('nDischarge',color ='b')
    
    ax2_1.legend(bbox_to_anchor=(0.4,0.8))
    plt.subplots_adjust(wspace = 0.5)
    fig2.canvas.draw()
    ax2_1.legend()
    fig2.tight_layout()
    #plt.legend(loc='upper left')
    return fig2, ax2_1

###########################################
##########################################
###########################################
###########################################
###########################################
#########Discharging Strat Efficiency plots
###########################################
###########################################
###########################################
###########################################

'''
def refineDF_Discharge(df):
    #this function refine -ve or >100 values frrom nStrat
    #dropped_df = df.loc[((df<110) | (df>0)).any(1)]
    #refined_df = df['nStratCharging'].where(df['nStratCharging'] >=110, 0.01, inplace=True)
    #df.loc[df['nStratDischarge'] > 1.5] = 0.1
    df.loc[df['nStratDischarge'] < -0.1] = 0.1
    df_refined  = df['nStratDischarge']
    #print ('refined df is:', df_refined)
    #df.loc[df['nStratCharging'] > 110] = 0.1
    #if refined_df
    return df_refined
'''

fig4.show()
fig4.canvas.draw()
ax4.legend(loc='best')
ax4.set_xlabel('Index')
ax4.set_ylabel('Entropy_kJ', color='r')
def plotObject_entropy_Discharge(df, ax4, ax4_1,  fig4):
    ax4.clear()
    ax4Twin.clear()
    ax4_1.clear()
    y1 = df.iloc[:, -3]
    y2= df.iloc[:,  -4]
    y3 = df.iloc[:, -1]
    #print ('Figure: Discharge entropy is:', y1)
    #print ('Figure: Discharge availability  is:', y3)
    #y3_1 =refineDF_Discharge(df)
    y3_1 =df['nStratDischarge']
    #print ('Figure: Discharge Start Efficiency is:', y3_1)
    #print ('Values of refiend df are:', y3_1)
    #y3_1 = Nan2Zero(df.iloc[:, -2])
    #ax3.plot(df.index, y1, label = 'entropy in kJ')
    ax4.plot(df.index, y1, label = ' Discharging entropy in kJ')
    ax4.plot(df.index, y2, label = 'Discharging Entropy in KJ/K')
    #ax3.plot(df.index, y3, label = 'Availability kJ')
    ax4Twin.plot(df.index, y3, label = 'Discharging Availability kJ', color = 'g')
    #ax3.plot(df.index, df.iloc[:, 8], label = 'load tem Mixed')
    ax4Twin.set_ylabel('Dishcarging availibility',color ='g')
    ax4.legend(bbox_to_anchor=(0.4,0.8))
    ax4Twin.legend(bbox_to_anchor=(0.4,0.8))
    ax4.legend()
    #Plot strt eff on first fig object of fig3

    ax4_1.plot(df.index, y3_1, label = 'Disch_econdLawStratificationEff ')
    #ax3_1.set_ylabel('secondLawStratificationEff')
    ax4_1.legend(bbox_to_anchor=(0.4,0.8))
    ax4_1.legend()

    fig4.canvas.draw()
    fig4.savefig('Disch_EntropyExergyAvailability.png')
    #plt.legend(loc='upper left')
    return fig4, ax4




############################
##Exergy/Entropy/nStrt plots for charging
#############################

def refineDF(df):
    #this function refine -ve or >100 values frrom nStrat
    #dropped_df = df.loc[((df<110) | (df>0)).any(1)]
    #refined_df = df['nStratCharging'].where(df['nStratCharging'] >=110, 0.01, inplace=True)
    df.loc[df['nStratCharging'] > 1.5] = 0.1
    df.loc[df['nStratCharging'] < -0.1] = 0.1
    df_refined  = df['nStratCharging']
    #df.loc[df['nStratCharging'] > 110] = 0.1
    #if refined_df
    return df_refined

fig3.show()
fig3.canvas.draw()
ax3.legend(loc='best')
ax3.set_xlabel('Index')
ax3.set_ylabel('Entropy_kJ', color='r')
def plotObject_entropy(df, ax3, ax3_1,  fig3):
    ax3.clear()
    ax3Twin.clear()
    ax3_1.clear()
    y1 = df.iloc[:, -7]
    y2= df.iloc[:,  -8]
    y3 = df.iloc[:, -5]
    
    y3_1 =refineDF(df)
    #print ('Values of refiend df are:', y3_1)
    #y3_1 = Nan2Zero(df.iloc[:, -2])
    #ax3.plot(df.index, y1, label = 'entropy in kJ')
    ax3.plot(df.index, y1, label = ' Charging entropy in kJ')
    ax3.plot(df.index, y2, label = 'Charging Entropy in KJ/K')
    #ax3.plot(df.index, y3, label = 'Availability kJ')
    ax3Twin.plot(df.index, y3, label = 'Chanrging Availability kJ', color = 'g')
    #ax3.plot(df.index, df.iloc[:, 8], label = 'load tem Mixed')
    ax3Twin.set_ylabel('Charging availibility',color ='g')
    ax3.legend(bbox_to_anchor=(0.4,0.8))
    ax3Twin.legend(bbox_to_anchor=(0.4,0.8))
    ax3.legend()
    #Plot strt eff on first fig object of fig3

    ax3_1.plot(df.index, y3_1, label = 'secondLawStratificationEff_charging ')
    #ax3_1.set_ylabel('secondLawStratificationEff')
    ax3_1.legend(bbox_to_anchor=(0.4,0.8))
    ax3_1.legend()

    fig3.canvas.draw()
    fig3.savefig('entropyExergyAvailability.png')
    #plt.legend(loc='upper left')
    return fig3, ax3


#######################
###Discharge efficiency
#######################
def densityFumction(temVlaue):
    #tcalculating density at a specific temp.
    return temVlaue.map(lambda x: 999.8473664794213 + 6.29265190e-02*x - \
    8.42930922e-03*x**2 + 6.77190849e-05*x*3 \
    - 4.40840180e-07*x**4 + 1.29302849e-09*x**5)

def flowCubeMeterPerSec(flow):
    return flow.map(lambda x: x*0.001*0.000277777778)

def specificHeatkJPerKgK(temValue):
    return temValue.map(lambda x: 4.253264761904763 - 0.00470305*x)

def dfMultiplication(df1_p_hot, cp_df_hot, df1_p_cold, cp_df_cold, df_V,  Tin, Tout, timeStamp_tem):
    
    #df_V_litersPerH =  df_V.map(lambda x: x*1000*3600)
    #if df_V_litersPerH.iloc[-1] > 5:
    
    #Hot side p*V*Cp*T_hot in kj/sec, I will convert it to kwh by multiplying by timeStamp.Then to KJ
    #Finally because I need to divide teh net energy extraccted by total energy mstore*C*dT which is 
    #in kJ.
    #deltaT_df = Tout.subtract(Tin)
    l2df_timeStamp_df= pd.DataFrame(timeStamp_tem)
    #print ('type of timestamp object is:', type (l2df_timeStamp_df))
    pcp_df_hot = df1_p_hot.multiply( cp_df_hot)
    pVCp_df_hot = pcp_df_hot.multiply(df_V)
    pCpVT_df_hot = pVCp_df_hot.multiply(Tout)
    
    #Cold side pCpVT_df_cold is in kJ/s:
    # I am seperating hot from cold becasue density, Cp are funstion of temp.otherwise I would have
    # only done pVCp [Thot -Tcold] without any problem, however, p&Cp are function of Thot and Tcold
    #So I calculate them during hot and during cold side and just subtract them
    pcp_df_cold = df1_p_cold.multiply(cp_df_cold)
    pVCp_df_cold = pcp_df_cold.multiply(df_V)
    pCpVT_df_cold = pVCp_df_cold.multiply(Tin)
    
    pVCpDeltaT_df_kJPersec = pCpVT_df_hot.subtract( pCpVT_df_cold )
    #convert pandas series to pandas dataframe.otherwise it will not multiply with other PD series in
    #next step:
    pVCpDeltaT_df_kJPersec = pVCpDeltaT_df_kJPersec.to_frame()
    #print ('type of timestamp object is:', type (pVCpDeltaT_df_kJPersec))
    # convert the kJ/sec to kwH, as energy = power in time, 
    pVCpDeltaT_df_kWh = pVCpDeltaT_df_kJPersec.multiply(l2df_timeStamp_df, fill_value=0)
    #pVCpDeltaT_sum  = pVCpDeltaT_df.sum()
    pVCpDeltaT_df_kWh_sum  = pVCpDeltaT_df_kWh.sum()
    #convert kwh to kJ as I need to divide mstore * C *DeltaT = kJ to calculate teh discharge
    #efficiency, so energy taken out must be in kJ instead of kwh. To make sense 
    pVCpDeltaT_df_kJ_sum = pVCpDeltaT_df_kWh_sum*3600
    pVCpDeltaT_df_kJ_sum  = pd.to_numeric(pVCpDeltaT_df_kJ_sum)
    #print ('flow lools like this:',df_V)
    print ('Total sum discharge in kJ is :',pVCpDeltaT_df_kJ_sum )
    #print ('discharge in kJ/sec:',pVCpDeltaT_df_kJPersec ,'tiem df is',  l2df_timeStamp_df\
    #       , 'multiplied df is:', pVCpDeltaT_df_kWh)
    #print ('multiplied df is :', )
    #pVCpDeltaT = pVCp.multiply(deltaT_df)
    return pVCpDeltaT_df_kJ_sum

def TankVolumeDischarged(Lol,timeStamp):
    mLoad = Lol[3]
    #print ('len of Mload is:', len (mLoad))
    #print ('len of tiem stamp is:', len (timeStamp))
    litersDischarged = sum([x*y for x, y in zip (mLoad , timeStamp)])
    print ('liters discharged is :',litersDischarged )
    return litersDischarged

nDischargePlotterList = []
def nDicharge(df_conc_all, gross_DF):
    '''
    T_initial should be average tem of tank i.e. mean of 10 sensors just before the discharge
    initiates 

    '''
    df_flowGreaterThan5 = df_conc_all.loc[(df_conc_all['flowLoad']>0.5)&(df_conc_all['flowLoad']<5)]
    #print ('df for just before discharge starts is:', df_flowGreaterThan5['flowLoad'], df_flowGreaterThan5['id'] )
    df_flowGreaterThan5_temValues = df_flowGreaterThan5.iloc[-1, -12:-2]
    #print ('df for just before discharge starts is:', df_flowGreaterThan5_temValues, df_flowGreaterThan5.iloc[-1]['id'] )
    df_flowGreaterThan5_mean  = df_flowGreaterThan5_temValues.mean()
    T_inlet = df_conc_all['TbottomTestTankLoadCir']
    T_inlet_lastValue  =  T_inlet.iloc[-1]
    cP_kjPerkgK = 4.253264761904763 - 0.00470305*df_flowGreaterThan5_mean 
    p_LperH = 999.8473664794213 + 6.29265190e-02*df_flowGreaterThan5_mean - \
    8.42930922e-03*df_flowGreaterThan5_mean**2 + 6.77190849e-05*df_flowGreaterThan5_mean**3 \
 - 4.40840180e-07*df_flowGreaterThan5_mean**4 + 1.29302849e-09*df_flowGreaterThan5_mean**5 
    
    mcT_kJ = 0.397*p_LperH*cP_kjPerkgK*(df_flowGreaterThan5_mean-T_inlet_lastValue)
    #mcT_kJ shoudl be constant throught the discharge process, as its the energy content of tank 
    #from very begineening of tank.
    flowLoad  = df_conc_all['flowLoad']
    T_out  = df_conc_all['TTopTestTankLoadCir']
    #T_inlet = df_conc_all['TbottomTestTankLoadCir']
    if not abs(T_out.iloc[-1]-T_inlet.iloc[-1]) <  0.8*abs(df_flowGreaterThan5_mean-T_inlet.iloc[-1]):
        print ('OK ok oK oK ok if not small run ')

        numerator = dfMultiplication(densityFumction(gross_DF['TTopTestTankLoadCir']), \
                         specificHeatkJPerKgK(gross_DF['TTopTestTankLoadCir']), \
                         densityFumction(gross_DF['TbottomTestTankLoadCir']),\
                         specificHeatkJPerKgK(gross_DF['TbottomTestTankLoadCir']),\
                         flowCubeMeterPerSec(gross_DF ['flowLoad']), \
                         gross_DF['TbottomTestTankLoadCir'], \
                         gross_DF['TTopTestTankLoadCir'], timePeriod_tem)
        denominator = mcT_kJ
        dischargeEfficiency =  numerator/denominator
        dischargeEfficiency= dischargeEfficiency.to_numpy()[0]
        print('type of nDis now is ', dischargeEfficiency)
        #dischargeEfficiency = pd.to_numeric(dischargeEfficiency)
        nDischargePlotterList.append(dischargeEfficiency)
        print ('energy content of tank from the begineening of discharge in kJ, Inlet, mean, cp, p:' \
               , denominator, T_inlet_lastValue, df_flowGreaterThan5_mean, cP_kjPerkgK,p_LperH )
        #print ('energy content of tank from the begineening of discharge in kJ:', denominator)
        print ('energy/sec discharged from tank in kJ/sec:', numerator)
        print ('discharge efficiency is:', dischargeEfficiency)

        return dischargeEfficiency
        
###########################################
###########################################
#########Exergy calculation for discharge##
###########################################
###########################################


def mcTForExergyDischarging (l_load_kwh, time_stamp_tem):
    load_mCT_kW_l = [x*y for x,y in zip (l_load_kwh, time_stamp_tem )]
    load_kwh_total = sum(load_mCT_kW_l)
    load_kJ_total = load_kwh_total*3600
    print ('Discharging: load_kJ_total mul 3600:',load_kJ_total)
    return load_kJ_total


DisEntropyPlotter_SUMList_KjPerK = []
DisEntropyPlotter_SUMList_Kj = []
DisMCTPlotterList_TankEnergyKJ = []
def entropyDischarging(Df_conc):

    mL =Df_conc['flowLoad']
    T =Df_conc.iloc[: ,11:-2]
    T_Load_out_df =  Df_conc['TTopTestTankLoadCir']
    T_Load_in_df =  Df_conc['TbottomTestTankLoadCir']
    T = T[['T4', 'T3', 'T2', 'T1', 'T0', 'T9', 'T8', 'T7', 'T6', 'T5']]
    T = T.rename({'T4':'T0', 'T3':'T1', 'T2':'T2', 'T1':'T3', 'T0':'T4', 'T9':'T5', 'T8':'T6',\
              'T7':'T7','T6':'T8','T5':'T9'}, axis='columns')
    df_density_columns = ['d{}'.format(x) for x in range(0,10)]
    df_density = T.apply(lambda x: 999.8473664794213 + 6.29265190e-02*x - \
                         8.42930922e-03*x**2 + 6.77190849e-05*x**3 \
                         - 4.40840180e-07*x**4 + 1.29302849e-09*x**5)
    #0.397/10 is probably mass of each layer which are 10 layers
    #It is volume of each layer which multiply by density to give mass
    df_m_kg = df_density.multiply(0.397/10, axis =1) 
    df_heatCapacity_kJPerkgK = T.apply(lambda x: 4.253264761904763 - 0.00470305*x)
    #T0_ambient_df =pd.DataFrame([np.random.uniform(24, 26) for _ in range(T.shape[0])])
    T0_ambient_df = np.random.uniform(21, 22)
    #log [TinLoad/Ti(h)], Ti is the tanks stratified temperatures in height 
    df_Logvalues = T.apply(lambda x: np.log(T_Load_out_df/x))
    #cpxLog[Tinlet/Ti]
    lnT_Mul_Cp_df = df_Logvalues.multiply(df_heatCapacity_kJPerkgK, axis =1)
    #mcpln[Tinlet/Ti]
    mass_mul_lnT_and_cp_df = lnT_Mul_Cp_df.multiply(df_m_kg, axis =1)
    #Tambient*DeltaS
    entropy_df = mass_mul_lnT_and_cp_df.multiply(T0_ambient_df, axis =0)
    #entropy sum for all teh columns, This si not time wise, so each tiem has one single value of tank
    entropy_sum_heightWise = entropy_df.sum(axis = 1)
    #print ('Entropy sum whole height wise is  :', entropy_sum_heightWise )
    #print ('Entropy sum whole height wise is  :', entropy_sum_heightWise.iloc[0] )
    
    
    entropy_sum_kjPerK = mass_mul_lnT_and_cp_df.sum(axis = 1)
    entropyLastValue_kJPerK = entropy_sum_kjPerK.iloc[-1]
    DisEntropyPlotter_SUMList_KjPerK.append(entropyLastValue_kJPerK)
    #print ('entropy list kJ/k is :', DisEntropyPlotter_SUMList_KjPerK)
    
    DisEntropyPlotter_SUMList_Kj.append(entropy_sum_heightWise.iloc[-1])
    #print ('Entropy sum whole height wise is  :', entropy_sum_heightWise.iloc[-1] )
    #print ('Entropy appended list is  :',DisEntropyPlotter_SUMList_Kj )
    #print ('entropy list kJ is :',DisEntropyPlotter_SUMList_Kj)
    #print ('discharge: log values that shoudl be negative is:', df_Logvalues)
    #print ('discharge: entropy df is :', entropy_df)
    #print ('discharge: entropy_sum :', entropy_sum_heightWise)
    MCT_df = df_heatCapacity_kJPerkgK.multiply(T, axis =1).multiply(df_m_kg, axis=1).sum(axis = 1)
    #appned last value (current value of energy) as value- energy is decreasing as discharge goes on 
    DisMCTPlotterList_TankEnergyKJ.append(MCT_df.iloc[-1] )
    print ('Availability :Total energy of in Kj is :', MCT_df.iloc[-1])
    #print ('Availability whole df :Total energy of in Kj howle df :', MCT_df)
    return entropy_sum_heightWise

nStratDischragePlotterList = []
def StratEffDischarge(load_kJ_total_float, entropy_sum_height_float):
    #n1 = (load_kJ_total_float-entropy_sum_height_float)/ load_kJ_total_float
    n2 = (load_kJ_total_float-entropy_sum_height_float.iloc[0])/ load_kJ_total_float
    nStratDischragePlotterList.append(n2)
    #print ('Discharge: strat efficiency sum_DF :', n1)
    print ('Discharge: strat efficiency sum_float :', n2)
    #print ('nStratDischarge plotter list is :', nStratDischragePlotterList[-1])
    return n2


###################################
###Exergy calculation for charging
###################################


def mcTForExergyCharging(Lol, time_stamp_tem, time_stamp_watt):
    #this calculates the energy addiction per timestamp in the tank. and integrates it over whole charging
    
    mHP = Lol[2]
    T = flatten_tem(Lol)
    #mL = Lol[3]
    #watt_kW = Lol[4]
    #p_LperH = [999.8473664794213 + 6.29265190e-02*x[2] - 8.42930922e-03*x[2]**2 + 6.77190849e-05*x[2]**3 \
    #- 4.40840180e-07*x[2]**4 + 1.29302849e-09*x[2]**5 for x in T]
    p_LperH = [999.8473664794213 + 6.29265190e-02*x[3] - 8.42930922e-03*x[3]**2 + 6.77190849e-05*x[3]**3 \
 - 4.40840180e-07*x[3]**4 + 1.29302849e-09*x[3]**5 for x in T]
    mF_kgPerS =[ x*2.7777e-07*y for x, y in zip(p_LperH, mHP)]
    #cP_kjPerkgK = [4.253264761904763 - 0.00470305*b[2] for b in T]
    cP_kjPerkgK = [4.253264761904763 - 0.00470305*b[3] for b in T]
    mCT_kW = [c*a*(b[3]-b[4]) for c, a, b in zip(cP_kjPerkgK,mF_kgPerS, T)]
    mCT_kWh_l = [x*y for x,y in zip (time_stamp_tem, mCT_kW)]
    #mCT_kJ_l = pd.DataFrame(mCT_kWh_l).multiply(3600)
    mCT_kJ_l = pd.DataFrame(mCT_kWh_l)
    #mCT_kWh_total = sum(mCT_kWh_l)
    mCT_kWh_total = mCT_kJ_l.sum()
    mCT_KJ_total = mCT_kWh_total*3600
    #electricty consumed:
    #watt_kW_l = [x*y for x,y in zip (time_stamp_watt,  watt_kW)]
    #watt_kWh = sum(watt_kW_l)
    #cop 
    #cop =mCT_kWh/watt_kWh
    #copPlotterList.append(cop)
    #print ('cop of system is:', cop)
    #print ('kwh heat addition is :', mCT_kWh)
    print ('chanrging : whole kJ list is mul by 3600:', mCT_KJ_total)
    #print ('chanrging : df of mcT energy addition is:', mCT_kJ_l)
    #print ('electricity in khW is:', watt_kWh)
    
    #print ('electricity consumption kW :', watt_kW)
    return mCT_KJ_total

entropyPlotter_SUMList_KjPerK = []
entropyPlotter_SUMList_Kj = []
MCTPlotterList_TankEnergyKJ = []
def entropyCharging(Df_conc):
    mHP =Df_conc['flowHP']
    T =Df_conc.iloc[: ,11:-2]
    T_hp_out_df =  Df_conc['TtopTestTankHPCir']
    T_hp_in_df =  Df_conc['TbottomTestTankHpCir']
    T = T[['T4', 'T3', 'T2', 'T1', 'T0', 'T9', 'T8', 'T7', 'T6', 'T5']]
    T = T.rename({'T4':'T0', 'T3':'T1', 'T2':'T2', 'T1':'T3', 'T0':'T4', 'T9':'T5', 'T8':'T6',\
              'T7':'T7','T6':'T8','T5':'T9'}, axis='columns')
    df_density_columns = ['d{}'.format(x) for x in range(0,10)]
    df_density = T.apply(lambda x: 999.8473664794213 + 6.29265190e-02*x - \
                         8.42930922e-03*x**2 + 6.77190849e-05*x**3 \
                         - 4.40840180e-07*x**4 + 1.29302849e-09*x**5)
    #0.397/10 is probably mass of each layer which are 10 layers
    df_m_kg = df_density.multiply(0.397/10, axis =1) 
    df_heatCapacity_kJPerkgK = T.apply(lambda x: 4.253264761904763 - 0.00470305*x)
    #T0_ambient_df =pd.DataFrame([np.random.uniform(24, 26) for _ in range(T.shape[0])])
    T0_ambient_df = np.random.uniform(21, 22)
    df_Logvalues = T.apply(lambda x: np.log(T_hp_out_df /x))
    lnT_Mul_Cp_df = df_Logvalues.multiply(df_heatCapacity_kJPerkgK, axis =1)
    mass_mul_lnT_and_cp_df = lnT_Mul_Cp_df.multiply(df_m_kg, axis =1)

    entropy_df = mass_mul_lnT_and_cp_df.multiply(T0_ambient_df, axis =0)
    entropy_sum_heightWise = entropy_df.sum(axis = 1)
    
    #entropyLastValue_kJPerK = mass_mul_lnT_and_cp_df.iloc[-1]
    #appending entropy sum to entropyPlotter_SUMList_KjPerK
    #entropyLastValue_kJPerK = entropy_sum_heightWise.iloc[-1]
    
    #calculates kJ/K  first without multiplication with T0 =Tambient
    #and appends it to entropyPlotter_SUMList_KjPerK
    entropy_sum_kjPerK = mass_mul_lnT_and_cp_df.sum(axis = 1)
    entropyLastValue_kJPerK = entropy_sum_kjPerK.iloc[-1]
    entropyPlotter_SUMList_KjPerK.append(entropyLastValue_kJPerK)
    #print ('entropy list kJ/k is :', entropyPlotter_SUMList_KjPerK)
    
    #Now appned Kj Total of tank entropy, by multiplying it with To
    entropyPlotter_SUMList_Kj.append(entropy_sum_heightWise.iloc[-1])
    #print ('entropy list kJ is :',entropyPlotter_SUMList_Kj,)
    
    #saving entropy of each node in a numpy file.
    #print ('shape of entropy df is:', mass_mul_lnT_and_cp_df.shape)
    
    #Exporting to csv each node entropy:
    file_name = 'entropyNodeWise_{}'.format(datetime.datetime.now().strftime("%Y_%m_%d"))
    suffix = '.csv'
    filePath = os.path.join(os.getcwd(), file_name + suffix)
    #mass_mul_lnT_and_cp_df.to_csv(filePath, header=True, na_rep=np.nan)
    
    
    #Calculation of Totoal energy in tank for availability = Energy - Entropy
    #I have entropy in KJ i should calculate Totoal enegry to show, how much is lost in entropy 
    #just for comparison.
    
    MCT_df = df_heatCapacity_kJPerkgK.multiply(T, axis =1).multiply(df_m_kg, axis=1).sum(axis = 1)
    MCTPlotterList_TankEnergyKJ.append(MCT_df.iloc[-1] )
    print ('Availability :Total energy of in Kj is :', MCT_df.iloc[-1])
    
    
    return entropy_sum_heightWise

nStratPlotterList = []
def nStratCharging(mCT_kWh_total_l, entropy_sum_heightWise):
    nStart = (mCT_kWh_total_l - entropy_sum_heightWise.iloc[-1]) / mCT_kWh_total_l
    nStratPlotterList.append(nStart.iloc[-1])
    #print ('nStratCharging plotter list is :', nStratPlotterList)
    print ('Charging stratified Efficiency:', nStart)
    return nStart


while True:
    #c.execute("INSERT INTO flowReadings(flowHp, flowLoad) VALUES(?,?,?,?)", (chan2.voltage, chan1.voltage))
    #connection.commit()
    
    ###################################################################################
    ################################################
    ##Modbus connection for wattmeter readings in kW
    ##https://stackoverflow.com/questions/28186746/python-convert-2-ints-to-float
    ################################################
    
    c = ModbusClient(host="10.208.8.125", port=502, auto_open=True)
    
    #This reads the register address 19026 where all teh meteric(values of wattmeter) 
    #values are stored in a 16 bit values.county = 2, means read two values in the
    #same register address.Register is a column (like in spreadsheet). each register
    #store a 16 bit value, we read two 16 bit value and would convert those 2 16 bit 
    #value to a 32 bit floating point value by the formula
    regs = c.read_input_registers(19026, 2)
    #this is forst value of two counts
    a = regs[0]
    #This is second value of two counts
    b = regs[1]
    #This is how we convert two 16 bit value to a single 32 floating point number.
    #from stackoverflow
    mypack = pack('>HH',a,b)
    #print (mypack)
    fl = unpack('>f', mypack)
    #fl = struct.unpack('!f', bytes.fromhex('{0:02x}'.format(a) + '{0:02x}'.format(b)))
    #fl is a tuple (5.0186,) I need to unpack it index it with [0] 
    fl = fl[0]*10**-3
    #wattMeterKw.append(fl)
    #lol[3].append(fl)
    #print ('watter meter reaidngs are:', wattMeterKw)
    #print ('gross lol is:', lol)
    ####################################################################################
    
    chan1 = AnalogIn(ads, ADS.P0)
    chan2 = AnalogIn(ads, ADS.P1)

    chan1Vol = chan1.voltage
    chan1curr = chan1Vol/159.42

    chan2Vol = chan2.voltage
    chan2curr=chan2Vol/159.65
    #flow1 = ((chan1Vol/159.42)*1000 -4)/16*1000
    flow1 = ((chan1Vol/159.42)-0.003956)/0.0000159
    #flow2 = ((chan2Vol/159.65)*1000 -4)/16*4000 +20
    #flow2 = ((chan2Vol/159.65)- 0.0005468893873066417)/1.09561608e-05
    flow2 = ((chan2Vol/159.65)- 0.003973767754877122)/5.3038815e-06
    cL.execute("INSERT INTO flowReadings(flowHp, flowLoad, watt) VALUES(%s, %s, %s)", (flow2, flow1, fl))
    connectionL.commit()
    
    #cL =connectionL.cursor()
    cL.execute("SELECT * FROM flowReadings ORDER BY id DESC LIMIT 1")
    FlowFormDb = cL.fetchall()
    #print ('flow and watt from FlowWattDB is :',FlowFormDb[-1][2],FlowFormDb )
    #print ('Time period of flow load and watt is :',timePeriod_watt, [x* 3600 for x in timePeriod_watt])

    #c.execute("SELECT * from temSensor")
    #cR.execute("SELECT * FROM temSensor ORDER BY id DESC LIMIT 1")
    #result = cR.fetchall()
    
    #print('flow HP:',"{:>5}\t{:>5.3f}".format(chan2.value, chan2.voltage), '\n\n')
    #print('flow load:',"{:>5}\t{:>5.3f}".format(chan1.value, chan1.voltage, '\n\n'))
    print('flow rates load is = ',chan1Vol, chan1curr,flow1 )
    print('flow rates HP is = ',chan2Vol, chan2curr,flow2 )

    connectionR = db.Connection(host=HOST, port=PORT,user=USER, passwd=PASSWORD, db=DB)
    cR = connectionR.cursor()
    #c.execute("SELECT * from temSensor")
    cR.execute("SELECT * FROM temSensor ORDER BY id DESC LIMIT 1")
    result = cR.fetchall()
    print ('result is',result)
    #print ('result diagnoses is',result[0])
    id = result[0][0]
    id_flowWatt = FlowFormDb[0][0]
    flowHP  = FlowFormDb[-1][2]
    flowLoad  = FlowFormDb[-1][3]
    wattUsed = FlowFormDb[-1][4]
    #print ('flow HP, flow Load, watt is:' ,flowHP, flowLoad, wattUsed)
    #idGenerator(id, l_id)
    #print ('id is :', id)
    
    flowRateLoad.append(flow1)
    if lol[0] ==[] or id < lol[0][-1][0][0] :
        lol[0].append(result)
        #print (lol)
        if lol[1] ==[] or id_flowWatt < lol[1][-1][0][0]:
            lol[1].append(FlowFormDb)
            lol[2].append(flowHP)
            lol[3].append(flowLoad)
            lol[4].append(wattUsed)
            timeStampCreator_cop(lol)
            timeStampCreator_watt(lol)
            wattMeterKw.append(fl)
    elif lol[0] != [] and id > lol[0][-1][0][0]:
        lol[0].append(result)
        if lol[1] != [] and id > lol[1][-1][0][0]:
            lol[1].append(FlowFormDb)
            lol[2].append(flowHP)
            lol[3].append(flowLoad)
            lol[4].append(wattUsed)
            timeStampCreator_cop(lol)
            timeStampCreator_watt(lol)
            wattMeterKw.append(fl)
        
    print ('cop is:', Cop(lol, timePeriod_tem, timePeriod_watt ))
    
    df = tankStrat(dfs(lol))

    GrossDf = toCsv(dfs(lol), list2df(Load_kWh(lol, timePeriod_tem), 'Load_kW'), \
                    list2df(MCT_timeStamp(lol, timePeriod_tem),'Heat_Capacity_kW'),\
                    list2df(wattMeterKw, 'electrcity_kW'), list2df(copPlotterList, 'COP'), \
                   list2df(nDischargePlotterList, 'nDis'), \
                    list2df(timePeriod_tem, 'timeStamp_Temp'),\
                    list2df(timePeriod_watt, 'timeStamp_watt'),\
                   list2df(entropyPlotter_SUMList_KjPerK , 'entropy_kJ/K'), \
                   list2df(entropyPlotter_SUMList_Kj , 'entropy_kJ'),\
                   list2df(nStratPlotterList , 'nStratCharging'),\
                   list2df(MCTPlotterList_TankEnergyKJ, 'TotalTanksEnergyForAvailability_kJ'),\
                    list2df(DisEntropyPlotter_SUMList_KjPerK , 'DisEntropy_kj/K'),\
                   list2df(DisEntropyPlotter_SUMList_Kj , 'DisEntropy_kj'), \
                   list2df(nStratDischragePlotterList , 'nStratDischarge'), \
                   list2df(DisMCTPlotterList_TankEnergyKJ,  'DisTotalTanksEnergyForAvailability_kJ'))
    
    #print ('gorss DF is :',GrossDf.iloc[:, -10] )
    #GrossDf = toCsv(dfs(lol), list2df(Load_kWh(lol), 'Load_kW'), list2df(MCT_timeStamp(lol, timePeriod),'Heat_Capacity_kW'))
    #heatAddition_kwh, cop = MCT_timeStamp(lol, timePeriod)
    # Plot tem values as a seperate first fig

    fig, ax = plotObject(df, ax,  fig, alpha=0.7, scm=scm)
    #plot load_kW in different fig2 
    fig2, ax2 = plotObject_Load(GrossDf, ax2, fig2)
    #Plot heat_Capacity in the same fig as fig2 but as a subplot
    fig2, ax2_1 =plotObject_Heat_Capacity(GrossDf, ax2_1, fig2)
    #This plot the HP in and out and tmixL laod tem.
    fig, ax_1 = plotObject_Tem_HpAndLoad(GrossDf, ax_2, fig)
    
    #Thjis plot plots Entropy in kJ/K and kJ
    fig3, ax3 = plotObject_entropy(GrossDf, ax3,ax3_1, fig3)
    
    fig4, ax4 = plotObject_entropy_Discharge(GrossDf, ax4, ax4_1,  fig4)
    
    #fig4, ax4 = plotObject_entropy_Discharge(GrossDf, ax4, ax4_1,  fig4)

    #print ('fetch the flow load:', nDicharge(dfs(lol)))
    #nDicharge(dfs(lol))
    #print ('lol len and lol itself is :', len (lol[0]), lol[0])
    #print ('Density of df is :',densityFumction(GrossDf ['TbottomTestTankLoadCir']))
    #print ('fow in cubeic meter per sec  :',flowCubeMeterPerSec(GrossDf ['flowLoad']))
    #flowCubeMeterPerSec(flow)
    #print ('discharge mcdelta T is :',dfMultiplication(densityFumction(), df2_V, Tin, Tout), flowCubeMeterPerSec(GrossDf ['flowLoad']))
    #dfMultiplication(df1_p, df2_V, Tin, Tout)
    #print ('flow in m3/sec:', flowCubeMeterPerSec(GrossDf ['flowLoad']))
    #print ('hot water cp, cold water cp:', specificHeatkJPerKgK(GrossDf['TTopTestTankLoadCir']),specificHeatkJPerKgK(GrossDf['TbottomTestTankLoadCir']))
    #print ('how water density, cold water density:', densityFumction(GrossDf['TTopTestTankLoadCir']),densityFumction(GrossDf['TbottomTestTankLoadCir']))
    #nDicharge(dfs(lol), GrossDf)
    #print ('tiem perod is :', pd.DataFrame({'time_tem':timePeriod_tem}))
    #print ('nDis plottre list is:',nDischargePlotterList, len(nDischargePlotterList))
    #print ('nDis plotter df looks like:',list2df(nDischargePlotterList, 'nDis'))
    #if nDischargePlotterList
    #print (' conc df wiuth Nan is :',dfs(lol))
    #df_CONC = dfs(lol)
    #print ('TemStrat is:',df)
    #entropyCharging(dfs(lol))
    #entropyCharging(dfs(lol))
    #mcTForExergyCharging(lol,timePeriod_tem,timePeriod_watt)
    #print ('nDis df looks like thuis :',Nan2Zero(list2df(nDischargePlotterList, 'nDis')))
    #nStratCharging(mcTForExergyCharging(lol,timePeriod_tem,timePeriod_watt), entropyCharging(dfs(lol)))
    #print ('GRoss DF is :', GrossDf )
    if GrossDf ['flowLoad'].iloc[-1]>50:
        #print ('Highre discharge calculating Discharge Efficiency',GrossDf ['flowLoad'].iloc[-1] )
        nDicharge(dfs(lol), GrossDf)
        TankVolumeDischarged(lol,timePeriod_watt)
        StratEffDischarge(mcTForExergyDischarging (Load_kWh(lol, timePeriod_watt), timePeriod_watt), \
                          entropyDischarging(dfs(lol)))
        #creat discharge grasphs only when discharge
        
        #plotObject_entropy_Discharge(GrossDf, ax4, ax4_1,  fig4)
    
    elif GrossDf ['flowHP'].iloc[-1]>0.5:
        print ('charging is going on so I will calculate charging efficiency:==' )
        #entropyCharging(dfs(lol))
        #mcTForExergyCharging(lol,timePeriod_tem,timePeriod_watt)
        nStratCharging(mcTForExergyCharging(lol,timePeriod_tem,timePeriod_watt), entropyCharging(dfs(lol)))
        
    else : 
        #This else conditions fills the nDischargePlotterList list even when discharge is not going on
        #otehrwise its problem. 
        nDischargePlotterList.append(np.nan)

    '''
    dfMultiplication(densityFn in kwh is: 6.10671895076359umction(GrossDf['TTopTestTankLoadCir']), \
                     specificHeatkJPerKgK(GrossDf['TTopTestTankLoadCir']), \
                     densityFumction(GrossDf['TbottomTestTankLoadCir']),\
                     specificHeatkJPerKgK(GrossDf['TbottomTestTankLoadCir']),\
                     flowCubeMeterPerSec(GrossDf ['flowLoad']), \
                     GrossDf['TbottomTestTankLoadCir'], \
                     GrossDf['TTopTestTankLoadCir'], timePeriod_tem)
    '''
    
    print('________________________________________________________________')
    time.sleep(0.01)
# Out:
# table flowReadings deleted
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  0.6340193487350078 0.003971308166207377 -0.4637337145910134
# result is ((5994, datetime.datetime(2021, 5, 12, 12, 22, 19), 23.7388, 26.3435, 23.8064, 19.1096, 26.2758, 25.4299, 27.4942, 17.6242, 24.6181, 23.6712, 23.8403, 23.7726, 23.8403, 23.705, 26.8172, 23.9755, 23.8741, 23.7388, 23.9079),)
# XXXXXXXXXXXXXXXXXX COP with kW is: -0.2576968919256904
# electricity in khW is: 2.910283333333333e-06
# cop is: -0.2576968919256904
# Load in kWh is: 6.830754496020748e-07
# heat addition in kwh is: -7.49970969623138e-07
# ________________________________________________________________
# flow rates load is =  0.6360194097720268 0.003989583551449171 2.1121730471176354
# flow rates HP is =  0.6360194097720268 0.003983835952220649 1.898269662232681
# result is ((5998, datetime.datetime(2021, 5, 12, 12, 22, 26), 23.7388, 26.3435, 23.7726, 19.0758, 26.2419, 25.4299, 27.4604, 17.5904, 24.6519, 23.705, 23.8403, 23.7726, 23.8741, 23.7388, 26.8172, 24.0093, 23.8403, 23.7726, 23.8741),)
# XXXXXXXXXXXXXXXXXX COP with kW is: 0.6538543250149248
# electricity in khW is: 1.7183483333333332e-05
# cop is: 0.5899883419531967
# Load in kWh is: 4.340653684289046e-06
# heat addition in kwh is: 1.0138054840813723e-05
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    0.036365
# dtype: float64
# Availability :Total energy of in Kj is : 39538.39975544111
# Charging stratified Efficiency: 0   -84168.481019
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  0.6340193487350078 0.003971308166207377 -0.4637337145910134
# result is ((6001, datetime.datetime(2021, 5, 12, 12, 22, 31), 23.7388, 26.3435, 23.8064, 19.1096, 26.2758, 25.4299, 27.4265, 17.5567, 24.6181, 23.705, 23.8403, 23.7726, 23.8741, 23.705, 26.8172, 23.9417, 23.8403, 23.7388, 23.8403),)
# XXXXXXXXXXXXXXXXXX COP with kW is: -0.32084853350421716
# electricity in khW is: 2.4195866666666666e-05
# cop is: 0.34150987565737995
# Load in kWh is: 6.048342308294233e-06
# heat addition in kwh is: 8.263127416755878e-06
# ________________________________________________________________
# flow rates load is =  0.6300192266609699 0.003951945970775122 -0.25497039150178974
# flow rates HP is =  0.6340193487350078 0.003971308166207377 -0.4637337145910134
# result is ((6005, datetime.datetime(2021, 5, 12, 12, 22, 38), 23.7388, 26.3435, 23.8064, 19.1096, 26.2081, 25.4637, 27.4265, 17.6242, 24.5843, 23.705, 23.8403, 23.7388, 23.8403, 23.7388, 26.7834, 23.9417, 23.8403, 23.7726, 23.8064),)
# XXXXXXXXXXXXXXXXXX COP with kW is: -0.28645498139490905
# electricity in khW is: 3.20502e-05
# cop is: 0.17591868453472662
# Load in kWh is: 5.5492967893925215e-06
# heat addition in kwh is: 5.638229023074895e-06
# ________________________________________________________________
# flow rates load is =  0.6360194097720268 0.003989583551449171 2.1121730471176354
# flow rates HP is =  0.7000213629566333 0.0043847251046453695 77.4823777205896
# result is ((6008, datetime.datetime(2021, 5, 12, 12, 22, 43), 23.7388, 26.3773, 23.8741, 19.1096, 26.2419, 25.4637, 27.3927, 17.5904, 24.5504, 23.705, 23.8403, 23.7726, 23.8403, 23.705, 26.8172, 23.9417, 23.8403, 23.7726, 23.9079),)
# XXXXXXXXXXXXXXXXXX COP with kW is: 1.1566613879122867
# electricity in khW is: 0.0003527152
# cop is: 0.8922843387114762
# Load in kWh is: 8.616050552555833e-06
# heat addition in kwh is: 0.00031472224898548606
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    1.128838
# dtype: float64
# Availability :Total energy of in Kj is : 39522.323183030865
# Charging stratified Efficiency: 0   -2854.942944
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  1.1820360728782007 0.0074039215338440375 646.7251915350889
# result is ((6011, datetime.datetime(2021, 5, 12, 12, 22, 48), 23.7388, 25.9036, 23.8403, 18.9408, 26.2081, 25.4299, 27.3927, 18.1305, 24.6181, 23.705, 23.8741, 23.7726, 23.8403, 23.705, 26.8849, 23.9417, 23.8741, 23.7726, 23.8403),)
# XXXXXXXXXXXXXXXXXX COP with kW is: 5.9377736971687
# electricity in khW is: 0.0007108415888888889
# cop is: 3.434233082799438
# Load in kWh is: 1.032373917656102e-05
# heat addition in kwh is: 0.0024411957011919393
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    8.7611
# dtype: float64
# Availability :Total energy of in Kj is : 39532.95777143619
# Charging stratified Efficiency: 0   -286.505871
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6320192876979889 0.003964491830999805 0.5340774213713702
# flow rates HP is =  1.3460410779137548 0.008431199986932382 840.4094684346284
# result is ((6015, datetime.datetime(2021, 5, 12, 12, 22, 55), 23.705, 24.821, 23.8403, 18.3668, 26.2081, 25.4976, 27.3927, 18.5018, 24.5843, 23.705, 23.8403, 23.7388, 23.8403, 23.705, 26.9188, 23.9755, 23.8741, 23.7726, 23.8741),)
# XXXXXXXXXXXXXXXXXX COP with kW is: 3.728475214856087
# electricity in khW is: 0.0011335832555555555
# cop is: 3.7757037057005136
# Load in kWh is: 1.14093179415357e-05
# heat addition in kwh is: 0.004280074498721163
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    15.370829
# dtype: float64
# Availability :Total energy of in Kj is : 39538.27842174917
# Charging stratified Efficiency: 0   -64.718594
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  1.4100430310983612 0.0088320891393571 915.9935764929849
# result is ((6018, datetime.datetime(2021, 5, 12, 12, 23), 23.7388, 24.2799, 23.8064, 18.0292, 26.2081, 25.4637, 27.3927, 18.1305, 24.5504, 23.705, 23.8064, 23.7726, 23.8403, 23.7388, 27.0542, 24.0432, 23.9079, 23.7388, 23.9079),)
# XXXXXXXXXXXXXXXXXX COP with kW is: 1.9740686866812782
# electricity in khW is: 0.0016237640888888889
# cop is: 3.0615614404512272
# Load in kWh is: 1.3330429360907376e-05
# heat addition in kwh is: 0.004971253522931641
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    17.857211
# dtype: float64
# Availability :Total energy of in Kj is : 39580.96974171164
# Charging stratified Efficiency: 0   -11.173102
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  1.4260435193945127 0.00893231142746328 934.8896035075742
# result is ((6022, datetime.datetime(2021, 5, 12, 12, 23, 7), 23.705, 24.0093, 23.8064, 17.8267, 26.1743, 25.4637, 27.3588, 17.8604, 24.6519, 23.6712, 23.8403, 23.7726, 23.8403, 23.705, 28.2052, 24.5843, 24.2461, 23.7726, 23.705),)
# XXXXXXXXXXXXXXXXXX COP with kW is: 0.8660702464733805
# electricity in khW is: 0.0020426240888888887
# cop is: 2.6409539080733064
# Load in kWh is: 1.5721080352196428e-05
# heat addition in kwh is: 0.005394476070275787
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    19.380172
# dtype: float64
# Availability :Total energy of in Kj is : 39868.4130170203
# Charging stratified Efficiency: 0    22.90836
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6320192876979889 0.003964491830999805 0.5340774213713702
# flow rates HP is =  1.4300436414685507 0.008957366999489826 939.6136102612215
# result is ((6025, datetime.datetime(2021, 5, 12, 12, 23, 12), 23.705, 23.9079, 23.8064, 17.7592, 26.1743, 25.4976, 27.3927, 17.7254, 24.6857, 23.6712, 23.8064, 23.7726, 23.8064, 23.6712, 28.6453, 24.8548, 24.5166, 23.8064, 23.9417),)
# XXXXXXXXXXXXXXXXXX COP with kW is: 0.43556600387068495
# electricity in khW is: 0.002391571311111111
# cop is: 2.3191721658694924
# Load in kWh is: 1.6410402746092146e-05
# heat addition in kwh is: 0.005546465617420897
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    19.927181
# dtype: float64
# Availability :Total energy of in Kj is : 40049.57063802624
# Charging stratified Efficiency: 0    37.577859
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  1.4300436414685507 0.008957366999489826 939.6136102612215
# result is ((6029, datetime.datetime(2021, 5, 12, 12, 23, 19), 23.705, 23.9079, 23.8403, 17.6579, 26.1743, 25.4637, 27.3588, 17.5567, 24.821, 23.6712, 23.8064, 23.8064, 23.8741, 23.705, 28.7131, 25.2608, 24.8548, 23.9755, 23.8741),)
# XXXXXXXXXXXXXXXXXX COP with kW is: 0.29090987606313234
# electricity in khW is: 0.0028787227
# cop is: 1.9759398039924256
# Load in kWh is: 1.8303075069449467e-05
# heat addition in kwh is: 0.005688182767586546
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    20.43722
# dtype: float64
# Availability :Total energy of in Kj is : 40215.328684718734
# Charging stratified Efficiency: 0    43.312685
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6360194097720268 0.003989583551449171 2.1121730471176354
# flow rates HP is =  1.4320437025055697 0.008969894785503097 941.975613638045
# result is ((6033, datetime.datetime(2021, 5, 12, 12, 23, 26), 23.705, 23.8741, 23.8741, 17.5904, 26.1743, 25.4976, 27.3588, 17.5229, 24.8548, 23.705, 23.8403, 23.7726, 23.8741, 23.705, 28.8485, 25.8021, 25.1255, 24.3137, 23.7726),)
# XXXXXXXXXXXXXXXXXX COP with kW is: 0.0
# electricity in khW is: 0.0032953560333333336
# cop is: 1.726120853118505
# Load in kWh is: 2.132475697752775e-05
# heat addition in kwh is: 0.005688182767586546
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    20.43722
# dtype: float64
# Availability :Total energy of in Kj is : 40407.47503567323
# Charging stratified Efficiency: 0    55.389408
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6360194097720268 0.003989583551449171 2.1121730471176354
# flow rates HP is =  1.4320437025055697 0.008969894785503097 941.975613638045
# result is ((6036, datetime.datetime(2021, 5, 12, 12, 23, 31), 23.7388, 23.8064, 23.8403, 17.5567, 26.1743, 25.5314, 27.3588, 17.4892, 24.8548, 23.705, 23.8403, 23.7388, 23.8403, 23.705, 28.8147, 26.0389, 25.4637, 24.4828, 23.7388),)
# XXXXXXXXXXXXXXXXXX COP with kW is: -0.09498505834111529
# electricity in khW is: 0.003831106033333334
# cop is: 1.4714535367937722
# Load in kWh is: 2.359648471473275e-05
# heat addition in kwh is: 0.005637294522580293
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    20.254039
# dtype: float64
# Availability :Total energy of in Kj is : 40503.57579644845
# Charging stratified Efficiency: 0    64.534561
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  1.4360438245796074 0.008994950357529643 946.6996203916924
# result is ((6040, datetime.datetime(2021, 5, 12, 12, 23, 38), 23.705, 23.9755, 23.8403, 17.4892, 26.1404, 25.4976, 27.325, 17.3204, 24.821, 23.705, 23.8064, 23.7726, 23.8741, 23.7388, 28.8824, 26.4111, 25.8359, 24.5166, 23.7726),)
# XXXXXXXXXXXXXXXXXX COP with kW is: 0.2355300866620654
# electricity in khW is: 0.005043570200000001
# cop is: 1.1743400166869773
# Load in kWh is: 2.5588893813321045e-05
# heat addition in kwh is: 0.005922866312829942
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    21.281714
# dtype: float64
# Availability :Total energy of in Kj is : 40652.82327739099
# Charging stratified Efficiency: 0    56.426608
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6300192266609699 0.003951945970775122 -0.25497039150178974
# flow rates HP is =  1.4300436414685507 0.008957366999489826 939.6136102612215
# result is ((6043, datetime.datetime(2021, 5, 12, 12, 23, 43), 23.7388, 24.7196, 23.8064, 17.4217, 26.1404, 25.5652, 27.325, 17.1517, 24.821, 23.705, 23.8064, 23.7388, 23.8403, 23.705, 29.0179, 26.648, 26.0728, 24.6181, 23.8741),)
# XXXXXXXXXXXXXXXXXX COP with kW is: 1.0113374873915306
# electricity in khW is: 0.00639563408888889
# cop is: 1.1398805978717563
# Load in kWh is: 2.528727834654239e-05
# heat addition in kwh is: 0.007290259209011653
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    26.197641
# dtype: float64
# Availability :Total energy of in Kj is : 40764.602079577875
# Charging stratified Efficiency: 0    7.711263
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6400195318460646 0.004014675271898536 3.6902686728639007
# flow rates HP is =  1.4380438856166264 0.009007478143542915 949.061623768516
# result is ((6046, datetime.datetime(2021, 5, 12, 12, 23, 48), 23.705, 26.5465, 23.8403, 17.3879, 26.1404, 25.7006, 27.325, 16.9492, 24.7872, 23.6712, 23.8403, 23.7726, 23.8403, 23.705, 29.1533, 26.7834, 26.1404, 24.7196, 23.8403),)
# XXXXXXXXXXXXXXXXXX COP with kW is: 2.2723856033237007
# electricity in khW is: 0.008557117422222224
# cop is: 1.330280006036324
# Load in kWh is: 3.064415440106173e-05
# heat addition in kwh is: 0.011383362216087312
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    40.874483
# dtype: float64
# Availability :Total energy of in Kj is : 40833.706814866506
# Charging stratified Efficiency: 0   -53.965918
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6320192876979889 0.003964491830999805 0.5340774213713702
# flow rates HP is =  1.4380438856166264 0.009007478143542915 949.061623768516
# result is ((6050, datetime.datetime(2021, 5, 12, 12, 23, 55), 23.7388, 29.2888, 23.8403, 17.3542, 26.1066, 25.8359, 27.2911, 16.4768, 24.6857, 23.705, 23.8403, 23.7726, 23.8403, 23.6712, 29.2211, 26.9188, 26.2081, 25.024, 23.8741),)
# XXXXXXXXXXXXXXXXXX COP with kW is: 4.187058790224267
# electricity in khW is: 0.010918800755555558
# cop is: 2.0991273843339937
# Load in kWh is: 3.2010672179607e-05
# heat addition in kwh is: 0.02291995367007337
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    82.082301
# dtype: float64
# Availability :Total energy of in Kj is : 40929.67397412836
# Charging stratified Efficiency: 0   -68.834007
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6320192876979889 0.003964491830999805 0.5340774213713702
# flow rates HP is =  1.4340437635425884 0.00898242257151637 944.3376170148686
# result is ((6053, datetime.datetime(2021, 5, 12, 12, 24), 23.7388, 30.6777, 23.8403, 17.3204, 26.1066, 25.9374, 27.2911, 15.8021, 24.6519, 23.705, 23.8064, 23.7726, 23.8403, 23.705, 29.3565, 27.1557, 26.2419, 25.1255, 23.8064),)
# XXXXXXXXXXXXXXXXXX COP with kW is: 5.435738089916213
# electricity in khW is: 0.01319033408888889
# cop is: 2.517715143910565
# Load in kWh is: 3.310141928554776e-05
# heat addition in kwh is: 0.033209503888835326
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    118.761984
# dtype: float64
# Availability :Total energy of in Kj is : 40998.56889520461
# Charging stratified Efficiency: 0   -58.777767
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6380194708090458 0.004002129411673854 2.9012208599907954
# flow rates HP is =  1.4360438245796074 0.008994950357529643 946.6996203916924
# result is ((6057, datetime.datetime(2021, 5, 12, 12, 24, 7), 23.705, 30.034, 23.8064, 17.2867, 26.1066, 26.0728, 27.2573, 15.0937, 24.6181, 23.705, 23.8403, 23.7726, 23.8403, 23.705, 29.3904, 27.4604, 26.5127, 25.1931, 23.8741),)
# XXXXXXXXXXXXXXXXXX COP with kW is: 5.1428356307179195
# electricity in khW is: 0.01538268408888889
# cop is: 3.0140090375924364
# Load in kWh is: 4.248670724239406e-05
# heat addition in kwh is: 0.04636354886634049
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    165.694503
# dtype: float64
# Availability :Total energy of in Kj is : 41121.027770996356
# Charging stratified Efficiency: 0   -37.87571
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  1.4340437635425884 0.00898242257151637 944.3376170148686
# result is ((6060, datetime.datetime(2021, 5, 12, 12, 24, 12), 23.7388, 28.9501, 23.8403, 17.2529, 26.0728, 26.1066, 27.2911, 15.0263, 24.5843, 23.705, 23.8403, 23.7388, 23.8403, 23.7388, 29.3227, 27.6973, 26.9188, 25.2608, 23.8064),)
# XXXXXXXXXXXXXXXXXX COP with kW is: 4.181551175609084
# electricity in khW is: 0.01758943408888889
# cop is: 3.073052093309337
# Load in kWh is: 4.568595286126906e-05
# heat addition in kwh is: 0.05405324724698661
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    193.174899
# dtype: float64
# Availability :Total energy of in Kj is : 41211.37436383827
# Charging stratified Efficiency: 0   -24.392536
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6320192876979889 0.003964491830999805 0.5340774213713702
# flow rates HP is =  1.4320437025055697 0.008969894785503097 941.975613638045
# result is ((6064, datetime.datetime(2021, 5, 12, 12, 24, 19), 23.7388, 28.1036, 23.8403, 17.2529, 26.0728, 26.2081, 27.2911, 15.06, 24.5504, 23.705, 23.8064, 23.7388, 23.8403, 23.7388, 29.3565, 28.0697, 27.4265, 25.1931, 23.9079),)
# XXXXXXXXXXXXXXXXXX COP with kW is: 3.4399347578386603
# electricity in khW is: 0.020194036866666668
# cop is: 3.1203721815839565
# Load in kWh is: 4.765438587700846e-05
# heat addition in kwh is: 0.06301291087262752
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    225.232567
# dtype: float64
# Availability :Total energy of in Kj is : 41354.63810945538
# Charging stratified Efficiency: 0   -15.905376
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  1.4320437025055697 0.008969894785503097 941.975613638045
# result is ((6068, datetime.datetime(2021, 5, 12, 12, 24, 26), 23.7388, 27.6635, 23.8403, 17.2192, 26.0728, 26.3096, 27.2573, 15.1612, 24.5166, 23.705, 23.8741, 23.7388, 23.8741, 23.705, 29.3227, 28.3744, 27.765, 24.9902, 23.7726),)
# XXXXXXXXXXXXXXXXXX COP with kW is: 3.0576441976468587
# electricity in khW is: 0.022446403533333333
# cop is: 3.1652139409019955
# Load in kWh is: 5.29282818314829e-05
# heat addition in kwh is: 0.07104766938681847
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    253.998966
# dtype: float64
# Availability :Total energy of in Kj is : 41407.29700707705
# Charging stratified Efficiency: 0   -11.639279
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6320192876979889 0.003964491830999805 0.5340774213713702
# flow rates HP is =  1.4340437635425884 0.00898242257151637 944.3376170148686
# result is ((6072, datetime.datetime(2021, 5, 12, 12, 24, 32), 23.7388, 27.3588, 23.8403, 17.1854, 26.0728, 26.3435, 27.2573, 15.1612, 24.4828, 23.705, 23.8064, 23.7388, 23.8064, 23.705, 29.2888, 28.5099, 27.7989, 24.8887, 23.8741),)
# XXXXXXXXXXXXXXXXXX COP with kW is: 2.813393759578955
# electricity in khW is: 0.02508128131111111
# cop is: 3.086031548904414
# Load in kWh is: 5.482176501087467e-05
# heat addition in kwh is: 0.07740162541303555
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    276.757537
# dtype: float64
# Availability :Total energy of in Kj is : 41407.084445691886
# Charging stratified Efficiency: 0   -9.429056
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6320192876979889 0.003964491830999805 0.5340774213713702
# flow rates HP is =  1.4340437635425884 0.00898242257151637 944.3376170148686
# result is ((6075, datetime.datetime(2021, 5, 12, 12, 24, 38), 23.7388, 27.325, 23.8403, 17.1854, 26.0389, 26.445, 27.2234, 15.1949, 24.4828, 23.705, 23.8403, 23.7726, 23.8403, 23.705, 29.1872, 28.476, 27.9343, 24.821, 23.9079),)
# XXXXXXXXXXXXXXXXXX COP with kW is: 2.7885485872565794
# electricity in khW is: 0.026961864644444444
# cop is: 3.10418230020834
# Load in kWh is: 5.681825080714932e-05
# heat addition in kwh is: 0.08369454300989748
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    299.298563
# dtype: float64
# Availability :Total energy of in Kj is : 41417.91966266778
# Charging stratified Efficiency: 0   -8.592618
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6300192266609699 0.003951945970775122 -0.25497039150178974
# flow rates HP is =  1.4360438245796074 0.008994950357529643 946.6996203916924
# result is ((6079, datetime.datetime(2021, 5, 12, 12, 24, 44), 23.7388, 27.325, 23.8403, 17.1854, 26.0389, 26.5127, 27.2234, 15.1612, 24.4152, 23.705, 23.8403, 23.7388, 23.8064, 23.705, 29.1195, 28.5099, 28.002, 24.821, 23.8741),)
# XXXXXXXXXXXXXXXXXX COP with kW is: 2.8158621619307245
# electricity in khW is: 0.029575664644444444
# cop is: 3.04315056582823
# Load in kWh is: 5.5799498377873786e-05
# heat addition in kwh is: 0.09000320059748708
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    321.89597
# dtype: float64
# Availability :Total energy of in Kj is : 41407.16188359991
# Charging stratified Efficiency: 0   -7.934242
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  1.4360438245796074 0.008994950357529643 946.6996203916924
# result is ((6082, datetime.datetime(2021, 5, 12, 12, 24, 50), 23.705, 27.3588, 23.8064, 17.1179, 26.0389, 26.5465, 27.2234, 15.1275, 24.4152, 23.705, 23.8403, 23.7388, 23.8403, 23.705, 28.984, 28.5099, 28.002, 24.8887, 23.9755),)
# XXXXXXXXXXXXXXXXXX COP with kW is: 2.8905928369036125
# electricity in khW is: 0.03142981742222222
# cop is: 3.06825585995504
# Load in kWh is: 6.117110240787394e-05
# heat addition in kwh is: 0.09643472148305034
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    344.931288
# dtype: float64
# Availability :Total energy of in Kj is : 41418.179380025605
# Charging stratified Efficiency: 0   -7.318114
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6360194097720268 0.003989583551449171 2.1121730471176354
# flow rates HP is =  1.4340437635425884 0.00898242257151637 944.3376170148686
# result is ((6085, datetime.datetime(2021, 5, 12, 12, 24, 55), 23.7388, 27.4265, 23.8403, 17.1179, 26.0051, 26.5803, 27.2573, 15.0937, 24.3813, 23.6712, 23.8064, 23.7726, 23.8403, 23.705, 28.8485, 28.476, 28.1036, 25.3623, 24.0432),)
# XXXXXXXXXXXXXXXXXX COP with kW is: 2.924062430917694
# electricity in khW is: 0.033644617422222224
# cop is: 3.026682240582941
# Load in kWh is: 6.854350465781864e-05
# heat addition in kwh is: 0.10183156604304743
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    364.259823
# dtype: float64
# Availability :Total energy of in Kj is : 41487.786922113955
# Charging stratified Efficiency: 0   -7.004033
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  1.4360438245796074 0.008994950357529643 946.6996203916924
# result is ((6088, datetime.datetime(2021, 5, 12, 12, 25), 23.705, 27.4265, 23.8741, 17.1179, 26.0389, 26.648, 27.2573, 15.06, 24.4152, 23.7388, 23.8064, 23.7388, 23.8403, 23.7388, 28.7808, 28.4083, 28.239, 25.8021, 24.1108),)
# XXXXXXXXXXXXXXXXXX COP with kW is: 2.908983853859981
# electricity in khW is: 0.03548704797777778
# cop is: 3.0205715293123454
# Load in kWh is: 7.323234826134002e-05
# heat addition in kwh is: 0.10719116678101681
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    383.454076
# dtype: float64
# Availability :Total energy of in Kj is : 41578.61311861019
# Charging stratified Efficiency: 0   -6.188281
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  1.4340437635425884 0.00898242257151637 944.3376170148686
# result is ((6091, datetime.datetime(2021, 5, 12, 12, 25, 5), 23.7388, 27.4942, 23.8741, 17.1179, 26.0051, 26.648, 27.2234, 15.0263, 24.3813, 23.7726, 23.8403, 23.7726, 23.8403, 23.705, 28.7131, 28.3744, 28.1713, 26.2081, 24.1446),)
# XXXXXXXXXXXXXXXXXX COP with kW is: 2.940550777447269
# electricity in khW is: 0.03733971464444445
# cop is: 3.0166011781451307
# Load in kWh is: 7.79923813122635e-05
# heat addition in kwh is: 0.11263902718803412
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    402.963445
# dtype: float64
# Availability :Total energy of in Kj is : 41632.19174559417
# Charging stratified Efficiency: 0   -5.890453
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6320192876979889 0.003964491830999805 0.5340774213713702
# flow rates HP is =  1.4340437635425884 0.00898242257151637 944.3376170148686
# result is ((6095, datetime.datetime(2021, 5, 12, 12, 25, 12), 23.7388, 27.4942, 23.8403, 17.0842, 26.0051, 26.7157, 27.2234, 15.0263, 24.3813, 23.8403, 23.8064, 23.7726, 23.8403, 23.705, 28.6115, 28.3744, 28.239, 26.5127, 24.3137),)
# XXXXXXXXXXXXXXXXXX COP with kW is: 2.9711020019553462
# electricity in khW is: 0.039930745200000006
# cop is: 3.0136488226313567
# Load in kWh is: 8.076237675660459e-05
# heat addition in kwh is: 0.12033724325877271
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    430.531577
# dtype: float64
# Availability :Total energy of in Kj is : 41706.97478303384
# Charging stratified Efficiency: 0   -5.489049
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6320192876979889 0.003964491830999805 0.5340774213713702
# flow rates HP is =  1.4360438245796074 0.008994950357529643 946.6996203916924
# result is ((6099, datetime.datetime(2021, 5, 12, 12, 25, 19), 23.7388, 27.4942, 23.8403, 17.0842, 25.9712, 26.7834, 27.1557, 14.9588, 24.3137, 23.8741, 23.8064, 23.7726, 23.8403, 23.705, 28.5438, 28.3744, 28.2052, 26.9188, 24.3475),)
# XXXXXXXXXXXXXXXXXX COP with kW is: 2.9621281274959115
# electricity in khW is: 0.04216392853333334
# cop is: 3.037067909456756
# Load in kWh is: 8.369263855135221e-05
# heat addition in kwh is: 0.12805471428521475
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    458.168664
# dtype: float64
# Availability :Total energy of in Kj is : 41765.64016248506
# Charging stratified Efficiency: 0   -4.933597
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.626019104586932 0.003926854250325756 -1.833066017248055
# flow rates HP is =  1.4320437025055697 0.008969894785503097 941.975613638045
# result is ((6102, datetime.datetime(2021, 5, 12, 12, 25, 24), 23.7388, 27.5281, 23.8741, 17.0167, 26.0051, 26.8172, 27.1557, 14.9926, 24.3137, 23.8741, 23.8403, 23.7726, 23.8403, 23.7388, 28.476, 28.3406, 28.1374, 27.088, 24.2461),)
# XXXXXXXXXXXXXXXXXX COP with kW is: 2.9484400935058424
# electricity in khW is: 0.044396345200000006
# cop is: 3.0079015743633097
# Load in kWh is: 7.64108812749919e-05
# heat addition in kwh is: 0.133539836623057
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    477.810525
# dtype: float64
# Availability :Total energy of in Kj is : 41760.40419061114
# Charging stratified Efficiency: 0   -4.843206
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6320192876979889 0.003964491830999805 0.5340774213713702
# flow rates HP is =  1.4320437025055697 0.008969894785503097 941.975613638045
# result is ((6106, datetime.datetime(2021, 5, 12, 12, 25, 31), 23.705, 27.5619, 23.8403, 17.0167, 25.9712, 26.8511, 27.1219, 14.9251, 24.2799, 23.8741, 23.8403, 23.7726, 23.8403, 23.705, 28.3744, 28.239, 28.1374, 27.2911, 24.4152),)
# XXXXXXXXXXXXXXXXXX COP with kW is: 2.9991192202103787
# electricity in khW is: 0.046631745200000005
# cop is: 3.0314421854133173
# Load in kWh is: 7.946127922127128e-05
# heat addition in kwh is: 0.141361439578725
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    505.816517
# dtype: float64
# Availability :Total energy of in Kj is : 41781.91914715808
# Charging stratified Efficiency: 0   -4.540243
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6360194097720268 0.003989583551449171 2.1121730471176354
# flow rates HP is =  1.4360438245796074 0.008994950357529643 946.6996203916924
# result is ((6110, datetime.datetime(2021, 5, 12, 12, 25, 38), 23.705, 27.5619, 23.8064, 16.9829, 25.9712, 26.8849, 27.1219, 14.8914, 24.3137, 23.9079, 23.7726, 23.7726, 23.8403, 23.705, 28.4083, 28.2052, 28.0697, 27.4265, 24.3813),)
# XXXXXXXXXXXXXXXXXX COP with kW is: 3.0582151297627225
# electricity in khW is: 0.04922555631111111
# cop is: 3.032852915240153
# Load in kWh is: 9.152442918287175e-05
# heat addition in kwh is: 0.14929387196247165
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    534.219344
# dtype: float64
# Availability :Total energy of in Kj is : 41781.83063974677
# Charging stratified Efficiency: 0   -4.284288
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  1.4320437025055697 0.008969894785503097 941.975613638045
# result is ((6113, datetime.datetime(2021, 5, 12, 12, 25, 43), 23.7388, 27.5958, 23.8741, 16.9829, 25.9374, 26.9188, 27.1557, 14.8914, 24.2461, 23.9079, 23.8741, 23.7726, 23.8403, 23.705, 28.3744, 28.2052, 28.0359, 27.5619, 24.449),)
# XXXXXXXXXXXXXXXXXX COP with kW is: 3.0276378350020896
# electricity in khW is: 0.051439856311111115
# cop is: 3.010906946177739
# Load in kWh is: 9.713490710476987e-05
# heat addition in kwh is: 0.15488062067750927
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    554.223197
# dtype: float64
# Availability :Total energy of in Kj is : 41819.27868184457
# Charging stratified Efficiency: 0   -4.022432
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  1.4340437635425884 0.00898242257151637 944.3376170148686
# result is ((6116, datetime.datetime(2021, 5, 12, 12, 25, 48), 23.705, 27.6296, 23.8403, 16.9492, 25.9374, 26.9526, 27.1219, 14.8577, 24.2461, 23.9079, 23.8741, 23.7726, 23.8403, 23.7388, 28.3067, 28.2052, 28.0359, 27.6973, 24.7196),)
# XXXXXXXXXXXXXXXXXX COP with kW is: 3.0947677015027053
# electricity in khW is: 0.05328256464444445
# cop is: 3.0138071615428994
# Load in kWh is: 0.00010281606549270708
# heat addition in kwh is: 0.16058337491079916
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    574.640483
# dtype: float64
# Availability :Total energy of in Kj is : 41878.08098581251
# Charging stratified Efficiency: 0   -3.915807
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6360194097720268 0.003989583551449171 2.1121730471176354
# flow rates HP is =  1.4360438245796074 0.008994950357529643 946.6996203916924
# result is ((6120, datetime.datetime(2021, 5, 12, 12, 25, 55), 23.705, 27.6296, 23.8741, 16.9492, 25.9036, 26.9865, 27.1557, 14.8239, 24.2461, 23.9417, 23.8403, 23.8064, 23.8403, 23.705, 28.239, 28.1374, 28.0697, 27.5958, 25.1931),)
# XXXXXXXXXXXXXXXXXX COP with kW is: 3.0781289599558463
# electricity in khW is: 0.0558595952
# cop is: 3.0167745879860193
# Load in kWh is: 0.00011567119241536882
# heat addition in kwh is: 0.16851580729454582
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    603.040575
# dtype: float64
# Availability :Total energy of in Kj is : 41921.095320723114
# Charging stratified Efficiency: 0   -3.524848
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6380194708090458 0.004002129411673854 2.9012208599907954
# flow rates HP is =  1.4360438245796074 0.008994950357529643 946.6996203916924
# result is ((6124, datetime.datetime(2021, 5, 12, 12, 26, 2), 23.7388, 27.6296, 23.8403, 16.9155, 25.9036, 26.9865, 27.1557, 14.8239, 24.2461, 23.9417, 23.8741, 23.7726, 23.8403, 23.705, 28.2052, 28.1374, 28.0359, 27.7312, 25.4976),)
# XXXXXXXXXXXXXXXXXX COP with kW is: 3.1069769969521834
# electricity in khW is: 0.058067561866666666
# cop is: 3.0398944528983445
# Load in kWh is: 0.0001333286495947458
# heat addition in kwh is: 0.17651925921181144
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    631.696271
# dtype: float64
# Availability :Total energy of in Kj is : 41979.790067542475
# Charging stratified Efficiency: 0   -3.197892
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6380194708090458 0.004002129411673854 2.9012208599907954
# flow rates HP is =  1.4360438245796074 0.008994950357529643 946.6996203916924
# result is ((6128, datetime.datetime(2021, 5, 12, 12, 26, 8), 23.705, 27.6296, 23.8403, 16.8817, 25.9036, 26.9865, 27.1219, 14.7565, 24.2122, 23.9417, 23.8741, 23.7726, 23.8403, 23.705, 28.1036, 28.0697, 27.9343, 27.6973, 25.7682),)
# XXXXXXXXXXXXXXXXXX COP with kW is: 3.1070515979879216
# electricity in khW is: 0.06064358131111111
# cop is: 3.0238926686007455
# Load in kWh is: 0.00014865083930200822
# heat addition in kwh is: 0.18337968092436208
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    656.258297
# dtype: float64
# Availability :Total energy of in Kj is : 41974.76373179264
# Charging stratified Efficiency: 0   -3.011715
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6380194708090458 0.004002129411673854 2.9012208599907954
# flow rates HP is =  1.4340437635425884 0.00898242257151637 944.3376170148686
# result is ((6132, datetime.datetime(2021, 5, 12, 12, 26, 15), 23.705, 27.6296, 23.8741, 16.8817, 25.8697, 27.0203, 27.1219, 14.7228, 24.2461, 23.9417, 23.8741, 23.7726, 23.8403, 23.705, 28.1036, 28.0697, 27.9343, 27.7312, 26.0051),)
# XXXXXXXXXXXXXXXXXX COP with kW is: 3.0694763580218027
# electricity in khW is: 0.06285316464444445
# cop is: 3.0434795624005795
# Load in kWh is: 0.00016652522732870745
# heat addition in kwh is: 0.19129232202756535
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    684.587531
# dtype: float64
# Availability :Total energy of in Kj is : 42017.39902460463
# Charging stratified Efficiency: 0   -2.961912
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6300192266609699 0.003951945970775122 -0.25497039150178974
# flow rates HP is =  1.4340437635425884 0.00898242257151637 944.3376170148686
# result is ((6135, datetime.datetime(2021, 5, 12, 12, 26, 20), 23.705, 27.6635, 23.8741, 16.848, 25.9036, 27.0203, 27.1219, 14.689, 24.1784, 23.9755, 23.8403, 23.7726, 23.8403, 23.7388, 28.002, 28.002, 27.9004, 27.7312, 26.2081),)
# XXXXXXXXXXXXXXXXXX COP with kW is: 3.108155817076706
# electricity in khW is: 0.06505494797777778
# cop is: 3.0281359509255577
# Load in kWh is: 0.0001653757971597257
# heat addition in kwh is: 0.1969952267571008
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    705.004371
# dtype: float64
# Availability :Total energy of in Kj is : 42022.92243519786
# Charging stratified Efficiency: 0   -2.752912
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6300192266609699 0.003951945970775122 -0.25497039150178974
# flow rates HP is =  1.4340437635425884 0.00898242257151637 944.3376170148686
# result is ((6139, datetime.datetime(2021, 5, 12, 12, 26, 27), 23.7388, 27.6635, 23.8403, 16.8142, 25.8697, 27.0542, 27.1219, 14.689, 24.1784, 24.0093, 23.8741, 23.8064, 23.8741, 23.705, 28.002, 28.002, 27.9343, 27.765, 26.5465),)
# XXXXXXXXXXXXXXXXXX COP with kW is: 3.1331953465256475
# electricity in khW is: 0.06725851464444445
# cop is: 3.0486866008137476
# Load in kWh is: 0.00016374747752641262
# heat addition in kwh is: 0.205050132387153
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    733.842902
# dtype: float64
# Availability :Total energy of in Kj is : 42102.83191737969
# Charging stratified Efficiency: 0   -2.608415
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6360194097720268 0.003989583551449171 2.1121730471176354
# flow rates HP is =  1.4380438856166264 0.009007478143542915 949.061623768516
# result is ((6142, datetime.datetime(2021, 5, 12, 12, 26, 32), 23.7388, 27.6635, 23.8741, 16.7467, 25.8697, 27.0203, 27.0542, 14.6553, 24.1446, 24.1784, 23.9079, 23.7726, 23.8403, 23.705, 28.002, 27.9682, 27.9343, 27.7312, 26.7834),)
# XXXXXXXXXXXXXXXXXX COP with kW is: 3.07782455486796
# electricity in khW is: 0.06986543131111111
# cop is: 3.016961238743185
# Load in kWh is: 0.00017338259830778537
# heat addition in kwh is: 0.2107812981936967
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    754.361876
# dtype: float64
# Availability :Total energy of in Kj is : 42150.912799759826
# Charging stratified Efficiency: 0   -2.49406
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6320192876979889 0.003964491830999805 0.5340774213713702
# flow rates HP is =  1.4380438856166264 0.009007478143542915 949.061623768516
# result is ((6146, datetime.datetime(2021, 5, 12, 12, 26, 39), 23.705, 27.7312, 23.8403, 16.7467, 25.8697, 27.0203, 27.088, 14.5879, 24.1446, 24.3813, 23.9079, 23.7726, 23.8403, 23.7388, 27.9343, 27.9343, 27.8666, 27.6973, 26.9865),)
# XXXXXXXXXXXXXXXXXX COP with kW is: 3.112427000020127
# electricity in khW is: 0.07213438131111112
# cop is: 3.0362806980726837
# Load in kWh is: 0.00017679342933093906
# heat addition in kwh is: 0.21902022964234164
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    783.855046
# dtype: float64
# Availability :Total energy of in Kj is : 42188.49128475138
# Charging stratified Efficiency: 0   -2.392322
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6360194097720268 0.003989583551449171 2.1121730471176354
# flow rates HP is =  1.4360438245796074 0.008994950357529643 946.6996203916924
# result is ((6149, datetime.datetime(2021, 5, 12, 12, 26, 45), 23.705, 27.7989, 23.8741, 16.713, 25.8359, 27.0542, 27.0542, 14.5204, 24.1784, 24.4828, 23.9079, 23.7726, 23.8741, 23.7388, 27.8666, 27.9004, 27.7989, 27.6973, 27.088),)
# XXXXXXXXXXXXXXXXXX COP with kW is: 3.067204124162063
# electricity in khW is: 0.07445106464444445
# cop is: 3.0372429379838652
# Load in kWh is: 0.00018835542109432265
# heat addition in kwh is: 0.22612597031671916
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    809.289243
# dtype: float64
# Availability :Total energy of in Kj is : 42199.34335899895
# Charging stratified Efficiency: 0   -2.294933
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  1.4320437025055697 0.008969894785503097 941.975613638045
# result is ((6153, datetime.datetime(2021, 5, 12, 12, 26, 51), 23.7388, 27.8327, 23.9079, 16.713, 25.8359, 27.0542, 27.0542, 14.453, 24.1784, 24.6857, 23.9417, 23.7726, 23.8403, 23.705, 27.9343, 27.9343, 27.8666, 27.6973, 27.2573),)
# XXXXXXXXXXXXXXXXXX COP with kW is: 3.0371390059204497
# electricity in khW is: 0.07639092575555556
# cop is: 3.052665240356881
# Load in kWh is: 0.00019559821791554716
# heat addition in kwh is: 0.23319592373266765
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    834.595306
# dtype: float64
# Availability :Total energy of in Kj is : 42279.15110151288
# Charging stratified Efficiency: 0   -2.224091
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6360194097720268 0.003989583551449171 2.1121730471176354
# flow rates HP is =  1.4340437635425884 0.00898242257151637 944.3376170148686
# result is ((6156, datetime.datetime(2021, 5, 12, 12, 26, 56), 23.7388, 27.8666, 23.8403, 16.6793, 25.8359, 27.0542, 27.0542, 14.4193, 24.1446, 25.0916, 23.9755, 23.7726, 23.8403, 23.705, 27.9004, 27.9343, 27.8666, 27.6296, 27.3588),)
# XXXXXXXXXXXXXXXXXX COP with kW is: 3.0617004104586165
# electricity in khW is: 0.0791615452
# cop is: 3.022364846013416
# Load in kWh is: 0.0002053464535470065
# heat addition in kwh is: 0.23925507136858207
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    856.282261
# dtype: float64
# Availability :Total energy of in Kj is : 42348.66803558877
# Charging stratified Efficiency: 0   -2.131133
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6320192876979889 0.003964491830999805 0.5340774213713702
# flow rates HP is =  1.4320437025055697 0.008969894785503097 941.975613638045
# result is ((6160, datetime.datetime(2021, 5, 12, 12, 27, 3), 23.7388, 27.9343, 23.8403, 16.6793, 25.8359, 27.0542, 27.0542, 14.3518, 24.1446, 25.4976, 24.1108, 23.7726, 23.8741, 23.705, 27.7989, 27.9004, 27.8327, 27.6296, 27.3927),)
# XXXXXXXXXXXXXXXXXX COP with kW is: 3.061668295858552
# electricity in khW is: 0.08116882297777778
# cop is: 3.0536224193238017
# Load in kWh is: 0.00020879732720674037
# heat addition in kwh is: 0.24785893759506716
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    887.074324
# dtype: float64
# Availability :Total energy of in Kj is : 42418.36371643996
# Charging stratified Efficiency: 0   -2.048061
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6420195928830836 0.00402722113212322 4.479316485737061
# flow rates HP is =  1.4360438245796074 0.008994950357529643 946.6996203916924
# result is ((6163, datetime.datetime(2021, 5, 12, 12, 27, 8), 23.7388, 28.002, 23.8741, 16.6455, 25.8021, 27.0542, 27.0203, 14.3518, 24.1108, 25.7006, 24.1446, 23.8064, 23.8741, 23.7388, 27.7989, 27.8666, 27.7989, 27.6973, 27.4604),)
# XXXXXXXXXXXXXXXXXX COP with kW is: 3.048398810278174
# electricity in khW is: 0.08402888686666667
# cop is: 3.0237996654118744
# Load in kWh is: 0.00022971075567262332
# heat addition in kwh is: 0.25408651999235893
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    909.359839
# dtype: float64
# Availability :Total energy of in Kj is : 42477.089696671406
# Charging stratified Efficiency: 0   -2.05053
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6360194097720268 0.003989583551449171 2.1121730471176354
# flow rates HP is =  1.4380438856166264 0.009007478143542915 949.061623768516
# result is ((6167, datetime.datetime(2021, 5, 12, 12, 27, 15), 23.705, 28.0359, 23.8403, 16.6118, 25.8021, 27.0542, 27.0203, 14.2844, 24.1446, 25.9712, 24.2122, 23.7726, 23.8403, 23.705, 27.765, 27.9004, 27.765, 27.6973, 27.5619),)
# XXXXXXXXXXXXXXXXXX COP with kW is: 3.067294847839738
# electricity in khW is: 0.08609774797777778
# cop is: 3.0543266927033073
# Load in kWh is: 0.0002433582855566664
# heat addition in kwh is: 0.2629706498301689
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    941.148835
# dtype: float64
# Availability :Total energy of in Kj is : 42524.9412203793
# Charging stratified Efficiency: 0   -1.933247
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6400195318460646 0.004014675271898536 3.6902686728639007
# flow rates HP is =  1.4360438245796074 0.008994950357529643 946.6996203916924
# result is ((6170, datetime.datetime(2021, 5, 12, 12, 27, 20), 23.705, 28.0697, 23.8403, 16.578, 25.8021, 27.088, 27.0203, 14.2507, 24.1108, 26.3096, 24.2461, 23.7726, 23.8741, 23.705, 27.7989, 27.9004, 27.8666, 27.6635, 27.5619),)
# XXXXXXXXXXXXXXXXXX COP with kW is: 3.0410494484307384
# electricity in khW is: 0.0890353563111111
# cop is: 3.025221324487683
# Load in kWh is: 0.0002607847471739357
# heat addition in kwh is: 0.26935165854573234
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    963.980118
# dtype: float64
# Availability :Total energy of in Kj is : 42604.86740415013
# Charging stratified Efficiency: 0   -1.811187
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  1.4340437635425884 0.00898242257151637 944.3376170148686
# result is ((6174, datetime.datetime(2021, 5, 12, 12, 27, 27), 23.7388, 28.1036, 23.8403, 16.5443, 25.7682, 27.088, 27.0203, 14.1832, 24.1108, 26.5465, 24.2799, 23.8403, 23.8403, 23.7388, 27.7312, 27.9004, 27.8327, 27.6635, 27.5619),)
# XXXXXXXXXXXXXXXXXX COP with kW is: 3.0137274169260406
# electricity in khW is: 0.09116421742222222
# cop is: 3.0531034692370658
# Load in kWh is: 0.0002695322002934962
# heat addition in kwh is: 0.2783337884820688
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    996.11817
# dtype: float64
# Availability :Total energy of in Kj is : 42642.30853070329
# Charging stratified Efficiency: 0   -1.729255
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6380194708090458 0.004002129411673854 2.9012208599907954
# flow rates HP is =  1.4360438245796074 0.008994950357529643 946.6996203916924
# result is ((6177, datetime.datetime(2021, 5, 12, 12, 27, 32), 23.7388, 28.1713, 23.8741, 16.5443, 25.8021, 27.0542, 26.9865, 14.1495, 24.0432, 26.6819, 24.3137, 23.8403, 23.8741, 23.705, 27.765, 27.8666, 27.7989, 27.6973, 27.5958),)
# ...
# Load in kWh is: 3.1171715893554413
# Discharging: load_kJ_total mul 3600: 11221.817721679588
# Availability :Total energy of in Kj is : 218761.90155536402
# Discharge: strat efficiency sum_float : 0.8273710856960106
# ________________________________________________________________
# flow rates load is =  1.6520504165776544 0.010362880545588097 402.9484619866727
# flow rates HP is =  0.6320192876979889 0.003958780380194105 -2.825737091414544
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# result is ((8878, datetime.datetime(2021, 5, 12, 13, 44, 51), 22.995, 46.4707, 26.3773, 16.578, 21.17, 52.7406, 35.5265, 14.4193, 21.0348, 50.4902, 47.9008, 26.8172, 23.5021, 23.3669, -242.02, 52.4677, 52.4336, 52.229, 51.7175),)
# XXXXXXXXXXXXXXXXXX COP with kW is: -10.84475747311404
# electricity in khW is: 3.010840561941668
# cop is: 1.886403654623754
# Load in kWh is: 3.139199647289863
# heat addition in kwh is: 5.679660639536199
# OK ok oK oK ok if not small run
# Total sum discharge in kJ is : 0    10746.04761
# dtype: float64
# type of nDis now is  0.2298898083495044
# energy content of tank from the begineening of discharge in kJ, Inlet, mean, cp, p: 46744.341071254545 21.0348 50.728229999999996 4.014687359803263 987.7031464493151
# energy/sec discharged from tank in kJ/sec: 0    10746.04761
# dtype: float64
# discharge efficiency is: 0.2298898083495044
# liters discharged is : 91.01397741222232
# Load in kWh is: 3.1366513461763086
# Discharging: load_kJ_total mul 3600: 11291.944846234712
# Availability :Total energy of in Kj is : 218660.8377150312
# Discharge: strat efficiency sum_float : 0.8298458449395216
# ________________________________________________________________
# flow rates load is =  1.6560505386516924 0.010387972266037463 404.5265576124191
# flow rates HP is =  0.6340193487350078 0.003971308166207377 -0.4637337145910134
# result is ((8881, datetime.datetime(2021, 5, 12, 13, 44, 56), 22.995, 46.4707, 26.3435, 16.6118, 21.17, 52.7406, 35.4926, 14.453, 21.0011, 50.4561, 47.8667, 26.7157, 23.4683, 23.3669, -242.02, 52.5359, 52.4677, 52.229, 51.7175),)
# XXXXXXXXXXXXXXXXXX COP with kW is: -1.927971081314761
# electricity in khW is: 3.0108498292916677
# cop is: 1.8863929030805873
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Load in kWh is: 3.158776523981162
# heat addition in kwh is: 5.679645750217199
# OK ok oK oK ok if not small run
# Total sum discharge in kJ is : 0    10813.090724
# dtype: float64
# type of nDis now is  0.2310618199852227
# energy content of tank from the begineening of discharge in kJ, Inlet, mean, cp, p: 46797.39268213619 21.0011 50.728229999999996 4.014687359803263 987.7031464493151
# energy/sec discharged from tank in kJ/sec: 0    10813.090724
# dtype: float64
# discharge efficiency is: 0.2310618199852227
# liters discharged is : 91.68818907888898
# Load in kWh is: 3.160143598205867
# Discharging: load_kJ_total mul 3600: 11376.516953541122
# Availability :Total energy of in Kj is : 218644.28867898177
# Discharge: strat efficiency sum_float : 0.8362681632007835
# ________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# flow rates load is =  1.6560505386516924 0.010387972266037463 404.5265576124191
# flow rates HP is =  0.6380194708090458 0.003996363738233922 4.260273039056376
# result is ((8885, datetime.datetime(2021, 5, 12, 13, 45, 3), 22.995, 46.4366, 26.2081, 16.6793, 21.2038, 52.8088, 35.5265, 14.5204, 21.0348, 50.4561, 47.5262, 26.6142, 23.4345, 23.3331, -242.02, 52.57, 52.4677, 52.2631, 51.7175),)
# XXXXXXXXXXXXXXXXXX COP with kW is: 17.09966277495132
# electricity in khW is: 3.0108610847666677
# cop is: 1.8864497747109583
# Load in kWh is: 3.1862108542758327
# heat addition in kwh is: 5.679838215044072
# OK ok oK oK ok if not small run
# Total sum discharge in kJ is : 0    10907.02969
# dtype: float64
# type of nDis now is  0.23333369217240643
# energy content of tank from the begineening of discharge in kJ, Inlet, mean, cp, p: 46744.341071254545 21.0348 50.728229999999996 4.014687359803263 987.7031464493151
# energy/sec discharged from tank in kJ/sec: 0    10907.02969
# dtype: float64
# discharge efficiency is: 0.23333369217240643
# liters discharged is : 92.47476935666676
# Load in kWh is: 3.187577928500538
# Discharging: load_kJ_total mul 3600: 11475.280542601937
# Availability :Total energy of in Kj is : 218577.6522594228
# Discharge: strat efficiency sum_float : 0.8338498260948944
# ________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# flow rates load is =  1.6540504776146734 0.010375426405812781 403.73750979954593
# flow rates HP is =  0.6380194708090458 0.003996363738233922 4.260273039056376
# result is ((8889, datetime.datetime(2021, 5, 12, 13, 45, 10), 23.0288, 46.3345, 26.0728, 16.7467, 21.17, 52.7406, 35.5265, 14.4867, 21.0348, 50.2857, 47.1516, 26.4788, 23.3669, 23.2993, -242.02, 52.5018, 52.4336, 52.2631, 51.6834),)
# XXXXXXXXXXXXXXXXXX COP with kW is: 18.64850961027431
# electricity in khW is: 3.0108714218805566
# cop is: 1.8865073232732361
# Load in kWh is: 3.213535981297386
# heat addition in kwh is: 5.680030986811771
# OK ok oK oK ok if not small run
# Total sum discharge in kJ is : 0    11000.600677
# dtype: float64
# type of nDis now is  0.2353354529079847
# energy content of tank from the begineening of discharge in kJ, Inlet, mean, cp, p: 46744.341071254545 21.0348 50.728229999999996 4.014687359803263 987.7031464493151
# energy/sec discharged from tank in kJ/sec: 0    11000.600677
# dtype: float64
# discharge efficiency is: 0.2353354529079847
# liters discharged is : 93.25981546777787
# Load in kWh is: 3.214903055522091
# Discharging: load_kJ_total mul 3600: 11573.650999879528
# Availability :Total energy of in Kj is : 218441.2670431696
# Discharge: strat efficiency sum_float : 0.8339637163230749
# ________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# flow rates load is =  1.6520504165776544 0.010362880545588097 402.9484619866727
# flow rates HP is =  0.6340193487350078 0.003971308166207377 -0.4637337145910134
# result is ((8893, datetime.datetime(2021, 5, 12, 13, 45, 16), 23.0288, 46.2324, 26.0051, 16.8142, 21.17, 52.7065, 35.4926, 14.4193, 21.0348, 50.3198, 46.8111, 26.3773, 23.3331, 23.2317, -242.02, 52.57, 52.4336, 52.2631, 51.6834),)
# XXXXXXXXXXXXXXXXXX COP with kW is: -1.9299621684215191
# electricity in khW is: 3.0108807252805567
# cop is: 1.8864955306631963
# Load in kWh is: 3.236887862594402
# heat addition in kwh is: 5.680013031601733
# OK ok oK oK ok if not small run
# Total sum discharge in kJ is : 0    11080.56839
# dtype: float64
# type of nDis now is  0.2370461992984413
# energy content of tank from the begineening of discharge in kJ, Inlet, mean, cp, p: 46744.341071254545 21.0348 50.728229999999996 4.014687359803263 987.7031464493151
# energy/sec discharged from tank in kJ/sec: 0    11080.56839
# dtype: float64
# discharge efficiency is: 0.2370461992984413
# liters discharged is : 93.93139546777788
# Load in kWh is: 3.238254936819107
# Discharging: load_kJ_total mul 3600: 11657.717772548785
# Availability :Total energy of in Kj is : 218374.0382459666
# Discharge: strat efficiency sum_float : 0.8374321041786035
# ________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# flow rates load is =  1.6520504165776544 0.010362880545588097 402.9484619866727
# flow rates HP is =  0.6340193487350078 0.003971308166207377 -0.4637337145910134
# result is ((8897, datetime.datetime(2021, 5, 12, 13, 45, 23), 22.995, 46.1643, 25.9036, 16.8817, 21.2038, 52.7406, 35.4926, 14.4193, 21.0348, 50.3198, 46.4707, 26.2419, 23.2993, 23.1979, -242.02, 52.5359, 52.4677, 52.2631, 51.6834),)
# XXXXXXXXXXXXXXXXXX COP with kW is: -1.4410958255454194
# electricity in khW is: 3.0108952859416678
# cop is: 1.8864794384628862
# Load in kWh is: 3.2641595221436166
# heat addition in kwh is: 5.679992048293789
# OK ok oK oK ok if not small run
# Total sum discharge in kJ is : 0    11173.956285
# dtype: float64
# type of nDis now is  0.23904404315975675
# energy content of tank from the begineening of discharge in kJ, Inlet, mean, cp, p: 46744.341071254545 21.0348 50.728229999999996 4.014687359803263 987.7031464493151
# energy/sec discharged from tank in kJ/sec: 0    11173.956285
# dtype: float64
# discharge efficiency is: 0.23904404315975675
# liters discharged is : 94.71490546777788
# Load in kWh is: 3.2655265963683218
# Discharging: load_kJ_total mul 3600: 11755.895746925959
# Availability :Total energy of in Kj is : 218292.08125836248
# Discharge: strat efficiency sum_float : 0.8385810874473343
# ________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# flow rates load is =  1.6540504776146734 0.010375426405812781 403.73750979954593
# flow rates HP is =  0.6320192876979889 0.003958780380194105 -2.825737091414544
# result is ((8901, datetime.datetime(2021, 5, 12, 13, 45, 30), 22.995, 46.1643, 25.7344, 16.9155, 21.2038, 52.8088, 35.4926, 14.4867, 21.0348, 50.2857, 46.0962, 26.1066, 23.2317, 23.164, -242.02, 52.57, 52.4677, 52.2631, 51.6834),)
# XXXXXXXXXXXXXXXXXX COP with kW is: -12.234432592184033
# electricity in khW is: 3.0109058241111124
# cop is: 1.8864300152751872
# Load in kWh is: 3.29154034380573
# heat addition in kwh is: 5.679863119770076
# OK ok oK oK ok if not small run
# Total sum discharge in kJ is : 0    11267.71203
# dtype: float64
# type of nDis now is  0.2410497564390118
# energy content of tank from the begineening of discharge in kJ, Inlet, mean, cp, p: 46744.341071254545 21.0348 50.728229999999996 4.014687359803263 987.7031464493151
# energy/sec discharged from tank in kJ/sec: 0    11267.71203
# dtype: float64
# discharge efficiency is: 0.2410497564390118
# liters discharged is : 95.499951578889
# Load in kWh is: 3.292907418030435
# Discharging: load_kJ_total mul 3600: 11854.466704909566
# Availability :Total energy of in Kj is : 218199.6256574069
# Discharge: strat efficiency sum_float : 0.8369871977598404
# ________________________________________________________________
# flow rates load is =  1.6500503555406356 0.010350334685363416 402.15941417379975
# flow rates HP is =  0.6340193487350078 0.003971308166207377 -0.4637337145910134
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# result is ((8904, datetime.datetime(2021, 5, 12, 13, 45, 35), 23.0288, 46.1302, 25.6667, 16.9829, 21.2376, 52.7406, 35.5265, 14.4867, 21.0348, 50.2857, 45.8239, 26.0051, 23.1979, 23.164, -242.02, 52.57, 52.4336, 52.229, 51.6152),)
# XXXXXXXXXXXXXXXXXX COP with kW is: -1.702792372272417
# electricity in khW is: 3.010916491811112
# cop is: 1.8864183041340576
# Load in kWh is: 3.3109819579180306
# heat addition in kwh is: 5.679847982371585
# OK ok oK oK ok if not small run
# Total sum discharge in kJ is : 0    11334.287055
# dtype: float64
# type of nDis now is  0.2424739935426699
# energy content of tank from the begineening of discharge in kJ, Inlet, mean, cp, p: 46744.341071254545 21.0348 50.728229999999996 4.014687359803263 987.7031464493151
# energy/sec discharged from tank in kJ/sec: 0    11334.287055
# dtype: float64
# discharge efficiency is: 0.2424739935426699
# liters discharged is : 96.170216578889
# Load in kWh is: 3.3162373549651956
# Discharging: load_kJ_total mul 3600: 11938.454477874704
# Availability :Total energy of in Kj is : 218118.64467644194
# Discharge: strat efficiency sum_float : 0.8387637567190174
# ________________________________________________________________
# flow rates load is =  1.6540504776146734 0.010375426405812781 403.73750979954593
# flow rates HP is =  0.6340193487350078 0.003971308166207377 -0.4637337145910134
# result is ((8908, datetime.datetime(2021, 5, 12, 13, 45, 42), 23.0288, 46.0622, 25.5314, 17.0167, 21.2038, 52.7406, 35.4926, 14.5541, 21.0686, 50.1835, 45.2453, 25.9036, 23.164, 23.1302, -242.02, 52.4336, 52.4336, 52.229, 51.6152),)
# XXXXXXXXXXXXXXXXXX COP with kW is: -1.9193338295241982
# electricity in khW is: 3.0109259870944456
# cop is: 1.8864052934750795
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# Load in kWh is: 3.338277954960421
# heat addition in kwh is: 5.679826720316641
# OK ok oK oK ok if not small run
# Total sum discharge in kJ is : 0    11427.751434
# dtype: float64
# type of nDis now is  0.24475207464859772
# energy content of tank from the begineening of discharge in kJ, Inlet, mean, cp, p: 46691.13203719522 21.0686 50.728229999999996 4.014687359803263 987.7031464493151
# energy/sec discharged from tank in kJ/sec: 0    11427.751434
# dtype: float64
# discharge efficiency is: 0.24475207464859772
# liters discharged is : 96.84311324555567
# Load in kWh is: 3.339633923858673
# Discharging: load_kJ_total mul 3600: 12022.682125891224
# Availability :Total energy of in Kj is : 217972.36091150623
# Discharge: strat efficiency sum_float : 0.842006839498288
# ________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# flow rates load is =  1.6500503555406356 0.010350334685363416 402.15941417379975
# flow rates HP is =  0.6340193487350078 0.003971308166207377 -0.4637337145910134
# result is ((8912, datetime.datetime(2021, 5, 12, 13, 45, 49), 23.0288, 46.1302, 25.4637, 17.0842, 21.2038, 52.7406, 35.5265, 14.5541, 21.0686, 50.1835, 44.5307, 25.8021, 23.1302, 23.0626, -242.02, 52.5359, 52.4336, 52.229, 51.5811),)
# XXXXXXXXXXXXXXXXXX COP with kW is: -1.985286785301346
# electricity in khW is: 3.010935227611112
# cop is: 1.8863923958386806
# Load in kWh is: 3.365467198664434
# heat addition in kwh is: 5.679805317728409
# OK ok oK oK ok if not small run
# Total sum discharge in kJ is : 0    11520.850278
# dtype: float64
# type of nDis now is  0.24674600454389575
# energy content of tank from the begineening of discharge in kJ, Inlet, mean, cp, p: 46691.13203719522 21.0686 50.728229999999996 4.014687359803263 987.7031464493151
# energy/sec discharged from tank in kJ/sec: 0    11520.850278
# dtype: float64
# discharge efficiency is: 0.24674600454389575
# liters discharged is : 97.51337824555567
# Load in kWh is: 3.3629389898906843
# Discharging: load_kJ_total mul 3600: 12106.580363606463
# Availability :Total energy of in Kj is : 217844.53878692628
# Discharge: strat efficiency sum_float : 0.8425359323479071
# ________________________________________________________________
# flow rates load is =  1.6540504776146734 0.010375426405812781 403.73750979954593
# flow rates HP is =  0.6300192266609699 0.003946252594180832 -5.187740468238238
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py:726: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# result is ((8916, datetime.datetime(2021, 5, 12, 13, 45, 56), 23.0288, 46.0622, 25.2946, 17.1517, 21.17, 52.6724, 35.5265, 14.5541, 21.0686, 50.1153, 43.8843, 25.6667, 23.1302, 23.0626, -242.02, 52.57, 52.4336, 52.229, 51.6152),)
# XXXXXXXXXXXXXXXXXX COP with kW is: -23.9817017290531
# electricity in khW is: 3.010943827011112
# cop is: 1.8863070998392595
# Load in kWh is: 3.3927074838814
# heat addition in kwh is: 5.679564718108252
