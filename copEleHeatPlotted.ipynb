# %%
import time
import board
import busio
import pandas as pd
from pandas import DataFrame
from matplotlib import pylab
import matplotlib.pyplot as plt
from pylab import *
import pylab
import numpy as np
import matplotlib.colors as clrs
import matplotlib.cm as cm
import matplotlib
from collections import deque

import time
import struct
from struct import *
from pyModbusTCP.client import ModbusClient

#matplotlib.use('TkAgg')
# %matplotlib notebook
#%matplotlib inline


#import time
import sys
import sqlite3
#from time import sleep

#import adafruit_ads1x15.ads1015 as ADS
import adafruit_ads1x15.ads1115 as ADS
from adafruit_ads1x15.analog_in import AnalogIn

import MySQLdb as db

HOST = "10.208.8.122"
PORT = 3306
USER = "yogi"
PASSWORD = "bittoo"
DB = "TemaccessToRemoteRp2"
'''
try:
    connection = db.Connection(host=HOST, port=PORT,
                               user=USER, passwd=PASSWORD, db=DB)

    c = connection.cursor()
    c.execute("SELECT * from temSensor")
    result = c.fetchall()
    for item in result:
        print (item)

except Exception as e:
    print (e)
'''
connectionL = db.connect(host="10.208.8.121",
                     user="yogi",
                     passwd="bittoo",
                     db="allSensors")

#c = conn.cursor()
connectionR = db.Connection(host=HOST, port=PORT,user=USER, passwd=PASSWORD, db=DB)

cR = connectionR.cursor()
cL =connectionL.cursor()

i2c = busio.I2C(board.SCL, board.SDA)

# Create the ADC object using the I2C bus
ads = ADS.ADS1115(i2c)

ads.gain = 1


cL.execute('DROP TABLE IF EXISTS flowReadings;')
print ('table deleted')


cL.execute('CREATE TABLE flowReadings(id INT AUTO_INCREMENT PRIMARY KEY, ts TIMESTAMP DEFAULT CURRENT_TIMESTAMP, flowHP FLOAT, flowLoad FLOAT) ENGINE=MyISAM;')


#cvsFileName = import os.path
#os.path.exists(file_path)

lol=[[], [], [], []]
flowRateLoad  = []
wattMeterKw = []



def flatten(l_of_l):
    T = l_of_l[0]
    flattend_l = [val for sublist in T for val in sublist]
    #print ('flattened list is =', flattend_l)
    return flattend_l


timePeriod = []
def timeStampCreator(Lol):
    mHP = Lol[2]
    T = flatten(Lol)
    if len(mHP) == 1:
        timeStamp = 2/3600
        timePeriod.append(timeStamp)
    elif len(mHP) > 1:
        timeLast = T[-1][1]
        timeSecondLast = T[-2][1]
        timeStamp = timeLast -timeSecondLast
        timeStamp = timeStamp.total_seconds()/3600
        timePeriod.append(timeStamp)
    return 
    
def MCT_timeStamp(Lol, time_stamp):
    mHP = Lol[2]
    T = flatten(Lol)
    mL = Lol[1]
    watt_kW = Lol[3]
    p_LperH = [999.8473664794213 + 6.29265190e-02*x[2] - 8.42930922e-03*x[2]**2 + 6.77190849e-05*x[2]**3 \
 - 4.40840180e-07*x[2]**4 + 1.29302849e-09*x[2]**5 for x in T]
    mF_kgPerS =[ x*2.7777e-07*y for x, y in zip(p_LperH, mHP)]
    cP_kjPerkgK = [4.253264761904763 - 0.00470305*b[2] for b in T]
    mCT_kW = [c*a*(b[3]-b[4]) for c, a, b in zip(cP_kjPerkgK,mF_kgPerS, T)]
    mCT_kWh_l = [x*y for x,y in zip (time_stamp, mCT_kW)]
    mCT_kWh = sum(mCT_kWh_l)
    #electricty consumed:
    watt_kW_l = [x*y for x,y in zip (time_stamp,  watt_kW)]
    watt_kWh = sum(watt_kW_l)
    #cop 
    cop =mCT_kWh/watt_kWh
    print ('cop of system is:', cop)
    print ('kwh heat addition is :', mCT_kWh)
    #print ('whole kW list is:', mCT_kW)
    print ('electricity in khW is:', watt_kWh)
    #print ('electricity consumption kW :', watt_kW)
    return mCT_kW

def Load_kWh(Lol, time_stamp):
    mHP = Lol[2]
    T = flatten(Lol)
    mL = Lol[1]
    #this is density as polynomial function of T
    p_LperH = [999.8473664794213 + 6.29265190e-02*x[10] - 8.42930922e-03*x[10]**2 + 6.77190849e-05*x[10]**3 \
 - 4.40840180e-07*x[10]**4 + 1.29302849e-09*x[10]**5 for x in T]
    #print ('denisty is:', p_LperH )
    #print ('Tem is:', [x[10] for x in T])
    # this is mass flow  in kg/S =  density*V(flow rate in m^3/sec)= d * (1000^-3/3600)
    mF_kgPerS =[ x*2.7777e-07*y for x, y in zip(p_LperH, mL)]
    #this is Cp as functiono of T linear function
    cP_kjPerkgK = [4.253264761904763 - 0.00470305*b[10] for b in T]
    #print ('Cp is:', cP_kjPerkgK)
    #Cp*M*deltaT
    load_mCT_kW = [c*a*(b[7]-b[10]) for c, a, b in zip(cP_kjPerkgK,mF_kgPerS, T)]
    load_mCT_kWh_l = [x*y for x,y in zip (time_stamp, load_mCT_kW)]
    load_mCT_kWh = sum(load_mCT_kWh_l)    
    #mCT2_kWh = sum([m*c*(dt[7]-dt[10])*0.0013888889 for m, c, dt in zip(mF_kgPerS,  cP_kjPerkgK, T)])
    #load_mCT2_kWh = sum([m*c*(dt[7]-dt[10])*2.7777777e-05 for m, c, dt in zip(mF_kgPerS,  cP_kjPerkgK, T)])
    #Time stamp uis 2 seconds 2* 1/3600
    #load_mCT2_kWh = sum([m*c*(dt[7]-dt[10])*0.000555555556 for m, c, dt in zip(mF_kgPerS,  cP_kjPerkgK, T)])
    #print ('Load in kWh is:', load_mCT2_kWh)
    print ('load in kWh is:', load_mCT_kWh)
    return load_mCT_kW

#electrictyPlotterList = []
copPlotterList = []
def Cop(Lol, time_stamp):
    mHP = Lol[2]
    T = flatten(Lol)
    mL = Lol[1]
    watt_kW = Lol[3]
    p_LperH = [999.8473664794213 + 6.29265190e-02*x[2] - 8.42930922e-03*x[2]**2 + 6.77190849e-05*x[2]**3 \
 - 4.40840180e-07*x[2]**4 + 1.29302849e-09*x[2]**5 for x in T]
    mF_kgPerS =[ x*2.7777e-07*y for x, y in zip(p_LperH, mHP)]
    cP_kjPerkgK = [4.253264761904763 - 0.00470305*b[2] for b in T]
    mCT_kW = [c*a*(b[3]-b[4]) for c, a, b in zip(cP_kjPerkgK,mF_kgPerS, T)]
    mCT_kWh_l = [x*y for x,y in zip (time_stamp, mCT_kW)]
    mCT_kWh = sum(mCT_kWh_l)
    #electricty consumed:
    watt_kW_l = [x*y for x,y in zip (time_stamp,  watt_kW)]
    watt_kWh = sum(watt_kW_l)
    #cop 
    cop =mCT_kWh/watt_kWh
    copPlotterList.append(cop)
    print ('cop of system is:', cop)
    print ('kwh heat addition is :', mCT_kWh)
    #print ('whole kW list is:', mCT_kW)
    print ('electricity in khW is:', watt_kWh)
    
    #print ('electricity consumption kW :', watt_kW)
    return cop


l_id = []

def idGenerator(Id, l_id):
    if Id not in l_id:
       l_id.append(Id) 
    #print (l_id)
    return l_id

#df_conc= None
def dfs(Lol):
    mHP = Lol[2]
    T = flatten(Lol)
    mL = Lol[1]
    StartTemTestingtank = [ 'id', 'dateTime', 'Tamb', 'TtopTestTankHPCir', 'TbottomTestTankHpCir', 'TtopSourceTank', \
'TloadTankMix','TTopTestTankLoadCir', 'TloadMix', 'TbottomSourceTank', 'TbottomTestTankLoadCir']
    l_T = ['T{}'.format(x) for x in range(0,10)]
    L = StartTemTestingtank +l_T
    df_mHP = DataFrame(mHP, columns=['flowHP'])
    df_mL = DataFrame(mL, columns=['flowLoad'])
    df_tem = DataFrame(T, columns = L)
    df_conc = pd.concat([df_tem, df_mHP, df_mL], axis=1)
    
    #print (df_mL)
    #print (df_mHP)
    #print (df_tem)
    #print ('TOut and Tin in Df is:', df_conc[['TTopTestTankLoadCir', 'TbottomTestTankLoadCir']])
    return df_conc

def list2df(lis, column_name = None):
    df  = pd.DataFrame(lis, columns = [column_name]) 
    return df


def toCsv(df_full, load_kW, heatCapacity_kW, electrictyUsed_kW, COP):
    df_Tem_Flow_Load_capacity_conc = pd.concat([df_full, load_kW, heatCapacity_kW, electrictyUsed_kW, \
                                                COP], axis=1)
    import os.path
    import datetime
    file_name = 'csvFile_{}'.format(datetime.datetime.now().strftime("%Y_%m_%d"))
    suffix = '.csv'
    filePath = os.path.join(os.getcwd(), file_name + suffix)
    df_Tem_Flow_Load_capacity_conc.to_csv(filePath, header=True)
    return df_Tem_Flow_Load_capacity_conc

'''
def toCsv(df_full, load_kW, heatCapacity_kW):
    df_Tem_Flow_Load_capacity_conc = pd.concat([df_full, load_kW, heatCapacity_kW], axis=1)
    import os.path
    import datetime
    file_name = 'csvFile_{}'.format(datetime.datetime.now().strftime("%Y_%m_%d"))
    suffix = '.csv'
    filePath = os.path.join(os.getcwd(), file_name + suffix)
    df_Tem_Flow_Load_capacity_conc.to_csv(filePath, header=True)
    return df_Tem_Flow_Load_capacity_conc
'''



def tankStrat(df):
    dfT = df.iloc[:, 11:-2]
    #print (dfT.columns)
    #print (dfT)
    dfT = dfT[['T4', 'T3', 'T2', 'T1', 'T0', 'T9', 'T8', 'T7', 'T6', 'T5']]
    dfT = dfT.rename({'T4':'T0', 'T3':'T1', 'T2':'T2', 'T1':'T3', 'T0':'T4', 'T9':'T5', 'T8':'T6',\
              'T7':'T7','T6':'T8','T5':'T9'}, axis='columns')
    #dfT = dfT[['T4', 'T3', 'T2', 'T1', 'T0', 'T5', 'T6', 'T7', 'T8', 'T9']]
    #dfT = dfT[['T4', 'T3', 'T2', 'T1', 'T0', 'T8', 'T9', 'T5', 'T6', 'T7']]
    #dfT = dfT.rename({'T4':'T0', 'T3':'T1', 'T2':'T2', 'T1':'T3', 'T0':'T4', 'T8':'T5', 'T9':'T6',\
    #           'T5':'T7','T6':'T8','T7':'T9'}, axis='columns')
    #dfT = dfT.rename({'T4':'T0', 'T3':'T1', 'T2':'T2', 'T1':'T3', 'T0':'T4', 'T5':'T5', 'T6':'T6',\
    #          'T7':'T7','T8':'T8','T9':'T9'}, axis='columns')
    #dfT.columns = ['T4', 'T3', 'T2', 'T1', 'T0', 'T5', 'T6', 'T7', 'T8', 'T9']
    #print (dfT)
    return dfT
#tankStratTem = tankStrat(df_conc)

def create_color_step_obj(cmap_name, n):
    """
    Return scalarMap object with n colors in gradient from color map
    given in cmap_name.
    """
    cmap = plt.get_cmap(cmap_name)
    values = range(n)
    cNorm  = clrs.Normalize(vmin=values[0], vmax=values[-1])
    scalarMap = cm.ScalarMappable(norm=cNorm, cmap=cmap)
    return scalarMap

#import logging
#logging.getLogger().setLevel(logging.CRITICAL)

# colors


cmap_name = "jet"
scm = create_color_step_obj(cmap_name, 10)

plt.ion()
#plt.rcParams["figure.figsize"]=5,5
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 8
fig_size[1] = 3
def plotObject(df, ax, fig, alpha =0.7, scm=None):
    ax.clear()
    for i in range (0, df.shape[1]):
        ax.plot(df.index, df.iloc[:, i], color= scm.to_rgba(i, alpha=alpha),\
                label = 'Layer ' + str(i))
        ax.legend(bbox_to_anchor=(0.4,0.8))
    fig.canvas.draw()
    ax.legend()
    #plt.legend(loc='upper left')
    return fig, ax
    
# initialize figure and interactivity
fig = plt.figure(1)
fig2 = plt.figure(2)


ax = fig.add_subplot(121)
ax_2 = fig.add_subplot(122)
ax2 = fig2.add_subplot(122)
ax2_1 = fig2.add_subplot(121)

fig.canvas.draw()
#plt.ion()

fig.show()

ax.legend(loc='best')
ax.set_xlabel('Index')
ax.set_ylabel('Tem, C', color='r')
#################################
#Plot for HPin, Hpout, TmixL tem.

fig.show()
fig.canvas.draw()
ax_2.legend(loc='best')
ax_2.set_xlabel('Index')
ax_2.set_ylabel('Load in kW', color='r')
def plotObject_Tem_HpAndLoad(df, ax_2, fig):
    ax_2.clear()
    ax_2.plot(df.index, df.iloc[:, 3], label = 'Hp to Testing tank top')
    ax_2.plot(df.index, df.iloc[:, 4], label = 'Testing tank to HP Bottom')
    ax_2.plot(df.index, df.iloc[:, 8], label = 'load tem Mixed')
    
    ax_2.legend(bbox_to_anchor=(0.4,0.8))
    fig.canvas.draw()
    ax_2.legend()
    #plt.legend(loc='upper left')
    return fig, ax_2
##################################

#fig2 = plt.figure(2)

#plt.ion()

fig2.show()
fig2.canvas.draw()
ax2.legend(loc='best')
ax2.set_xlabel('Index')
ax2.set_ylabel('Load in kW', color='r')
def plotObject_Load(df, ax2, fig2):
    ax2.clear()
    ax2.plot(df.index, df.iloc[:, -2], label = 'Load in kW')
    #ax2.plot(df.index, COP, label = 'cop')
    print (df.index)
    ax2.legend(bbox_to_anchor=(0.4,0.8))
    fig2.canvas.draw()
    ax2.legend()
    #plt.legend(loc='upper left')
    return fig2, ax2
    
# initialize figure and interactivity
####Plot for heat_Capacity:

fig2.show()
fig2.canvas.draw()
ax2_1.legend(loc='best')
ax2_1.set_xlabel('Index')
ax2_1.set_ylabel('Heat_Capacity in kW', color='r')
def plotObject_Heat_Capacity(df, ax2_1, fig2):
    ax2_1.clear()
    ax2_1.plot(df.index, df.iloc[:, -3], label = 'heat_Capacity in kW')
    ax2_1.plot(df.index, df.iloc[:, -2], label = 'electrcity_kW')
    ax2_1.plot(df.index, df.iloc[:, -1], label = 'cop of system')
    ax2_1.legend(bbox_to_anchor=(0.4,0.8))
    fig2.canvas.draw()
    ax2_1.legend()
    #plt.legend(loc='upper left')
    return fig2, ax2_1
############

while True:
    #c.execute("INSERT INTO flowReadings(flowHp, flowLoad) VALUES(?,?,?,?)", (chan2.voltage, chan1.voltage))
    #connection.commit()
    
    ###################################################################################
    ################################################
    ##Modbus connection for wattmeter readings in kW
    ##https://stackoverflow.com/questions/28186746/python-convert-2-ints-to-float
    ################################################
    
    c = ModbusClient(host="10.208.8.125", port=502, auto_open=True)
    
    #This reads the register address 19026 where all teh meteric(values of wattmeter) 
    #values are stored in a 16 bit values.county = 2, means read two values in the
    #same register address.Register is a column (like in spreadsheet). each register
    #store a 16 bit value, we read two 16 bit value and would convert those 2 16 bit 
    #value to a 32 bit floating point value by the formula
    regs = c.read_input_registers(19026, 2)
    #this is forst value of two counts
    a = regs[0]
    #This is second value of two counts
    b = regs[1]
    #This is how we convert two 16 bit value to a single 32 floating point number.
    #from stackoverflow
    mypack = pack('>HH',a,b)
    #print (mypack)
    fl = unpack('>f', mypack)
    #fl = struct.unpack('!f', bytes.fromhex('{0:02x}'.format(a) + '{0:02x}'.format(b)))
    #fl is a tuple (5.0186,) I need to unpack it index it with [0] 
    fl = fl[0]*10**-3
    wattMeterKw.append(fl)
    #lol[3].append(fl)
    #print ('watter meter reaidngs are:', wattMeterKw)
    #print ('gross lol is:', lol)
    ####################################################################################
    
    chan1 = AnalogIn(ads, ADS.P0)
    chan2 = AnalogIn(ads, ADS.P1)

    chan1Vol = chan1.voltage
    chan1curr = chan1Vol/159.42

    chan2Vol = chan2.voltage
    chan2curr=chan2Vol/159.65
    #flow1 = ((chan1Vol/159.42)*1000 -4)/16*1000
    flow1 = ((chan1Vol/159.42)-0.003956)/0.0000159
    #flow2 = ((chan2Vol/159.65)*1000 -4)/16*4000 +20
    #flow2 = ((chan2Vol/159.65)- 0.0005468893873066417)/1.09561608e-05
    flow2 = ((chan2Vol/159.65)- 0.003973767754877122)/5.3038815e-06
    cL.execute("INSERT INTO flowReadings(flowHp, flowLoad) VALUES(%s, %s)", (flow2, flow1))
    connectionL.commit()
    
    #cL =connectionL.cursor()
    cL.execute("SELECT * FROM flowReadings ORDER BY id DESC LIMIT 1")
    FlowFormDb = cL.fetchall()
    print ('flow from FlowDB is :',FlowFormDb)
    #c.execute("SELECT * from temSensor")
    #cR.execute("SELECT * FROM temSensor ORDER BY id DESC LIMIT 1")
    #result = cR.fetchall()
    #print('flow HP:',"{:>5}\t{:>5.3f}".format(chan2.value, chan2.voltage), '\n\n')
    #print('flow load:',"{:>5}\t{:>5.3f}".format(chan1.value, chan1.voltage, '\n\n'))
    print('flow rates load is = ',chan1Vol, chan1curr,flow1 )
    print('flow rates HP is = ',chan2Vol, chan2curr,flow2 )

    connectionR = db.Connection(host=HOST, port=PORT,user=USER, passwd=PASSWORD, db=DB)
    cR = connectionR.cursor()
    #c.execute("SELECT * from temSensor")
    cR.execute("SELECT * FROM temSensor ORDER BY id DESC LIMIT 1")
    result = cR.fetchall()
    print ('result is',result)
    id = result[0][0]
    #idGenerator(id, l_id)
    #print ('id is :', id)
    flowRateLoad.append(flow1)

    if lol[0] ==[] or id < lol[0][-1][0][0] :
        lol[0].append(result)
        #print (lol)
        lol[1].append(flow1)
        lol[2].append(flow2)
        lol[3].append(fl)
        timeStampCreator(lol)
    elif lol[0] != [] and id > lol[0][-1][0][0]:

        lol[0].append(result)
        lol[1].append(flow1)
        lol[2].append(flow2)
        lol[3].append(fl)
        timeStampCreator(lol)


    #mct(lol)
    #Load = Load_kWh(lol)
    #print ('load in kWh is:', Load)
    #print ('lol is:',lol)
    #print ('df of tem is:',df_tem)
    #print ('df is:', tankStrat(dfs(lol)))
    df = tankStrat(dfs(lol))
    #restTem = InletTem(dfs(lol))
    #print (df)
    cop = Cop(lol, timePeriod)
    #Load_kWh(lol, timePeriod)
    #print ('type of cop function in :', type(cop))
    #print ('cop list shoudl look like this:', copPlotterList)
    
    GrossDf = toCsv(dfs(lol), list2df(Load_kWh(lol, timePeriod), 'Load_kW'), \
                    list2df(MCT_timeStamp(lol, timePeriod),'Heat_Capacity_kW'),\
                    list2df(wattMeterKw, 'electrcity_kW'), list2df(copPlotterList, 'COP'))
    #print ('gorss DF is :',GrossDf )
    #GrossDf = toCsv(dfs(lol), list2df(Load_kWh(lol), 'Load_kW'), list2df(MCT_timeStamp(lol, timePeriod),'Heat_Capacity_kW'))
    #heatAddition_kwh, cop = MCT_timeStamp(lol, timePeriod)
    # Plot tem values as a seperate first fig
    fig, ax = plotObject(df, ax,  fig, alpha=0.7, scm=scm)
    #plot load_kW in different fig2 
    fig2, ax2 = plotObject_Load(GrossDf, ax2, fig2)
    #Plot heat_Capacity in the same fig as fig2 but as a subplot
    fig2, ax2_1 =plotObject_Heat_Capacity(GrossDf, ax2_1, fig2)
    #This plot the HP in and out and tmixL laod tem.
    fig, ax_1 = plotObject_Tem_HpAndLoad(GrossDf, ax_2, fig)
    #print ('df whole is:', dfs(lol))
    #print ('df is:', df)
    #plot(tankStrat(dfs(lol)), plotObject(tankStrat(dfs(lol))))
    #plotObject(tankStrat(dfs(lol)))for i in range (0, 10):
    #x = tankStrat(dfs(lol)).index[-1]
    #y =tankStrat(dfs(lol)).iloc[-1]
    #print ('x is:',x,'y is :',y)
    #restTem = InletTem(dfs(lol))
    #print ('rets of inlet tem values are:', restTem.iloc[:, 1])
    #print ('gross lol is:', lol)
    #print ('values in teh list are:', lol[0][-1][0][0])
    #print ('GrossDf is :', GrossDf.iloc[:, 0:2])
    #print ('grand lollolo is :', lol)
    #MCT_timeStamp(lol)
    #timeStampCreator(lol)
    #MCT_timeStamp(lol, timePeriod)
    
    #print ('time stamp list is :',timePeriod )
    print('________________________________________________________________')
    time.sleep(0.1)
# Out:
# table deleted
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# flow from FlowDB is : ((3, datetime.datetime(2021, 2, 18, 13, 52, 40), 1.89827, 18.6822),)
# flow rates load is =  0.6780206915494248 0.004253046616167513 18.682177117453612
# flow rates HP is =  0.6360194097720268 0.003983835952220649 1.898269662232681
# result is ((5579, datetime.datetime(2021, 2, 18, 12, 52, 39), 23.8064, 32.7791, 24.8887, 17.7929, 32.2706, 33.559, 28.002, 13.8798, 24.3475, 31.3555, 31.0166, 29.763, 28.1036, 26.6142, 33.4234, 32.5418, 31.9655, 31.6605, 31.6266),)
# cop of system is: 3.4645381564777757
# kwh heat addition is : 9.546722848993759e-06
# electricity in khW is: 2.7555542522006566e-06
# load in kWh is: 0.00010960488735874878
# cop of system is: 3.4645381564777757
# kwh heat addition is : 9.546722848993759e-06
# electricity in khW is: 2.7555542522006566e-06
# RangeIndex(start=0, stop=1, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((8, datetime.datetime(2021, 2, 18, 13, 52, 42), -0.463734, 17.8931),)
# flow rates load is =  0.6760206305124058 0.0042405007559428295 17.89312930458045
# flow rates HP is =  0.6340193487350078 0.003971308166207377 -0.4637337145910134
# result is ((5580, datetime.datetime(2021, 2, 18, 12, 52, 41), 23.7726, 32.7452, 24.8887, 17.7592, 32.2367, 33.593, 28.0359, 13.9472, 24.3475, 31.3555, 30.9827, 29.763, 28.1036, 26.6142, 33.4234, 32.5757, 31.9655, 31.6605, 31.6605),)
# cop of system is: 1.2926136201222524
# kwh heat addition is : 7.224438222358026e-06
# electricity in khW is: 5.589016013675266e-06
# load in kWh is: 0.00021496804603142515
# cop of system is: 1.2926136201222524
# kwh heat addition is : 7.224438222358026e-06
# electricity in khW is: 5.589016013675266e-06
# RangeIndex(start=0, stop=2, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((15, datetime.datetime(2021, 2, 18, 13, 52, 45), 1.89827, 13.9479),)
# flow rates load is =  0.666020325327311 0.004177771454819415 13.947890240214761
# flow rates HP is =  0.6360194097720268 0.003983835952220649 1.898269662232681
# result is ((5582, datetime.datetime(2021, 2, 18, 12, 52, 44), 23.8064, 32.7791, 24.8887, 17.7592, 32.2367, 33.559, 28.1036, 13.8798, 24.449, 31.3893, 30.9827, 29.763, 28.1036, 26.5803, 33.4234, 32.5418, 31.9655, 31.6605, 31.6605),)
# cop of system is: 2.1695939649221887
# kwh heat addition is : 2.1544522495848666e-05
# electricity in khW is: 9.930209451251561e-06
# load in kWh is: 0.00033634299384387395
# cop of system is: 2.1695939649221887
# kwh heat addition is : 2.1544522495848666e-05
# electricity in khW is: 9.930209451251561e-06
# RangeIndex(start=0, stop=3, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((22, datetime.datetime(2021, 2, 18, 13, 52, 49), 1.89827, -0.25497),)
# flow rates load is =  0.6300192266609699 0.003951945970775122 -0.25497039150178974
# flow rates HP is =  0.6360194097720268 0.003983835952220649 1.898269662232681
# result is ((5584, datetime.datetime(2021, 2, 18, 12, 52, 48), 23.8064, 32.7791, 24.8887, 17.7592, 32.2367, 33.593, 28.1374, 13.9135, 24.4828, 31.3555, 30.9827, 29.763, 28.1036, 26.5803, 33.4234, 32.5079, 31.9655, 31.6944, 31.6605),)
# cop of system is: 2.6139536448920917
# kwh heat addition is : 4.0637968193836184e-05
# electricity in khW is: 1.5546552737553915e-05
# load in kWh is: 0.00033338472136858866
# cop of system is: 2.6139536448920917
# kwh heat addition is : 4.0637968193836184e-05
# electricity in khW is: 1.5546552737553915e-05
# RangeIndex(start=0, stop=4, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((29, datetime.datetime(2021, 2, 18, 13, 52, 52), -0.463734, 0.534077),)
# flow rates load is =  0.6320192876979889 0.003964491830999805 0.5340774213713702
# flow rates HP is =  0.6340193487350078 0.003971308166207377 -0.4637337145910134
# result is ((5586, datetime.datetime(2021, 2, 18, 12, 52, 51), 23.8064, 32.8131, 24.8887, 17.7592, 32.2367, 33.593, 28.2729, 13.9135, 24.5843, 31.3555, 30.9827, 29.763, 28.1036, 26.6142, 33.4234, 32.5757, 31.9655, 31.6605, 31.6605),)
# cop of system is: 1.857574826112582
# kwh heat addition is : 3.7124599660424776e-05
# electricity in khW is: 1.9985520442326865e-05
# load in kWh is: 0.00033797973570957656
# cop of system is: 1.857574826112582
# kwh heat addition is : 3.7124599660424776e-05
# electricity in khW is: 1.9985520442326865e-05
# RangeIndex(start=0, stop=5, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((34, datetime.datetime(2021, 2, 18, 13, 52, 54), -0.463734, 1.32313),)
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  0.6340193487350078 0.003971308166207377 -0.4637337145910134
# result is ((5588, datetime.datetime(2021, 2, 18, 12, 52, 54), 23.7726, 32.7791, 24.8887, 17.7929, 32.2028, 33.593, 28.3744, 13.8798, 24.5843, 31.3555, 30.9827, 29.763, 28.1036, 26.5803, 33.3895, 32.5418, 31.9655, 31.6944, 31.6605),)
# cop of system is: 1.3824866457649072
# kwh heat addition is : 3.362614208682204e-05
# electricity in khW is: 2.4322941700617474e-05
# load in kWh is: 0.0003493634399872543
# cop of system is: 1.3824866457649072
# kwh heat addition is : 3.362614208682204e-05
# electricity in khW is: 2.4322941700617474e-05
# RangeIndex(start=0, stop=6, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((38, datetime.datetime(2021, 2, 18, 13, 52, 57), -0.463734, 2.90122),)
# flow rates load is =  0.6380194708090458 0.004002129411673854 2.9012208599907954
# flow rates HP is =  0.6340193487350078 0.003971308166207377 -0.4637337145910134
# result is ((5589, datetime.datetime(2021, 2, 18, 12, 52, 56), 23.7726, 32.7791, 24.9225, 17.7929, 32.2028, 33.593, 28.4083, 13.9135, 24.6519, 31.3555, 31.0166, 29.7291, 28.1036, 26.5803, 33.3895, 32.5757, 31.9655, 31.6605, 31.6944),)
# cop of system is: 1.1651556454443683
# kwh heat addition is : 3.1303827901418064e-05
# electricity in khW is: 2.686664912435744e-05
# load in kWh is: 0.0003658777409556064
# cop of system is: 1.1651556454443683
# kwh heat addition is : 3.1303827901418064e-05
# electricity in khW is: 2.686664912435744e-05
# RangeIndex(start=0, stop=7, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((43, datetime.datetime(2021, 2, 18, 13, 52, 59), -0.463734, 1.32313),)
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  0.6340193487350078 0.003971308166207377 -0.4637337145910134
# result is ((5590, datetime.datetime(2021, 2, 18, 12, 52, 58), 23.8064, 32.7791, 24.9225, 17.7592, 32.2028, 33.559, 28.4422, 13.9135, 24.6857, 31.3555, 30.9827, 29.763, 28.1036, 26.5803, 33.4234, 32.5079, 31.9316, 31.6944, 31.6266),)
# cop of system is: 0.9672526970948248
# kwh heat addition is : 2.8981622121834326e-05
# electricity in khW is: 2.9962823788324996e-05
# load in kWh is: 0.0003733517591676627
# cop of system is: 0.9672526970948248
# kwh heat addition is : 2.8981622121834326e-05
# electricity in khW is: 2.9962823788324996e-05
# RangeIndex(start=0, stop=8, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((51, datetime.datetime(2021, 2, 18, 13, 53, 2), 1.89827, 0.534077),)
# flow rates load is =  0.6320192876979889 0.003964491830999805 0.5340774213713702
# flow rates HP is =  0.6360194097720268 0.003983835952220649 1.898269662232681
# result is ((5592, datetime.datetime(2021, 2, 18, 12, 53, 1), 23.8064, 32.7791, 24.8887, 17.7929, 32.2028, 33.559, 28.5099, 13.9135, 24.7196, 31.3893, 30.9827, 29.763, 28.1036, 26.5803, 33.4234, 32.5757, 31.9655, 31.6944, 31.6266),)
# cop of system is: 1.2693533365496386
# kwh heat addition is : 4.330170639532496e-05
# electricity in khW is: 3.411320169766744e-05
# load in kWh is: 0.0003778595713800624
# cop of system is: 1.2693533365496386
# kwh heat addition is : 4.330170639532496e-05
# electricity in khW is: 3.411320169766744e-05
# RangeIndex(start=0, stop=9, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((58, datetime.datetime(2021, 2, 18, 13, 53, 6), -0.463734, 1.32313),)
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  0.6340193487350078 0.003971308166207377 -0.4637337145910134
# result is ((5594, datetime.datetime(2021, 2, 18, 12, 53, 5), 23.8064, 32.7791, 24.9225, 17.7929, 32.2028, 33.559, 28.6115, 13.9472, 24.7534, 31.3893, 30.9827, 29.763, 28.1036, 26.5803, 33.3895, 32.5079, 31.9994, 31.6944, 31.6605),)
# cop of system is: 0.9569525543639965
# kwh heat addition is : 3.865729483615749e-05
# electricity in khW is: 4.039625022146437e-05
# load in kWh is: 0.0003926921624980234
# cop of system is: 0.9569525543639965
# kwh heat addition is : 3.865729483615749e-05
# electricity in khW is: 4.039625022146437e-05
# RangeIndex(start=0, stop=10, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((63, datetime.datetime(2021, 2, 18, 13, 53, 8), 1.89827, 2.11217),)
# flow rates load is =  0.6360194097720268 0.003989583551449171 2.1121730471176354
# flow rates HP is =  0.6360194097720268 0.003983835952220649 1.898269662232681
# result is ((5595, datetime.datetime(2021, 2, 18, 12, 53, 7), 23.8064, 32.7791, 24.8887, 17.7929, 32.2028, 33.559, 28.6453, 13.8798, 24.821, 31.3555, 30.9827, 29.763, 28.0697, 26.5803, 33.3895, 32.5418, 31.9655, 31.6605, 31.6266),)
# cop of system is: 1.112953364316981
# kwh heat addition is : 4.820401768515125e-05
# electricity in khW is: 4.331180373827616e-05
# load in kWh is: 0.00040443918465263924
# cop of system is: 1.112953364316981
# kwh heat addition is : 4.820401768515125e-05
# electricity in khW is: 4.331180373827616e-05
# RangeIndex(start=0, stop=11, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((70, datetime.datetime(2021, 2, 18, 13, 53, 11), 6.62228, 1.32313),)
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  0.6400195318460646 0.004008891524247195 6.622276415880069
# result is ((5597, datetime.datetime(2021, 2, 18, 12, 53, 10), 23.8064, 32.7791, 24.8887, 17.7929, 32.1689, 33.559, 28.7131, 13.9135, 24.9225, 31.3555, 31.0166, 29.763, 28.0697, 26.6142, 33.3895, 32.5079, 31.9655, 31.6605, 31.6944),)
# cop of system is: 2.0983154376710114
# kwh heat addition is : 9.816085903624488e-05
# electricity in khW is: 4.67807924747467e-05
# load in kWh is: 0.00041534742829009587
# cop of system is: 2.0983154376710114
# kwh heat addition is : 9.816085903624488e-05
# electricity in khW is: 4.67807924747467e-05
# RangeIndex(start=0, stop=12, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((75, datetime.datetime(2021, 2, 18, 13, 53, 14), -5.18774, 0.534077),)
# flow rates load is =  0.6320192876979889 0.003964491830999805 0.5340774213713702
# flow rates HP is =  0.6300192266609699 0.003946252594180832 -5.187740468238238
# result is ((5599, datetime.datetime(2021, 2, 18, 12, 53, 13), 23.8403, 32.7791, 24.8887, 17.7929, 32.1689, 33.559, 28.8485, 13.9135, 24.9563, 31.3555, 30.9827, 29.763, 28.1036, 26.6142, 33.4234, 32.5418, 31.9655, 31.6605, 31.6266),)
# cop of system is: 1.1499222498236041
# kwh heat addition is : 5.902764042893282e-05
# electricity in khW is: 5.133185346921285e-05
# load in kWh is: 0.0004197330850122684
# cop of system is: 1.1499222498236041
# kwh heat addition is : 5.902764042893282e-05
# electricity in khW is: 5.133185346921285e-05
# RangeIndex(start=0, stop=13, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((83, datetime.datetime(2021, 2, 18, 13, 53, 17), -0.463734, 0.534077),)
# flow rates load is =  0.6320192876979889 0.003964491830999805 0.5340774213713702
# flow rates HP is =  0.6340193487350078 0.003971308166207377 -0.4637337145910134
# result is ((5601, datetime.datetime(2021, 2, 18, 12, 53, 17), 23.7726, 32.7452, 24.8887, 17.7592, 32.135, 33.6269, 28.8824, 13.8798, 25.024, 31.3555, 30.9827, 29.763, 28.0697, 26.5803, 33.3895, 32.5079, 31.9994, 31.6605, 31.6944),)
# cop of system is: 0.9544619589772467
# kwh heat addition is : 5.438307117566136e-05
# electricity in khW is: 5.697772516144647e-05
# load in kWh is: 0.00042558021124333224
# cop of system is: 0.9544619589772467
# kwh heat addition is : 5.438307117566136e-05
# electricity in khW is: 5.697772516144647e-05
# RangeIndex(start=0, stop=14, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((88, datetime.datetime(2021, 2, 18, 13, 53, 20), 1.89827, -0.25497),)
# flow rates load is =  0.6300192266609699 0.003951945970775122 -0.25497039150178974
# flow rates HP is =  0.6360194097720268 0.003983835952220649 1.898269662232681
# result is ((5602, datetime.datetime(2021, 2, 18, 12, 53, 19), 23.8064, 32.7791, 24.8887, 17.7929, 32.1689, 33.593, 28.9163, 13.9135, 25.0578, 31.3893, 30.9827, 29.763, 28.0697, 26.5803, 33.3895, 32.5418, 31.9655, 31.6944, 31.6944),)
# cop of system is: 1.0700827100921029
# kwh heat addition is : 6.392979402465511e-05
# electricity in khW is: 5.9742852979236185e-05
# load in kWh is: 0.0004241955410075433
# cop of system is: 1.0700827100921029
# kwh heat addition is : 6.392979402465511e-05
# electricity in khW is: 5.9742852979236185e-05
# RangeIndex(start=0, stop=15, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((93, datetime.datetime(2021, 2, 18, 13, 53, 22), -0.463734, 1.32313),)
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  0.6340193487350078 0.003971308166207377 -0.4637337145910134
# result is ((5603, datetime.datetime(2021, 2, 18, 12, 53, 20), 23.8064, 32.7791, 24.8887, 17.7929, 32.135, 33.593, 28.984, 13.9135, 25.0578, 31.3893, 30.9827, 29.763, 28.1036, 26.5803, 33.4234, 32.5418, 31.9655, 31.6944, 31.6944),)
# cop of system is: 1.0237344349652207
# kwh heat addition is : 6.276369593621815e-05
# electricity in khW is: 6.130857163005406e-05
# load in kWh is: 0.00042778829567856303
# cop of system is: 1.0237344349652207
# kwh heat addition is : 6.276369593621815e-05
# electricity in khW is: 6.130857163005406e-05
# RangeIndex(start=0, stop=16, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((100, datetime.datetime(2021, 2, 18, 13, 53, 25), 4.26027, 1.32313),)
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  0.6380194708090458 0.003996363738233922 4.260273039056376
# result is ((5605, datetime.datetime(2021, 2, 18, 12, 53, 24), 23.8403, 32.7791, 24.8887, 17.7929, 32.135, 33.593, 28.984, 13.8798, 25.1593, 31.3893, 30.9827, 29.7291, 28.0697, 26.5803, 33.4234, 32.5418, 31.9994, 31.6605, 31.6605),)
# cop of system is: 1.5744555458413863
# kwh heat addition is : 0.00010561297291526963
# electricity in khW is: 6.707904405064054e-05
# load in kWh is: 0.00044198640367541304
# cop of system is: 1.5744555458413863
# kwh heat addition is : 0.00010561297291526963
# electricity in khW is: 6.707904405064054e-05
# RangeIndex(start=0, stop=17, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((106, datetime.datetime(2021, 2, 18, 13, 53, 28), -0.463734, 1.32313),)
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  0.6340193487350078 0.003971308166207377 -0.4637337145910134
# result is ((5607, datetime.datetime(2021, 2, 18, 12, 53, 27), 23.8064, 32.7791, 24.8548, 17.7929, 32.135, 33.559, 29.0517, 13.8798, 25.1931, 31.3893, 30.9488, 29.763, 28.0697, 26.5803, 33.3895, 32.5418, 31.9655, 31.6605, 31.6605),)
# cop of system is: 1.4324827367181994
# kwh heat addition is : 0.00010209964871794087
# electricity in khW is: 7.12746102280087e-05
# load in kWh is: 0.00045254888028583716
# cop of system is: 1.4324827367181994
# kwh heat addition is : 0.00010209964871794087
# electricity in khW is: 7.12746102280087e-05
# RangeIndex(start=0, stop=18, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((111, datetime.datetime(2021, 2, 18, 13, 53, 30), 4.26027, 1.32313),)
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  0.6380194708090458 0.003996363738233922 4.260273039056376
# result is ((5608, datetime.datetime(2021, 2, 18, 12, 53, 29), 23.8064, 32.7791, 24.8887, 17.7929, 32.135, 33.559, 29.0517, 13.9472, 25.1931, 31.3555, 30.9827, 29.763, 28.1036, 26.5803, 33.4234, 32.5418, 31.9316, 31.6605, 31.6605),)
# cop of system is: 1.671050630566122
# kwh heat addition is : 0.0001235252905928023
# electricity in khW is: 7.392073485586379e-05
# load in kWh is: 0.00045959053135945325
# cop of system is: 1.671050630566122
# kwh heat addition is : 0.0001235252905928023
# electricity in khW is: 7.392073485586379e-05
# RangeIndex(start=0, stop=19, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((118, datetime.datetime(2021, 2, 18, 13, 53, 33), -0.463734, -0.25497),)
# flow rates load is =  0.6300192266609699 0.003951945970775122 -0.25497039150178974
# flow rates HP is =  0.6340193487350078 0.003971308166207377 -0.4637337145910134
# result is ((5610, datetime.datetime(2021, 2, 18, 12, 53, 32), 23.8064, 32.7791, 24.9225, 17.7929, 32.135, 33.593, 29.1533, 13.9135, 25.2608, 31.3555, 30.9827, 29.763, 28.0697, 26.5803, 33.4234, 32.5418, 31.9994, 31.6944, 31.6605),)
# cop of system is: 1.5420926739183503
# kwh heat addition is : 0.0001200419819234267
# electricity in khW is: 7.784355892075433e-05
# load in kWh is: 0.00045756349984566824
# cop of system is: 1.5420926739183503
# kwh heat addition is : 0.0001200419819234267
# electricity in khW is: 7.784355892075433e-05
# RangeIndex(start=0, stop=20, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((124, datetime.datetime(2021, 2, 18, 13, 53, 36), -2.82574, 1.32313),)
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  0.6320192876979889 0.003958780380194105 -2.825737091414544
# result is ((5612, datetime.datetime(2021, 2, 18, 12, 53, 36), 23.8064, 32.7791, 24.8887, 17.7929, 32.1011, 33.593, 29.2211, 13.9135, 25.2946, 31.3893, 30.9488, 29.763, 28.0697, 26.5465, 33.3895, 32.5418, 31.9316, 31.6605, 31.6266),)
# cop of system is: 1.0688165362397026
# kwh heat addition is : 9.161975151794521e-05
# electricity in khW is: 8.572074664963616e-05
# load in kWh is: 0.000471531190315949
# cop of system is: 1.0688165362397026
# kwh heat addition is : 9.161975151794521e-05
# electricity in khW is: 8.572074664963616e-05
# RangeIndex(start=0, stop=21, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((130, datetime.datetime(2021, 2, 18, 13, 53, 39), 1.89827, 1.32313),)
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  0.6360194097720268 0.003983835952220649 1.898269662232681
# result is ((5613, datetime.datetime(2021, 2, 18, 12, 53, 37), 23.8403, 32.7791, 24.8887, 17.7929, 32.1011, 33.593, 29.2211, 13.9135, 25.3623, 31.3555, 30.9827, 29.763, 28.0697, 26.5803, 33.4234, 32.5418, 31.9655, 31.6944, 31.6605),)
# cop of system is: 1.1049198982198842
# kwh heat addition is : 9.639288940090792e-05
# electricity in khW is: 8.723970810572306e-05
# load in kWh is: 0.0004749942973209218
# cop of system is: 1.1049198982198842
# kwh heat addition is : 9.639288940090792e-05
# electricity in khW is: 8.723970810572306e-05
# RangeIndex(start=0, stop=22, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((137, datetime.datetime(2021, 2, 18, 13, 53, 42), -0.463734, 1.32313),)
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  0.6340193487350078 0.003971308166207377 -0.4637337145910134
# result is ((5615, datetime.datetime(2021, 2, 18, 12, 53, 41), 23.8064, 32.7791, 24.8887, 17.7929, 32.0672, 33.593, 29.2888, 13.9135, 25.3623, 31.3555, 30.9827, 29.763, 28.0697, 26.5465, 33.3895, 32.5757, 31.9655, 31.6944, 31.6266),)
# cop of system is: 0.9883286001567406
# kwh heat addition is : 9.172849704716012e-05
# electricity in khW is: 9.281173997455173e-05
# load in kWh is: 0.000488846725340813
# cop of system is: 0.9883286001567406
# kwh heat addition is : 9.172849704716012e-05
# electricity in khW is: 9.281173997455173e-05
# RangeIndex(start=0, stop=23, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((143, datetime.datetime(2021, 2, 18, 13, 53, 45), 1.89827, 1.32313),)
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  0.6360194097720268 0.003983835952220649 1.898269662232681
# result is ((5617, datetime.datetime(2021, 2, 18, 12, 53, 44), 23.8064, 32.7452, 24.9225, 17.7592, 32.0672, 33.559, 29.3227, 13.8798, 25.4299, 31.3555, 31.0166, 29.763, 28.0697, 26.5803, 33.4234, 32.5418, 31.9316, 31.6944, 31.6605),)
# cop of system is: 1.089305613168551
# kwh heat addition is : 0.00010592571432971045
# electricity in khW is: 9.724150233798557e-05
# load in kWh is: 0.0004991068299913706
# cop of system is: 1.089305613168551
# kwh heat addition is : 0.00010592571432971045
# electricity in khW is: 9.724150233798557e-05
# RangeIndex(start=0, stop=24, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((151, datetime.datetime(2021, 2, 18, 13, 53, 49), -0.463734, 2.90122),)
# flow rates load is =  0.6380194708090458 0.004002129411673854 2.9012208599907954
# flow rates HP is =  0.6340193487350078 0.003971308166207377 -0.4637337145910134
# result is ((5619, datetime.datetime(2021, 2, 18, 12, 53, 48), 23.8403, 32.7791, 24.9225, 17.7929, 32.0672, 33.559, 29.3904, 13.8798, 25.4637, 31.3555, 30.9827, 29.763, 28.0697, 26.5803, 33.4234, 32.5418, 31.9994, 31.6944, 31.6605),)
# cop of system is: 0.9796723759978525
# kwh heat addition is : 0.00010128152027321937
# electricity in khW is: 0.00010338305208418104
# load in kWh is: 0.0005289771795826725
# cop of system is: 0.9796723759978525
# kwh heat addition is : 0.00010128152027321937
# electricity in khW is: 0.00010338305208418104
# RangeIndex(start=0, stop=25, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((158, datetime.datetime(2021, 2, 18, 13, 53, 52), -0.463734, 1.32313),)
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  0.6340193487350078 0.003971308166207377 -0.4637337145910134
# result is ((5621, datetime.datetime(2021, 2, 18, 12, 53, 51), 23.8064, 32.7791, 24.9225, 17.7592, 32.0672, 33.593, 29.4581, 13.9135, 25.5314, 31.3555, 31.0166, 29.763, 28.0359, 26.5803, 33.4234, 32.5418, 31.9994, 31.6944, 31.6944),)
# cop of system is: 0.9074286541341163
# kwh heat addition is : 9.779821160384377e-05
# electricity in khW is: 0.00010777509742312961
# load in kWh is: 0.0005391506438855332
# cop of system is: 0.9074286541341163
# kwh heat addition is : 9.779821160384377e-05
# electricity in khW is: 0.00010777509742312961
# RangeIndex(start=0, stop=26, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((163, datetime.datetime(2021, 2, 18, 13, 53, 55), -0.463734, 0.534077),)
# flow rates load is =  0.6320192876979889 0.003964491830999805 0.5340774213713702
# flow rates HP is =  0.6340193487350078 0.003971308166207377 -0.4637337145910134
# result is ((5622, datetime.datetime(2021, 2, 18, 12, 53, 53), 23.8064, 32.7791, 24.8887, 17.7929, 32.0333, 33.559, 29.4243, 13.9135, 25.5652, 31.3216, 30.9827, 29.763, 28.0697, 26.5465, 33.3895, 32.5079, 31.9316, 31.6944, 31.6266),)
# cop of system is: 0.8611244761510028
# kwh heat addition is : 9.546601542696987e-05
# electricity in khW is: 0.0001108620391951667
# load in kWh is: 0.0005418651595140879
# cop of system is: 0.8611244761510028
# kwh heat addition is : 9.546601542696987e-05
# electricity in khW is: 0.0001108620391951667
# RangeIndex(start=0, stop=27, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((169, datetime.datetime(2021, 2, 18, 13, 53, 57), -5.18774, 1.32313),)
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  0.6300192266609699 0.003946252594180832 -5.187740468238238
# result is ((5624, datetime.datetime(2021, 2, 18, 12, 53, 56), 23.8064, 32.7791, 24.9225, 17.7929, 32.0333, 33.593, 29.5259, 13.9135, 25.6329, 31.3216, 30.9827, 29.763, 28.0359, 26.5803, 33.4234, 32.5757, 31.9655, 31.6944, 31.6266),)
# cop of system is: 0.49124462752481496
# kwh heat addition is : 5.6498606375372074e-05
# electricity in khW is: 0.00011501114355193244
# load in kWh is: 0.0005519091060077812
# cop of system is: 0.49124462752481496
# kwh heat addition is : 5.6498606375372074e-05
# electricity in khW is: 0.00011501114355193244
# RangeIndex(start=0, stop=28, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((174, datetime.datetime(2021, 2, 18, 13, 53, 59), 4.26027, 1.32313),)
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  0.6380194708090458 0.003996363738233922 4.260273039056376
# result is ((5625, datetime.datetime(2021, 2, 18, 12, 53, 58), 23.8064, 32.7791, 24.8887, 17.7929, 32.0333, 33.593, 29.5598, 13.9135, 25.6329, 31.3893, 30.9827, 29.7291, 28.0697, 26.5803, 33.4234, 32.5418, 31.9655, 31.6944, 31.6944),)
# cop of system is: 0.6617611293038522
# kwh heat addition is : 7.79242482502335e-05
# electricity in khW is: 0.00011775283376375835
# load in kWh is: 0.00055860507033691
# cop of system is: 0.6617611293038522
# kwh heat addition is : 7.79242482502335e-05
# electricity in khW is: 0.00011775283376375835
# RangeIndex(start=0, stop=29, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((181, datetime.datetime(2021, 2, 18, 13, 54, 3), -2.82574, 0.534077),)
# flow rates load is =  0.6320192876979889 0.003964491830999805 0.5340774213713702
# flow rates HP is =  0.6320192876979889 0.003958780380194105 -2.825737091414544
# result is ((5627, datetime.datetime(2021, 2, 18, 12, 54, 2), 23.8403, 32.7791, 24.9225, 17.7929, 32.0333, 33.559, 29.5598, 13.9135, 25.6667, 31.3893, 30.9827, 29.7969, 28.0359, 26.5803, 33.3895, 32.5418, 31.9655, 31.6944, 31.6605),)
# cop of system is: 0.40065220981660965
# kwh heat addition is : 4.9625095110747444e-05
# electricity in khW is: 0.0001238607797357771
# load in kWh is: 0.0005639644050271088
# cop of system is: 0.40065220981660965
# kwh heat addition is : 4.9625095110747444e-05
# electricity in khW is: 0.0001238607797357771
# RangeIndex(start=0, stop=30, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((186, datetime.datetime(2021, 2, 18, 13, 54, 5), -0.463734, -0.25497),)
# flow rates load is =  0.6300192266609699 0.003951945970775122 -0.25497039150178974
# flow rates HP is =  0.6340193487350078 0.003971308166207377 -0.4637337145910134
# result is ((5628, datetime.datetime(2021, 2, 18, 12, 54, 3), 23.8064, 32.7452, 24.8887, 17.7592, 32.0333, 33.593, 29.6275, 13.9135, 25.7006, 31.3555, 30.9827, 29.7291, 28.0697, 26.5803, 33.3895, 32.5757, 31.9994, 31.6944, 31.6266),)
# cop of system is: 0.3865278020554956
# kwh heat addition is : 4.846400699964979e-05
# electricity in khW is: 0.00012538297825389437
# load in kWh is: 0.000563324786135587
# cop of system is: 0.3865278020554956
# kwh heat addition is : 4.846400699964979e-05
# electricity in khW is: 0.00012538297825389437
# RangeIndex(start=0, stop=31, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((192, datetime.datetime(2021, 2, 18, 13, 54, 7), -2.82574, -0.25497),)
# flow rates load is =  0.6300192266609699 0.003951945970775122 -0.25497039150178974
# flow rates HP is =  0.6320192876979889 0.003958780380194105 -2.825737091414544
# result is ((5630, datetime.datetime(2021, 2, 18, 12, 54, 7), 23.8064, 32.8131, 24.8887, 17.7929, 31.9994, 33.559, 29.6614, 13.9135, 25.7006, 31.3893, 30.9827, 29.763, 28.0697, 26.5803, 33.3895, 32.5418, 31.9316, 31.6605, 31.6605),)
# cop of system is: 0.15241740419247368
# kwh heat addition is : 1.9919304243744195e-05
# electricity in khW is: 0.00013068917128774855
# load in kWh is: 0.0005607773323333799
# cop of system is: 0.15241740419247368
# kwh heat addition is : 1.9919304243744195e-05
# electricity in khW is: 0.00013068917128774855
# RangeIndex(start=0, stop=32, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((199, datetime.datetime(2021, 2, 18, 13, 54, 10), -0.463734, 2.11217),)
# flow rates load is =  0.6360194097720268 0.003989583551449171 2.1121730471176354
# flow rates HP is =  0.6340193487350078 0.003971308166207377 -0.4637337145910134
# result is ((5632, datetime.datetime(2021, 2, 18, 12, 54, 10), 23.8403, 32.7791, 24.9225, 17.7929, 31.9994, 33.593, 29.6953, 13.9472, 25.7682, 31.3555, 30.9827, 29.763, 28.0359, 26.5465, 33.3895, 32.5418, 31.9655, 31.6944, 31.6605),)
# cop of system is: 0.12149920316475372
# kwh heat addition is : 1.6436158701375886e-05
# electricity in khW is: 0.0001352779135439131
# load in kWh is: 0.0005765354835565244
# cop of system is: 0.12149920316475372
# kwh heat addition is : 1.6436158701375886e-05
# electricity in khW is: 0.0001352779135439131
# RangeIndex(start=0, stop=33, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((206, datetime.datetime(2021, 2, 18, 13, 54, 14), 1.89827, 2.11217),)
# flow rates load is =  0.6360194097720268 0.003989583551449171 2.1121730471176354
# flow rates HP is =  0.6360194097720268 0.003983835952220649 1.898269662232681
# result is ((5634, datetime.datetime(2021, 2, 18, 12, 54, 14), 23.8403, 32.7791, 24.9225, 17.7929, 31.9655, 33.593, 29.6953, 13.8798, 25.8359, 31.3555, 30.9827, 29.763, 28.0359, 26.5803, 33.3895, 32.5079, 31.9655, 31.6266, 31.6605),)
# cop of system is: 0.2507753339534817
# kwh heat addition is : 3.544692372788143e-05
# electricity in khW is: 0.00014134932319323222
# load in kWh is: 0.000597362587542527
# cop of system is: 0.2507753339534817
# kwh heat addition is : 3.544692372788143e-05
# electricity in khW is: 0.00014134932319323222
# RangeIndex(start=0, stop=34, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((213, datetime.datetime(2021, 2, 18, 13, 54, 17), 1.89827, 1.32313),)
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  0.6360194097720268 0.003983835952220649 1.898269662232681
# result is ((5635, datetime.datetime(2021, 2, 18, 12, 54, 15), 23.8064, 32.7791, 24.8887, 17.7929, 31.9994, 33.559, 29.7291, 13.9472, 25.8359, 31.3893, 31.0166, 29.763, 28.0697, 26.5803, 33.3895, 32.5079, 31.9994, 31.6944, 31.6605),)
# cop of system is: 0.2819830832469654
# kwh heat addition is : 4.022028515237831e-05
# electricity in khW is: 0.00014263368103239273
# load in kWh is: 0.000600609963851212
# cop of system is: 0.2819830832469654
# kwh heat addition is : 4.022028515237831e-05
# electricity in khW is: 0.00014263368103239273
# RangeIndex(start=0, stop=35, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((218, datetime.datetime(2021, 2, 18, 13, 54, 19), 6.62228, 1.32313),)
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  0.6400195318460646 0.004008891524247195 6.622276415880069
# result is ((5637, datetime.datetime(2021, 2, 18, 12, 54, 19), 23.8064, 32.7791, 24.8887, 17.7929, 31.9655, 33.559, 29.8307, 13.9135, 25.9036, 31.3555, 30.9827, 29.763, 28.0359, 26.5465, 33.4234, 32.5418, 31.9655, 31.6944, 31.6605),)
# cop of system is: 0.7194785118113907
# kwh heat addition is : 0.00010682940695383648
# electricity in khW is: 0.00014848172002368505
# load in kWh is: 0.0006134843804432807
# cop of system is: 0.7194785118113907
# kwh heat addition is : 0.00010682940695383648
# electricity in khW is: 0.00014848172002368505
# RangeIndex(start=0, stop=36, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((223, datetime.datetime(2021, 2, 18, 13, 54, 22), 4.26027, 0.534077),)
# flow rates load is =  0.6320192876979889 0.003964491830999805 0.5340774213713702
# flow rates HP is =  0.6380194708090458 0.003996363738233922 4.260273039056376
# result is ((5638, datetime.datetime(2021, 2, 18, 12, 54, 21), 23.8064, 32.7791, 24.8887, 17.7929, 31.9655, 33.593, 29.7969, 13.9135, 25.9374, 31.3893, 30.9488, 29.763, 28.0359, 26.5803, 33.4234, 32.5079, 31.9655, 31.6605, 31.6944),)
# cop of system is: 0.8473050784598948
# kwh heat addition is : 0.0001282550488286979
# electricity in khW is: 0.0001513682050175137
# load in kWh is: 0.0006160826939811741
# cop of system is: 0.8473050784598948
# kwh heat addition is : 0.0001282550488286979
# electricity in khW is: 0.0001513682050175137
# RangeIndex(start=0, stop=37, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((230, datetime.datetime(2021, 2, 18, 13, 54, 25), 1.89827, 0.534077),)
# flow rates load is =  0.6320192876979889 0.003964491830999805 0.5340774213713702
# flow rates HP is =  0.6360194097720268 0.003983835952220649 1.898269662232681
# result is ((5640, datetime.datetime(2021, 2, 18, 12, 54, 24), 23.8403, 32.7452, 24.8887, 17.7929, 31.9316, 33.593, 29.8307, 13.9135, 25.9712, 31.3893, 30.9827, 29.763, 28.0697, 26.5465, 33.4234, 32.5418, 31.9655, 31.6605, 31.6605),)
# cop of system is: 0.9129332079798353
# kwh heat addition is : 0.00014251294111964507
# electricity in khW is: 0.0001561044552591112
# load in kWh is: 0.0006199627724305147
# cop of system is: 0.9129332079798353
# kwh heat addition is : 0.00014251294111964507
# electricity in khW is: 0.0001561044552591112
# RangeIndex(start=0, stop=38, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((236, datetime.datetime(2021, 2, 18, 13, 54, 27), -5.18774, 0.534077),)
# flow rates load is =  0.6320192876979889 0.003964491830999805 0.5340774213713702
# flow rates HP is =  0.6300192266609699 0.003946252594180832 -5.187740468238238
# result is ((5641, datetime.datetime(2021, 2, 18, 12, 54, 26), 23.8403, 32.7791, 24.9225, 17.8267, 31.9655, 33.559, 29.8307, 13.9135, 25.9712, 31.3555, 30.9827, 29.7291, 28.0359, 26.5465, 33.3895, 32.5079, 31.9655, 31.6944, 31.6944),)
# cop of system is: 0.7339079905564494
# kwh heat addition is : 0.00011653588500840374
# electricity in khW is: 0.00015878814034991795
# load in kWh is: 0.0006225379523318421
# cop of system is: 0.7339079905564494
# kwh heat addition is : 0.00011653588500840374
# electricity in khW is: 0.00015878814034991795
# RangeIndex(start=0, stop=39, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((243, datetime.datetime(2021, 2, 18, 13, 54, 31), -0.463734, 1.32313),)
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  0.6340193487350078 0.003971308166207377 -0.4637337145910134
# result is ((5643, datetime.datetime(2021, 2, 18, 12, 54, 29), 23.8403, 32.7791, 24.9225, 17.7929, 31.9316, 33.559, 29.8646, 13.9135, 26.0389, 31.3555, 30.9827, 29.763, 28.0359, 26.5803, 33.3895, 32.5079, 31.9655, 31.6605, 31.6605),)
# cop of system is: 0.6926200192817985
# kwh heat addition is : 0.00011305273946603543
# electricity in khW is: 0.00016322476440005834
# load in kWh is: 0.0006320213067992059
# cop of system is: 0.6926200192817985
# kwh heat addition is : 0.00011305273946603543
# electricity in khW is: 0.00016322476440005834
# RangeIndex(start=0, stop=40, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((248, datetime.datetime(2021, 2, 18, 13, 54, 33), -0.463734, 1.32313),)
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  0.6340193487350078 0.003971308166207377 -0.4637337145910134
# result is ((5645, datetime.datetime(2021, 2, 18, 12, 54, 33), 23.8064, 32.7791, 24.8887, 17.7929, 31.9316, 33.593, 29.9324, 13.8798, 26.0728, 31.3555, 30.9827, 29.7291, 28.0359, 26.5465, 33.4234, 32.5079, 31.9655, 31.6944, 31.6605),)
# cop of system is: 0.6399290327664536
# kwh heat addition is : 0.00010838834711228762
# electricity in khW is: 0.00016937557379404706
# load in kWh is: 0.0006446653448737167
# cop of system is: 0.6399290327664536
# kwh heat addition is : 0.00010838834711228762
# electricity in khW is: 0.00016937557379404706
# RangeIndex(start=0, stop=41, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((255, datetime.datetime(2021, 2, 18, 13, 54, 36), 1.89827, 1.32313),)
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  0.6360194097720268 0.003983835952220649 1.898269662232681
# result is ((5647, datetime.datetime(2021, 2, 18, 12, 54, 36), 23.8403, 32.7791, 24.8887, 17.7929, 31.9316, 33.559, 29.9324, 13.9135, 26.1066, 31.3893, 30.9827, 29.763, 28.0359, 26.5465, 33.3895, 32.5418, 31.9655, 31.6944, 31.6605),)
# cop of system is: 0.7082077542802183
# kwh heat addition is : 0.00012270776076117576
# electricity in khW is: 0.0001732652036348979
# load in kWh is: 0.000654062430405033
# cop of system is: 0.7082077542802183
# kwh heat addition is : 0.00012270776076117576
# electricity in khW is: 0.0001732652036348979
# RangeIndex(start=0, stop=42, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((263, datetime.datetime(2021, 2, 18, 13, 54, 40), -0.463734, 1.32313),)
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  0.6340193487350078 0.003971308166207377 -0.4637337145910134
# result is ((5649, datetime.datetime(2021, 2, 18, 12, 54, 40), 23.8064, 32.7791, 24.9225, 17.7929, 31.9316, 33.5251, 29.9662, 13.9135, 26.1066, 31.3555, 30.9827, 29.763, 28.0359, 26.5465, 33.3895, 32.5079, 31.9655, 31.6944, 31.6605),)
# cop of system is: 0.6592153939497423
# kwh heat addition is : 0.00011806334920200829
# electricity in khW is: 0.0001790967721409268
# load in kWh is: 0.0006665348829508025
# cop of system is: 0.6592153939497423
# kwh heat addition is : 0.00011806334920200829
# electricity in khW is: 0.0001790967721409268
# RangeIndex(start=0, stop=43, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((269, datetime.datetime(2021, 2, 18, 13, 54, 43), -5.18774, 1.32313),)
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  0.6300192266609699 0.003946252594180832 -5.187740468238238
# result is ((5651, datetime.datetime(2021, 2, 18, 12, 54, 43), 23.8403, 32.7791, 24.8887, 17.7592, 31.8977, 33.593, 30.0001, 13.8798, 26.1404, 31.3555, 30.9827, 29.763, 28.002, 26.5465, 33.4234, 32.5418, 31.9655, 31.6944, 31.6605),)
# cop of system is: 0.43040103960884707
# kwh heat addition is : 7.893013059469622e-05
# electricity in khW is: 0.00018338740693198312
# load in kWh is: 0.0006759317738485066
# cop of system is: 0.43040103960884707
# kwh heat addition is : 7.893013059469622e-05
# electricity in khW is: 0.00018338740693198312
# RangeIndex(start=0, stop=44, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((276, datetime.datetime(2021, 2, 18, 13, 54, 47), -0.463734, 1.32313),)
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  0.6340193487350078 0.003971308166207377 -0.4637337145910134
# result is ((5653, datetime.datetime(2021, 2, 18, 12, 54, 46), 23.8403, 32.7791, 24.8887, 17.7929, 31.9316, 33.559, 30.034, 13.8798, 26.2081, 31.3893, 30.9827, 29.7291, 28.0359, 26.5465, 33.3895, 32.5418, 31.9655, 31.7283, 31.6266),)
# cop of system is: 0.4018430730730766
# kwh heat addition is : 7.543200015818388e-05
# electricity in khW is: 0.0001877150689231025
# load in kWh is: 0.0006851995494419748
# cop of system is: 0.4018430730730766
# kwh heat addition is : 7.543200015818388e-05
# electricity in khW is: 0.0001877150689231025
# RangeIndex(start=0, stop=45, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((281, datetime.datetime(2021, 2, 18, 13, 54, 49), -0.463734, 1.32313),)
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  0.6340193487350078 0.003971308166207377 -0.4637337145910134
# result is ((5654, datetime.datetime(2021, 2, 18, 12, 54, 48), 23.8403, 32.7791, 24.9225, 17.7929, 31.8977, 33.559, 30.0679, 13.8798, 26.2081, 31.3555, 30.9827, 29.7291, 28.0697, 26.5465, 33.4234, 32.5418, 31.9655, 31.6944, 31.6605),)
# cop of system is: 0.3836939302309584
# kwh heat addition is : 7.310990312993834e-05
# electricity in khW is: 0.00019054224570592247
# load in kWh is: 0.000691378066504287
# cop of system is: 0.3836939302309584
# kwh heat addition is : 7.310990312993834e-05
# electricity in khW is: 0.00019054224570592247
# RangeIndex(start=0, stop=46, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((288, datetime.datetime(2021, 2, 18, 13, 54, 52), -0.463734, -0.25497),)
# flow rates load is =  0.6300192266609699 0.003951945970775122 -0.25497039150178974
# flow rates HP is =  0.6340193487350078 0.003971308166207377 -0.4637337145910134
# result is ((5656, datetime.datetime(2021, 2, 18, 12, 54, 52), 23.8403, 32.7791, 24.8887, 17.7929, 31.8977, 33.559, 30.1018, 13.8798, 26.2758, 31.3555, 30.9827, 29.7291, 28.0359, 26.5465, 33.4234, 32.5079, 31.9655, 31.6944, 31.6605),)
# cop of system is: 0.34801339160149947
# kwh heat addition is : 6.844572921458855e-05
# electricity in khW is: 0.0001966755615340339
# load in kWh is: 0.0006890189827128499
# cop of system is: 0.34801339160149947
# kwh heat addition is : 6.844572921458855e-05
# electricity in khW is: 0.0001966755615340339
# RangeIndex(start=0, stop=47, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((296, datetime.datetime(2021, 2, 18, 13, 54, 56), -2.82574, 0.534077),)
# flow rates load is =  0.6320192876979889 0.003964491830999805 0.5340774213713702
# flow rates HP is =  0.6320192876979889 0.003958780380194105 -2.825737091414544
# result is ((5658, datetime.datetime(2021, 2, 18, 12, 54, 55), 23.8064, 32.7791, 24.9225, 17.7929, 31.8977, 33.559, 30.1695, 13.9135, 26.3096, 31.3555, 30.9827, 29.7291, 28.0697, 26.5465, 33.3895, 32.5079, 31.9655, 31.6944, 31.6944),)
# cop of system is: 0.2352917926045492
# kwh heat addition is : 4.722037035410246e-05
# electricity in khW is: 0.00020068855709499785
# load in kWh is: 0.0006927077244343468
# cop of system is: 0.2352917926045492
# kwh heat addition is : 4.722037035410246e-05
# electricity in khW is: 0.00020068855709499785
# RangeIndex(start=0, stop=48, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((302, datetime.datetime(2021, 2, 18, 13, 54, 59), 1.89827, -1.04402),)
# flow rates load is =  0.6280191656239509 0.003939400110550439 -1.0440182043749497
# flow rates HP is =  0.6360194097720268 0.003983835952220649 1.898269662232681
# result is ((5660, datetime.datetime(2021, 2, 18, 12, 54, 58), 23.8403, 32.7791, 24.8887, 17.7929, 31.8638, 33.559, 30.1695, 13.9135, 26.3096, 31.3893, 30.9827, 29.7291, 28.0359, 26.5803, 33.4234, 32.5418, 31.9994, 31.6944, 31.6605),)
# cop of system is: 0.3003479948469123
# kwh heat addition is : 6.153978400299059e-05
# electricity in khW is: 0.00020489493873384265
# load in kWh is: 0.0006854969468309957
# cop of system is: 0.3003479948469123
# kwh heat addition is : 6.153978400299059e-05
# electricity in khW is: 0.00020489493873384265
# RangeIndex(start=0, stop=49, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((309, datetime.datetime(2021, 2, 18, 13, 55, 3), 1.89827, -0.25497),)
# flow rates load is =  0.6300192266609699 0.003951945970775122 -0.25497039150178974
# flow rates HP is =  0.6360194097720268 0.003983835952220649 1.898269662232681
# result is ((5662, datetime.datetime(2021, 2, 18, 12, 55, 2), 23.8403, 32.7791, 24.8887, 17.7929, 31.8638, 33.559, 30.2034, 13.9135, 26.4111, 31.3555, 30.9827, 29.7291, 28.0359, 26.5465, 33.4234, 32.5079, 31.9994, 31.6605, 31.6605),)
# cop of system is: 0.3830559824583864
# kwh heat addition is : 8.063233553484143e-05
# electricity in khW is: 0.0002104975231488546
# load in kWh is: 0.0006831821291157147
# cop of system is: 0.3830559824583864
# kwh heat addition is : 8.063233553484143e-05
# electricity in khW is: 0.0002104975231488546
# RangeIndex(start=0, stop=50, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((317, datetime.datetime(2021, 2, 18, 13, 55, 6), 1.89827, -0.25497),)
# flow rates load is =  0.6300192266609699 0.003951945970775122 -0.25497039150178974
# flow rates HP is =  0.6360194097720268 0.003983835952220649 1.898269662232681
# result is ((5664, datetime.datetime(2021, 2, 18, 12, 55, 5), 23.8064, 32.7791, 24.9225, 17.7929, 31.83, 33.559, 30.2373, 13.8798, 26.4111, 31.3555, 30.9827, 29.7291, 28.0359, 26.5465, 33.4234, 32.5079, 31.9655, 31.6944, 31.6605),)
# cop of system is: 0.4420320251714316
# kwh heat addition is : 9.489107705657753e-05
# electricity in khW is: 0.00021467014074325562
# load in kWh is: 0.000681446015829254
# cop of system is: 0.4420320251714316
# kwh heat addition is : 9.489107705657753e-05
# electricity in khW is: 0.00021467014074325562
# RangeIndex(start=0, stop=51, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((324, datetime.datetime(2021, 2, 18, 13, 55, 10), -0.463734, -0.25497),)
# flow rates load is =  0.6300192266609699 0.003951945970775122 -0.25497039150178974
# flow rates HP is =  0.6340193487350078 0.003971308166207377 -0.4637337145910134
# result is ((5666, datetime.datetime(2021, 2, 18, 12, 55, 9), 23.8403, 32.7791, 24.8887, 17.7592, 31.83, 33.559, 30.305, 13.8798, 26.4788, 31.3555, 30.9827, 29.7291, 28.0359, 26.5465, 33.3895, 32.5079, 31.9655, 31.6605, 31.6605),)
# cop of system is: 0.4087515296433432
# kwh heat addition is : 9.022690314122774e-05
# electricity in khW is: 0.0002207377749019199
# load in kWh is: 0.0006791533413763639
# cop of system is: 0.4087515296433432
# kwh heat addition is : 9.022690314122774e-05
# electricity in khW is: 0.0002207377749019199
# RangeIndex(start=0, stop=52, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((331, datetime.datetime(2021, 2, 18, 13, 55, 13), 1.89827, -1.04402),)
# flow rates load is =  0.6280191656239509 0.003939400110550439 -1.0440182043749497
# flow rates HP is =  0.6360194097720268 0.003983835952220649 1.898269662232681
# result is ((5668, datetime.datetime(2021, 2, 18, 12, 55, 12), 23.8403, 32.7791, 24.8887, 17.7929, 31.83, 33.559, 30.305, 13.8798, 26.5127, 31.3893, 30.9827, 29.7291, 28.0359, 26.5465, 33.3895, 32.5418, 31.9655, 31.6605, 31.6266),)
# cop of system is: 0.4636854129174984
# kwh heat addition is : 0.00010454631679011587
# electricity in khW is: 0.00022546820296181575
# load in kWh is: 0.0006721465883586594
# cop of system is: 0.4636854129174984
# kwh heat addition is : 0.00010454631679011587
# electricity in khW is: 0.00022546820296181575
# RangeIndex(start=0, stop=53, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((336, datetime.datetime(2021, 2, 18, 13, 55, 15), -0.463734, 1.32313),)
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  0.6340193487350078 0.003971308166207377 -0.4637337145910134
# result is ((5669, datetime.datetime(2021, 2, 18, 12, 55, 14), 23.8741, 32.7791, 24.9225, 17.7929, 31.83, 33.559, 30.3389, 13.9135, 26.5465, 31.3555, 30.9827, 29.7291, 28.0697, 26.5127, 33.4234, 32.5418, 31.9655, 31.6944, 31.6266),)
# cop of system is: 0.4473146542958889
# kwh heat addition is : 0.00010222432821710478
# electricity in khW is: 0.0002285289051797655
# load in kWh is: 0.0006780378656046931
# cop of system is: 0.4473146542958889
# kwh heat addition is : 0.00010222432821710478
# electricity in khW is: 0.0002285289051797655
# RangeIndex(start=0, stop=54, step=1)
# ________________________________________________________________
# ...
# load in kWh is: 0.014182234475436468
# cop of system is: 0.585862060578606
# kwh heat addition is : 0.003702945247640246
# electricity in khW is: 0.006320506987571721
# RangeIndex(start=0, stop=1380, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((8926, datetime.datetime(2021, 2, 18, 15, 4, 44), -0.463734, 0.534077),)
# flow rates load is =  0.6320192876979889 0.003964491830999805 0.5340774213713702
# flow rates HP is =  0.6340193487350078 0.003971308166207377 -0.4637337145910134
# result is ((8090, datetime.datetime(2021, 2, 18, 14, 4, 43), 22.5894, 32.4062, 24.7872, 17.8604, 25.2608, 33.2199, 30.881, 13.9472, 25.2946, 31.0843, 30.4405, 28.9501, 27.5958, 26.2758, 33.0165, 32.2367, 31.7961, 31.6266, 31.5249),)
# cop of system is: 0.5852275041018368
# kwh heat addition is : 0.0037006895002497328
# electricity in khW is: 0.006323505772219768
# load in kWh is: 0.014184926749196523
# cop of system is: 0.5852275041018368
# kwh heat addition is : 0.0037006895002497328
# electricity in khW is: 0.006323505772219768
# RangeIndex(start=0, stop=1381, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((8934, datetime.datetime(2021, 2, 18, 15, 4, 49), 1.89827, 16.315),)
# flow rates load is =  0.6720205084383679 0.004215409035493464 16.315033678834187
# flow rates HP is =  0.6360194097720268 0.003983835952220649 1.898269662232681
# result is ((8093, datetime.datetime(2021, 2, 18, 14, 4, 48), 22.5218, 32.4062, 24.7534, 17.8942, 25.2608, 33.1521, 30.9149, 13.9809, 25.2269, 31.1182, 30.3389, 28.9163, 27.5619, 26.2419, 32.9826, 32.3045, 31.7961, 31.6266, 31.5588),)
# cop of system is: 0.5882511878141198
# kwh heat addition is : 0.0037238785116536013
# electricity in khW is: 0.006330422426329723
# load in kWh is: 0.014390553015412288
# cop of system is: 0.5882511878141198
# kwh heat addition is : 0.0037238785116536013
# electricity in khW is: 0.006330422426329723
# RangeIndex(start=0, stop=1382, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((8940, datetime.datetime(2021, 2, 18, 15, 4, 52), 1.89827, 18.6822),)
# flow rates load is =  0.6780206915494248 0.004253046616167513 18.682177117453612
# flow rates HP is =  0.6360194097720268 0.003983835952220649 1.898269662232681
# result is ((8094, datetime.datetime(2021, 2, 18, 14, 4, 50), 22.5556, 32.3723, 24.821, 17.8604, 25.2608, 33.186, 30.881, 13.9809, 25.2608, 31.0505, 30.3389, 28.9163, 27.5619, 26.2758, 33.0843, 32.3384, 31.83, 31.5249, 31.5249),)
# cop of system is: 0.5894324719325345
# kwh heat addition is : 0.003733030669906776
# electricity in khW is: 0.006333262668185768
# load in kWh is: 0.01448473276271789
# cop of system is: 0.5894324719325345
# kwh heat addition is : 0.003733030669906776
# electricity in khW is: 0.006333262668185768
# RangeIndex(start=0, stop=1383, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((8948, datetime.datetime(2021, 2, 18, 15, 4, 55), 1.89827, 17.1041),)
# flow rates load is =  0.6740205694753869 0.004227954895718147 17.104081491707348
# flow rates HP is =  0.6360194097720268 0.003983835952220649 1.898269662232681
# result is ((8097, datetime.datetime(2021, 2, 18, 14, 4, 55), 22.5218, 32.4062, 24.7872, 17.8942, 25.2269, 33.186, 30.9149, 13.9809, 25.1931, 31.0843, 30.4067, 28.9163, 27.5619, 26.3096, 32.9826, 32.2367, 31.83, 31.5927, 31.4571),)
# cop of system is: 0.5923779642562894
# kwh heat addition is : 0.0037561172627729265
# electricity in khW is: 0.006340744405455063
# load in kWh is: 0.014702155533078326
# cop of system is: 0.5923779642562894
# kwh heat addition is : 0.0037561172627729265
# electricity in khW is: 0.006340744405455063
# RangeIndex(start=0, stop=1384, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((8953, datetime.datetime(2021, 2, 18, 15, 4, 58), 1.89827, 17.1041),)
# flow rates load is =  0.6740205694753869 0.004227954895718147 17.104081491707348
# flow rates HP is =  0.6360194097720268 0.003983835952220649 1.898269662232681
# result is ((8098, datetime.datetime(2021, 2, 18, 14, 4, 57), 22.488, 32.4062, 24.7534, 17.8604, 25.2269, 33.186, 30.9827, 13.9809, 25.2608, 31.0843, 30.4405, 28.9163, 27.5958, 26.2419, 33.0504, 32.2028, 31.83, 31.5927, 31.5249),)
# cop of system is: 0.5936426376071385
# kwh heat addition is : 0.003765393295774374
# electricity in khW is: 0.006342861946291398
# load in kWh is: 0.014788379856006863
# cop of system is: 0.5936426376071385
# kwh heat addition is : 0.003765393295774374
# electricity in khW is: 0.006342861946291398
# RangeIndex(start=0, stop=1385, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((8960, datetime.datetime(2021, 2, 18, 15, 5, 2), 4.26027, 16.315),)
# flow rates load is =  0.6720205084383679 0.004215409035493464 16.315033678834187
# flow rates HP is =  0.6380194708090458 0.003996363738233922 4.260273039056376
# result is ((8100, datetime.datetime(2021, 2, 18, 14, 5), 22.488, 32.3384, 24.7196, 17.8604, 25.2608, 33.2199, 30.881, 13.9809, 25.1931, 31.0505, 30.4067, 28.9501, 27.5958, 26.2758, 33.0843, 32.2367, 31.83, 31.5927, 31.5588),)
# cop of system is: 0.5982259310449306
# kwh heat addition is : 0.003796481760866255
# electricity in khW is: 0.006346234029399028
# load in kWh is: 0.014913343176200801
# cop of system is: 0.5982259310449306
# kwh heat addition is : 0.003796481760866255
# electricity in khW is: 0.006346234029399028
# RangeIndex(start=0, stop=1386, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((8967, datetime.datetime(2021, 2, 18, 15, 5, 6), -0.463734, 16.315),)
# flow rates load is =  0.6720205084383679 0.004215409035493464 16.315033678834187
# flow rates HP is =  0.6340193487350078 0.003971308166207377 -0.4637337145910134
# result is ((8102, datetime.datetime(2021, 2, 18, 14, 5, 4), 22.488, 32.3723, 24.821, 17.8942, 25.2269, 33.186, 30.881, 13.9809, 25.1931, 31.0843, 30.3728, 28.9501, 27.5958, 26.2419, 33.0843, 32.2367, 31.8638, 31.5927, 31.5588),)
# cop of system is: 0.597114159756452
# kwh heat addition is : 0.0037920097339798845
# electricity in khW is: 0.006350560729503636
# load in kWh is: 0.015079257251046424
# cop of system is: 0.597114159756452
# kwh heat addition is : 0.0037920097339798845
# electricity in khW is: 0.006350560729503636
# RangeIndex(start=0, stop=1387, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((8975, datetime.datetime(2021, 2, 18, 15, 5, 9), -0.463734, 18.6822),)
# flow rates load is =  0.6780206915494248 0.004253046616167513 18.682177117453612
# flow rates HP is =  0.6340193487350078 0.003971308166207377 -0.4637337145910134
# result is ((8105, datetime.datetime(2021, 2, 18, 14, 5, 9), 22.4542, 32.4062, 24.7872, 17.8604, 25.2269, 33.186, 30.9488, 13.9809, 25.1931, 31.0843, 30.4067, 28.9163, 27.5619, 26.2419, 33.0843, 32.135, 31.7961, 31.5588, 31.4571),)
# cop of system is: 0.5955950769421541
# kwh heat addition is : 0.0037863693233547596
# electricity in khW is: 0.006357287811703157
# load in kWh is: 0.015316740375013675
# cop of system is: 0.5955950769421541
# kwh heat addition is : 0.0037863693233547596
# electricity in khW is: 0.006357287811703157
# RangeIndex(start=0, stop=1388, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((8981, datetime.datetime(2021, 2, 18, 15, 5, 12), 4.26027, 16.315),)
# flow rates load is =  0.6720205084383679 0.004215409035493464 16.315033678834187
# flow rates HP is =  0.6380194708090458 0.003996363738233922 4.260273039056376
# result is ((8106, datetime.datetime(2021, 2, 18, 14, 5, 11), 22.4542, 32.3723, 24.8548, 17.8604, 25.1931, 33.1521, 30.8471, 13.9809, 25.2269, 31.0843, 30.3389, 28.9163, 27.5619, 26.2758, 33.0165, 32.2028, 31.83, 31.5588, 31.5588),)
# cop of system is: 0.5985420431562548
# kwh heat addition is : 0.003806820341731306
# electricity in khW is: 0.0063601552894380405
# load in kWh is: 0.015398990881499982
# cop of system is: 0.5985420431562548
# kwh heat addition is : 0.003806820341731306
# electricity in khW is: 0.0063601552894380405
# RangeIndex(start=0, stop=1389, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((8986, datetime.datetime(2021, 2, 18, 15, 5, 15), -0.463734, 16.315),)
# flow rates load is =  0.6720205084383679 0.004215409035493464 16.315033678834187
# flow rates HP is =  0.6340193487350078 0.003971308166207377 -0.4637337145910134
# result is ((8108, datetime.datetime(2021, 2, 18, 14, 5, 14), 22.4542, 32.4062, 24.8548, 17.8942, 25.1931, 33.2199, 30.8471, 13.9809, 25.2269, 31.0843, 30.4405, 28.9501, 27.5619, 26.3096, 33.0504, 32.2028, 31.83, 31.5927, 31.5588),)
# cop of system is: 0.5976193374332537
# kwh heat addition is : 0.003803466122269862
# electricity in khW is: 0.006364362536536328
# load in kWh is: 0.015523422119515119
# cop of system is: 0.5976193374332537
# kwh heat addition is : 0.003803466122269862
# electricity in khW is: 0.006364362536536328
# RangeIndex(start=0, stop=1390, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((8992, datetime.datetime(2021, 2, 18, 15, 5, 18), -0.463734, 17.1041),)
# flow rates load is =  0.6740205694753869 0.004227954895718147 17.104081491707348
# flow rates HP is =  0.6340193487350078 0.003971308166207377 -0.4637337145910134
# result is ((8109, datetime.datetime(2021, 2, 18, 14, 5, 16), 22.4542, 32.4062, 24.8548, 17.8604, 25.1931, 33.2199, 30.9488, 13.9809, 25.2269, 31.0843, 30.4067, 28.9163, 27.5619, 26.2419, 32.9826, 32.135, 31.7961, 31.5249, 31.4571),)
# cop of system is: 0.5969861627362454
# kwh heat addition is : 0.0038012299759622326
# electricity in khW is: 0.006367366973029248
# load in kWh is: 0.015610388209687766
# cop of system is: 0.5969861627362454
# kwh heat addition is : 0.0038012299759622326
# electricity in khW is: 0.006367366973029248
# RangeIndex(start=0, stop=1391, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((8997, datetime.datetime(2021, 2, 18, 15, 5, 20), 4.26027, 17.8931),)
# flow rates load is =  0.6760206305124058 0.0042405007559428295 17.89312930458045
# flow rates HP is =  0.6380194708090458 0.003996363738233922 4.260273039056376
# result is ((8111, datetime.datetime(2021, 2, 18, 14, 5, 19), 22.4204, 32.3384, 24.7196, 17.8942, 25.2269, 33.1521, 30.881, 13.9809, 25.2269, 31.0843, 30.3728, 28.9163, 27.5958, 26.2758, 33.0165, 32.2028, 31.83, 31.6266, 31.491),)
# cop of system is: 0.6011993460659223
# kwh heat addition is : 0.0038323213118489417
# electricity in khW is: 0.0063744602134492715
# load in kWh is: 0.01574569767121551
# cop of system is: 0.6011993460659223
# kwh heat addition is : 0.0038323213118489417
# electricity in khW is: 0.0063744602134492715
# RangeIndex(start=0, stop=1392, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((9004, datetime.datetime(2021, 2, 18, 15, 5, 23), 4.26027, 17.1041),)
# flow rates load is =  0.6740205694753869 0.004227954895718147 17.104081491707348
# flow rates HP is =  0.6380194708090458 0.003996363738233922 4.260273039056376
# result is ((8113, datetime.datetime(2021, 2, 18, 14, 5, 23), 22.4542, 32.4062, 24.7872, 17.8604, 25.2269, 33.1521, 30.9149, 13.9809, 25.1593, 31.0843, 30.3389, 28.9163, 27.5619, 26.2419, 33.0165, 32.3045, 31.83, 31.5588, 31.5588),)
# cop of system is: 0.6071340653702688
# kwh heat addition is : 0.003873775600910706
# electricity in khW is: 0.0063804286760754106
# load in kWh is: 0.01591964192145194
# cop of system is: 0.6071340653702688
# kwh heat addition is : 0.003873775600910706
# electricity in khW is: 0.0063804286760754106
# RangeIndex(start=0, stop=1393, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((9012, datetime.datetime(2021, 2, 18, 15, 5, 27), -5.18774, 16.315),)
# flow rates load is =  0.6720205084383679 0.004215409035493464 16.315033678834187
# flow rates HP is =  0.6300192266609699 0.003946252594180832 -5.187740468238238
# result is ((8115, datetime.datetime(2021, 2, 18, 14, 5, 26), 22.4204, 32.3723, 24.7196, 17.8942, 25.1593, 33.1521, 30.881, 13.9809, 25.1931, 31.0505, 30.4067, 28.9163, 27.5619, 26.2419, 33.0843, 32.1011, 31.8638, 31.6944, 31.491),)
# cop of system is: 0.6007482833564104
# kwh heat addition is : 0.003835747178847381
# electricity in khW is: 0.006384949046240917
# load in kWh is: 0.016043549713526437
# cop of system is: 0.6007482833564104
# kwh heat addition is : 0.003835747178847381
# electricity in khW is: 0.006384949046240917
# RangeIndex(start=0, stop=1394, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((9018, datetime.datetime(2021, 2, 18, 15, 5, 30), 4.26027, 17.8931),)
# flow rates load is =  0.6760206305124058 0.0042405007559428295 17.89312930458045
# flow rates HP is =  0.6380194708090458 0.003996363738233922 4.260273039056376
# result is ((8117, datetime.datetime(2021, 2, 18, 14, 5, 30), 22.3866, 32.4062, 24.8548, 17.8942, 25.2269, 33.2199, 30.9827, 13.9809, 25.2269, 31.0843, 30.3389, 28.9163, 27.5619, 26.2419, 33.0165, 32.2706, 31.8638, 31.5588, 31.5588),)
# cop of system is: 0.6066280767451854
# kwh heat addition is : 0.0038768374553927103
# electricity in khW is: 0.006390797927114704
# load in kWh is: 0.016225505756863514
# cop of system is: 0.6066280767451854
# kwh heat addition is : 0.0038768374553927103
# electricity in khW is: 0.006390797927114704
# RangeIndex(start=0, stop=1395, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((9024, datetime.datetime(2021, 2, 18, 15, 5, 33), 4.26027, 17.8931),)
# flow rates load is =  0.6760206305124058 0.0042405007559428295 17.89312930458045
# flow rates HP is =  0.6380194708090458 0.003996363738233922 4.260273039056376
# result is ((8118, datetime.datetime(2021, 2, 18, 14, 5, 31), 22.4204, 32.3723, 24.7196, 17.8604, 25.1931, 33.1521, 30.9149, 13.9809, 25.1255, 31.0843, 30.3389, 28.9163, 27.5619, 26.2419, 32.9826, 32.1689, 31.7961, 31.6266, 31.5588),)
# cop of system is: 0.6081195649089695
# kwh heat addition is : 0.00388724734785785
# electricity in khW is: 0.006392241875065703
# load in kWh is: 0.01627119245774455
# cop of system is: 0.6081195649089695
# kwh heat addition is : 0.00388724734785785
# electricity in khW is: 0.006392241875065703
# RangeIndex(start=0, stop=1396, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((9031, datetime.datetime(2021, 2, 18, 15, 5, 36), -2.82574, 1.32313),)
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  0.6320192876979889 0.003958780380194105 -2.825737091414544
# result is ((8120, datetime.datetime(2021, 2, 18, 14, 5, 35), 22.4204, 32.3723, 24.7196, 17.8942, 25.1931, 33.1521, 30.881, 13.9809, 25.2269, 31.0843, 30.4405, 28.9163, 27.5619, 26.2758, 33.1182, 32.2706, 31.83, 31.6266, 31.5588),)
# cop of system is: 0.6030332964313524
# kwh heat addition is : 0.003859628818259665
# electricity in khW is: 0.006400357726679913
# load in kWh is: 0.016284533247938885
# cop of system is: 0.6030332964313524
# kwh heat addition is : 0.003859628818259665
# electricity in khW is: 0.006400357726679913
# RangeIndex(start=0, stop=1397, step=1)
# ________________________________________________________________
# flow from FlowDB is : ((9039, datetime.datetime(2021, 2, 18, 15, 5, 40), 1.89827, -0.25497),)
# flow rates load is =  0.6300192266609699 0.003951945970775122 -0.25497039150178974
# flow rates HP is =  0.6360194097720268 0.003983835952220649 1.898269662232681
# result is ((8123, datetime.datetime(2021, 2, 18, 14, 5, 40), 22.4204, 32.3723, 24.8548, 17.8604, 25.1593, 33.1521, 30.881, 13.9809, 25.1593, 31.0843, 30.4067, 28.9163, 27.5619, 26.2419, 32.9826, 32.135, 31.83, 31.491, 31.5249),)
# cop of system is: 0.6062229811646905
# kwh heat addition is : 0.003882411008238318
# electricity in khW is: 0.006404262340532414
# load in kWh is: 0.016281292016189334
# cop of system is: 0.6062229811646905
# kwh heat addition is : 0.003882411008238318
# electricity in khW is: 0.006404262340532414
# RangeIndex(start=0, stop=1398, step=1)
