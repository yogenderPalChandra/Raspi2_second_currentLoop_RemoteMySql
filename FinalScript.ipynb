# %%
import time
import board
import busio
import pandas as pd
from pandas import DataFrame
from matplotlib import pylab
import matplotlib.pyplot as plt
from pylab import *
import pylab
import numpy as np
import matplotlib.colors as clrs
import matplotlib.cm as cm
import matplotlib
from collections import deque
import os.path
import datetime
import time
import math
import struct
from struct import *
from pyModbusTCP.client import ModbusClient

#matplotlib.use('TkAgg')
# %matplotlib notebook
#%matplotlib inline


#import time
import sys
import sqlite3
#from time import sleep

#import adafruit_ads1x15.ads1015 as ADS
import adafruit_ads1x15.ads1115 as ADS
from adafruit_ads1x15.analog_in import AnalogIn

import MySQLdb as db

HOST = "10.208.8.122"
PORT = 3306
USER = "yogi"
PASSWORD = "bittoo"
DB = "TemaccessToRemoteRp2"
'''
try:
    connection = db.Connection(host=HOST, port=PORT,
                               user=USER, passwd=PASSWORD, db=DB)

    c = connection.cursor()
    c.execute("SELECT * from temSensor")
    result = c.fetchall()
    for item in result:
        print (item)

except Exception as e:
    print (e)
'''
connectionL = db.connect(host="10.208.8.121",
                     user="yogi",
                     passwd="bittoo",
                     db="allSensors")

#c = conn.cursor()
connectionR = db.Connection(host=HOST, port=PORT,user=USER, passwd=PASSWORD, db=DB)

cR = connectionR.cursor()
cL =connectionL.cursor()

i2c = busio.I2C(board.SCL, board.SDA)

# Create the ADC object using the I2C bus
ads = ADS.ADS1115(i2c)

ads.gain = 1


cL.execute('DROP TABLE IF EXISTS flowReadings;')
print ('table flowReadings deleted')


cL.execute('CREATE TABLE flowReadings(id INT AUTO_INCREMENT PRIMARY KEY,  \
ts TIMESTAMP DEFAULT CURRENT_TIMESTAMP, \
flowHP FLOAT, flowLoad FLOAT, watt FLOAT) ENGINE=MyISAM;')

#cvsFileName = import os.path
#os.path.exists(file_path)

lol=[[], [], [], [], []]
flowRateLoad  = []
wattMeterKw = []
################################
##Cop functions, takes Tiem stamp of both Wattmegter and Tem values
###
###############################
def flatten_watt(l_of_l):
    '''this to flatten the watt tuple/list  whish is 
    present in lol[1]
    '''
    T = l_of_l[1]
    flattend_l = [val for sublist in T for val in sublist]
    #print ('flattened list is =', flattend_l)
    return flattend_l


timePeriod_watt = []
def timeStampCreator_watt(Lol):
    '''calculating timestamp of wattmeter'''
    mHP = Lol[2]
    T = flatten_watt(Lol)
    if len(mHP) == 1:
        timeStamp = 2/3600
        timePeriod_watt.append(timeStamp)
    elif len(mHP) > 1:
        timeLast = T[-1][1]
        timeSecondLast = T[-2][1]
        timeStamp = timeLast -timeSecondLast
        timeStamp = timeStamp.total_seconds()/3600
        timePeriod_watt.append(timeStamp)
    return 

def flatten_tem(l_of_l):
    '''flatting the time lol to calculate time stamp b/w each'''
    T = l_of_l[0]
    flattend_l = [val for sublist in T for val in sublist]
    #print ('flattened list is =', flattend_l)
    return flattend_l

timePeriod_tem = []
def timeStampCreator_cop(Lol):
    '''calculatng tem time stamp to calculate accuractly the mCT '''
    mHP = Lol[2]
    T = flatten_tem(Lol)
    if len(mHP) == 1:
        timeStamp = 2/3600
        timePeriod_tem.append(timeStamp)
    elif len(mHP) > 1:
        timeLast = T[-1][1]
        timeSecondLast = T[-2][1]
        timeStamp = timeLast -timeSecondLast
        timeStamp = timeStamp.total_seconds()/3600
        timePeriod_tem.append(timeStamp)
    return 

copPlotterList = []
def Cop(Lol, time_stamp_tem, time_stamp_watt):
    '''this function takes both time stamp Tem and Watt
     because both Tem and watt are running at different timetamps
    '''
    mHP = Lol[2]
    T = flatten_tem(Lol)
    mL = Lol[3]
    watt_kW = Lol[4]
    p_LperH = [999.8473664794213 + 6.29265190e-02*x[2] - 8.42930922e-03*x[2]**2 + 6.77190849e-05*x[2]**3 \
 - 4.40840180e-07*x[2]**4 + 1.29302849e-09*x[2]**5 for x in T]
    mF_kgPerS =[ x*2.7777e-07*y for x, y in zip(p_LperH, mHP)]
    cP_kjPerkgK = [4.253264761904763 - 0.00470305*b[2] for b in T]
    mCT_kW = [c*a*(b[3]-b[4]) for c, a, b in zip(cP_kjPerkgK,mF_kgPerS, T)]
    mCT_kWh_l = [x*y for x,y in zip (time_stamp_tem, mCT_kW)]
    mCT_kWh = sum(mCT_kWh_l)
    #electricty consumed:
    watt_kW_l = [x*y for x,y in zip (time_stamp_watt,  watt_kW)]
    watt_kWh = sum(watt_kW_l)
    #cop 
    cop =mCT_kWh/watt_kWh
    copPlotterList.append(cop)
    #print ('cop of system is:', cop)
    #print ('kwh heat addition is :', mCT_kWh)
    #print ('whole kW list is:', mCT_kW)
    print ('electricity in khW is:', watt_kWh)
    
    #print ('electricity consumption kW :', watt_kW)
    return cop
############################################################

def MCT_timeStamp(Lol, time_stamp_tem):
    mHP = Lol[2]
    T = flatten_tem(Lol)
    mL = Lol[3]
    watt_kW = Lol[4]
    p_LperH = [999.8473664794213 + 6.29265190e-02*x[2] - 8.42930922e-03*x[2]**2 + 6.77190849e-05*x[2]**3 \
 - 4.40840180e-07*x[2]**4 + 1.29302849e-09*x[2]**5 for x in T]
    mF_kgPerS =[ x*2.7777e-07*y for x, y in zip(p_LperH, mHP)]
    cP_kjPerkgK = [4.253264761904763 - 0.00470305*b[2] for b in T]
    mCT_kW = [c*a*(b[3]-b[4]) for c, a, b in zip(cP_kjPerkgK,mF_kgPerS, T)]
    mCT_kWh_l = [x*y for x,y in zip (time_stamp_tem, mCT_kW)]
    mCT_kWh = sum(mCT_kWh_l)
    print ('heat addition in kwh is:', mCT_kWh)
    return mCT_kW

l_id = []
def idGenerator(Id, l_id):
    if Id not in l_id:
       l_id.append(Id) 
    #print (l_id)
    return l_id

#df_conc= None
def dfs(Lol):
    mHP = Lol[2]
    T = flatten_tem(Lol)
    mL = Lol[3]
    StartTemTestingtank = [ 'id', 'dateTime', 'Tamb', 'TtopTestTankHPCir', 'TbottomTestTankHpCir', 'TtopSourceTank', \
'TloadTankMix','TTopTestTankLoadCir', 'TloadMix', 'TbottomSourceTank', 'TbottomTestTankLoadCir']
    l_T = ['T{}'.format(x) for x in range(0,10)]
    L = StartTemTestingtank +l_T
    df_mHP = DataFrame(mHP, columns=['flowHP'])
    df_mL = DataFrame(mL, columns=['flowLoad'])
    df_tem = DataFrame(T, columns = L)
    df_conc = pd.concat([df_tem, df_mHP, df_mL], axis=1)
    return df_conc

def list2df(lis, column_name = None):
    df  = pd.DataFrame(lis, columns = [column_name]) 
    return df


def toCsv(df_full, load_kW, heatCapacity_kW, electrictyUsed_kW, COP, nDis, timePeriod_tem, timePeriod_watt ,\
         entropy_kjPerK, entropy_kJ, nStratCharging, TankEnergyTotal_kJ,\
         DisEntropy_kjPerK, DisEntropy_kJ, nStratDis, DisTankEnergyTotal_kJ):
    df_Tem_Flow_Load_capacity_conc = pd.concat([df_full, load_kW, heatCapacity_kW, electrictyUsed_kW, \
                                                COP, nDis, timePeriod_tem , \
                                                timePeriod_watt, entropy_kjPerK,\
                                               entropy_kJ,nStratCharging, \
                                               TankEnergyTotal_kJ, \
                                               DisEntropy_kjPerK, \
                                                DisEntropy_kJ, \
                                                nStratDis, \
                                                DisTankEnergyTotal_kJ], axis=1)

    file_name = 'csvFile_{}'.format(datetime.datetime.now().strftime("%Y_%m_%d"))
    suffix = '.csv'
    filePath = os.path.join(os.getcwd(), file_name + suffix)
    df_Tem_Flow_Load_capacity_conc.to_csv(filePath, header=True, na_rep=np.nan)
    #print ('gross df with NAN is: ', df_Tem_Flow_Load_capacity_conc )
    return df_Tem_Flow_Load_capacity_conc

def Load_kWh(Lol, time_stamp_tem):
    
    #mHP = Lol[2]
    T = flatten_tem(Lol)
    #d = [x[10] for x in T]
    #print ('XXXXTem tem diagnosis is :', d)
    mL = Lol[3]
    #this is density as polynomial function of T
    p_LperH = [999.8473664794213 + 6.29265190e-02*x[7] - 8.42930922e-03*x[7]**2 + 6.77190849e-05*x[7]**3 \
 - 4.40840180e-07*x[7]**4 + 1.29302849e-09*x[7]**5 for x in T]
    #print ('denisty is:', p_LperH )
    #print ('Tem is:', [x[10] for x in T])
    # this is mass flow  in kg/S =  density*V(flow rate in m^3/sec)= d * (1000^-3/3600)
    mF_kgPerS =[ x*2.7777e-07*y for x, y in zip(p_LperH, mL)]
    #this is Cp as functiono of T linear function
    cP_kjPerkgK = [4.253264761904763 - 0.00470305*b[7] for b in T]
    #print ('Cp if load function is:')
    #print ('Cp is:', cP_kjPerkgK)
    #Cp*M*deltaT
    load_mCT_kW = [c*a*(b[7]-b[10]) for c, a, b in zip(cP_kjPerkgK,mF_kgPerS, T)]
    load_mCT_kW_l = [x*y for x,y in zip (time_stamp_tem, load_mCT_kW )]
    load_mCT_kWh = sum(load_mCT_kW_l)
    print ('Load in kWh is:', load_mCT_kWh)
    #print ('Load in kW:', load_mCT_kW)
    return load_mCT_kW

def tankStrat(df):
    dfT = df.iloc[:, 11:-2]
    #print (dfT.columns)
    #print (dfT)
    dfT = dfT[['T4', 'T3', 'T2', 'T1', 'T0', 'T9', 'T8', 'T7', 'T6', 'T5']]
    dfT = dfT.rename({'T4':'T0', 'T3':'T1', 'T2':'T2', 'T1':'T3', 'T0':'T4', 'T9':'T5', 'T8':'T6',\
              'T7':'T7','T6':'T8','T5':'T9'}, axis='columns')

    return dfT
#tankStratTem = tankStrat(df_conc)

def create_color_step_obj(cmap_name, n):
    """
    Return scalarMap object with n colors in gradient from color map
    given in cmap_name.
    """
    cmap = plt.get_cmap(cmap_name)
    values = range(n)
    cNorm  = clrs.Normalize(vmin=values[0], vmax=values[-1])
    scalarMap = cm.ScalarMappable(norm=cNorm, cmap=cmap)
    return scalarMap

#import logging
#logging.getLogger().setLevel(logging.CRITICAL)

# colors
cmap_name = "jet"
scm = create_color_step_obj(cmap_name, 10)
plt.ion()
#plt.rcParams["figure.figsize"]=5,5
fig_size = plt.rcParams["figure.figsize"]
fig_size[0] = 8
fig_size[1] = 3
def plotObject(df, ax, fig, alpha =0.7, scm=None):
    ax.clear()
    for i in range (0, df.shape[1]):
        ax.plot(df.index, df.iloc[:, i], color= scm.to_rgba(i, alpha=alpha),\
                label = 'Layer ' + str(i))
        ax.legend(bbox_to_anchor=(0.4,0.8))
    fig.canvas.draw()
    ax.legend()
    #plt.legend(loc='upper left')
    return fig, ax
    
# initialize figure and interactivity
fig = plt.figure(1)
fig2 = plt.figure(2)
fig3 = plt.figure(3)
fig4 = plt.figure(4)

#Figure 1 and 2 axes initialise
ax = fig.add_subplot(121)
ax_2 = fig.add_subplot(122)
ax2 = fig2.add_subplot(122)
ax2_1 = fig2.add_subplot(121)
axTwin = ax2.twinx()

#Figure 3 axis initialies
ax3 = fig3.add_subplot(122)
ax3_1 = fig3.add_subplot(121)
ax3Twin = ax3.twinx()
fig.canvas.draw()
#plt.ion()

#Figure 4 Axes initialise
ax4 = fig4.add_subplot(122)
ax4_1 = fig4.add_subplot(121)
ax4Twin = ax4.twinx()

#fig.show()

ax.legend(loc='best')
ax.set_xlabel('Index')
ax.set_ylabel('Tem, C', color='r')
#################################
#Plot for HPin, Hpout, TmixL tem.

fig.show()
fig.canvas.draw()
ax_2.legend(loc='best')
ax_2.set_xlabel('Index')
ax_2.set_ylabel('Load in kW', color='r')
def plotObject_Tem_HpAndLoad(df, ax_2, fig):
    ax_2.clear()
    ax_2.plot(df.index, df.iloc[:, 3], label = 'Hp to Testing tank top')
    ax_2.plot(df.index, df.iloc[:, 4], label = 'Testing tank to HP Bottom')
    ax_2.plot(df.index, df.iloc[:, 8], label = 'load tem Mixed')
    
    ax_2.legend(bbox_to_anchor=(0.4,0.8))
    fig.canvas.draw()
    ax_2.legend()
    fig.savefig('Temperatures3.png')
    #plt.legend(loc='upper left')
    return fig, ax_2
##################################

#fig2 = plt.figure(2)

#plt.ion()

fig2.show()
fig2.canvas.draw()
ax2.legend(loc='best')
ax2.set_xlabel('Index')
ax2.set_ylabel('Load in kW', color='r')
def plotObject_Load(df, ax2, fig2):
    ax2.clear()
    axTwin.clear()
    ax2.plot(df.index, df.iloc[:, -15],label = 'Load in kW')
    #axTwin.plot(df.index, Nan2Zero(df).iloc[:, -11]*100, label = 'Discharge Efficiency', color = 'b')
    axTwin.plot(df.index, df.iloc[:, -11]*100, label = 'Discharge Efficiency', color = 'b')
    axTwin.set_ylabel('nDischarge',color ='b')
    #ax2.plot(df.index, COP, label = 'cop')
    #print (df.index)
    ax2.legend(bbox_to_anchor=(0.4,0.8))
    fig2.canvas.draw()
    ax2.legend()
    fig2.savefig('LoadNDiscCopHeatCapacityAndElectricty.png')
    #plt.legend(loc='upper left')
    return fig2, ax2
    
# initialize figure and interactivity
####Plot for heat_Capacity:

def Nan2Zero(df):
    #df.replace('NaN', 0)
     return df.fillna(0) 

fig2.show()
fig2.canvas.draw()
ax2_1.legend(loc='best')
ax2_1.set_xlabel('Index')
ax2_1.set_ylabel('Heat_Capacity in kW', color='r')
def plotObject_Heat_Capacity(df, ax2_1, fig2):
    ax2_1.clear()
    #axTwin = ax2_1.twinx()
    #axTwin.clear()
    
    ax2_1.plot(df.index, df.iloc[:, -14], label = 'heat_Capacity in kW')
    ax2_1.plot(df.index, df.iloc[:, -13], label = 'electrcity_kW')
    ax2_1.plot(df.index, df.iloc[:, -12], label = 'cop of system')
    #axTwin.plot(df.index, Nan2Zero(df).iloc[:, -2]*100, label = 'Discharge Efficiency', color = 'b')
    #axTwin.set_ylabel('nDischarge',color ='b')
    
    ax2_1.legend(bbox_to_anchor=(0.4,0.8))
    plt.subplots_adjust(wspace = 0.5)
    fig2.canvas.draw()
    ax2_1.legend()
    fig2.tight_layout()
    #plt.legend(loc='upper left')
    return fig2, ax2_1

###########################################
##########################################
###########################################
###########################################
###########################################
#########Discharging Strat Efficiency plots
###########################################
###########################################
###########################################
###########################################

'''
def refineDF_Discharge(df):
    #this function refine -ve or >100 values frrom nStrat
    #dropped_df = df.loc[((df<110) | (df>0)).any(1)]
    #refined_df = df['nStratCharging'].where(df['nStratCharging'] >=110, 0.01, inplace=True)
    #df.loc[df['nStratDischarge'] > 1.5] = 0.1
    df.loc[df['nStratDischarge'] < -0.1] = 0.1
    df_refined  = df['nStratDischarge']
    #print ('refined df is:', df_refined)
    #df.loc[df['nStratCharging'] > 110] = 0.1
    #if refined_df
    return df_refined
'''

fig4.show()
fig4.canvas.draw()
ax4.legend(loc='best')
ax4.set_xlabel('Index')
ax4.set_ylabel('Entropy_kJ', color='r')
def plotObject_entropy_Discharge(df, ax4, ax4_1,  fig4):
    ax4.clear()
    ax4Twin.clear()
    ax4_1.clear()
    y1 = df.iloc[:, -3]
    y2= df.iloc[:,  -4]
    y3 = df.iloc[:, -1]
    #print ('Figure: Discharge entropy is:', y1)
    #print ('Figure: Discharge availability  is:', y3)
    #y3_1 =refineDF_Discharge(df)
    y3_1 =df['nStratDischarge']
    #print ('Figure: Discharge Start Efficiency is:', y3_1)
    #print ('Values of refiend df are:', y3_1)
    #y3_1 = Nan2Zero(df.iloc[:, -2])
    #ax3.plot(df.index, y1, label = 'entropy in kJ')
    ax4.plot(df.index, y1, label = ' Discharging entropy in kJ')
    ax4.plot(df.index, y2, label = 'Discharging Entropy in KJ/K')
    #ax3.plot(df.index, y3, label = 'Availability kJ')
    ax4Twin.plot(df.index, y3, label = 'Discharging Availability kJ', color = 'g')
    #ax3.plot(df.index, df.iloc[:, 8], label = 'load tem Mixed')
    ax4Twin.set_ylabel('Dishcarging availibility',color ='g')
    ax4.legend(bbox_to_anchor=(0.4,0.8))
    ax4Twin.legend(bbox_to_anchor=(0.4,0.8))
    ax4.legend()
    #Plot strt eff on first fig object of fig3

    ax4_1.plot(df.index, y3_1, label = 'Disch_econdLawStratificationEff ')
    #ax3_1.set_ylabel('secondLawStratificationEff')
    ax4_1.legend(bbox_to_anchor=(0.4,0.8))
    ax4_1.legend()

    fig4.canvas.draw()
    fig4.savefig('Disch_EntropyExergyAvailability.png')
    #plt.legend(loc='upper left')
    return fig4, ax4




############################
##Exergy/Entropy/nStrt plots for charging
#############################

def refineDF(df):
    #this function refine -ve or >100 values frrom nStrat
    #dropped_df = df.loc[((df<110) | (df>0)).any(1)]
    #refined_df = df['nStratCharging'].where(df['nStratCharging'] >=110, 0.01, inplace=True)
    df.loc[df['nStratCharging'] > 1.5] = 0.1
    df.loc[df['nStratCharging'] < -0.1] = 0.1
    df_refined  = df['nStratCharging']
    #df.loc[df['nStratCharging'] > 110] = 0.1
    #if refined_df
    return df_refined

fig3.show()
fig3.canvas.draw()
ax3.legend(loc='best')
ax3.set_xlabel('Index')
ax3.set_ylabel('Entropy_kJ', color='r')
def plotObject_entropy(df, ax3, ax3_1,  fig3):
    ax3.clear()
    ax3Twin.clear()
    ax3_1.clear()
    y1 = df.iloc[:, -7]
    y2= df.iloc[:,  -8]
    y3 = df.iloc[:, -5]
    
    y3_1 =refineDF(df)
    #print ('Values of refiend df are:', y3_1)
    #y3_1 = Nan2Zero(df.iloc[:, -2])
    #ax3.plot(df.index, y1, label = 'entropy in kJ')
    ax3.plot(df.index, y1, label = ' Charging entropy in kJ')
    ax3.plot(df.index, y2, label = 'Charging Entropy in KJ/K')
    #ax3.plot(df.index, y3, label = 'Availability kJ')
    ax3Twin.plot(df.index, y3, label = 'Chanrging Availability kJ', color = 'g')
    #ax3.plot(df.index, df.iloc[:, 8], label = 'load tem Mixed')
    ax3Twin.set_ylabel('Charging availibility',color ='g')
    ax3.legend(bbox_to_anchor=(0.4,0.8))
    ax3Twin.legend(bbox_to_anchor=(0.4,0.8))
    ax3.legend()
    #Plot strt eff on first fig object of fig3

    ax3_1.plot(df.index, y3_1, label = 'secondLawStratificationEff_charging ')
    #ax3_1.set_ylabel('secondLawStratificationEff')
    ax3_1.legend(bbox_to_anchor=(0.4,0.8))
    ax3_1.legend()

    fig3.canvas.draw()
    fig3.savefig('entropyExergyAvailability.png')
    #plt.legend(loc='upper left')
    return fig3, ax3


#######################
###Discharge efficiency
#######################
def densityFumction(temVlaue):
    #tcalculating density at a specific temp.
    return temVlaue.map(lambda x: 999.8473664794213 + 6.29265190e-02*x - \
    8.42930922e-03*x**2 + 6.77190849e-05*x*3 \
    - 4.40840180e-07*x**4 + 1.29302849e-09*x**5)

def flowCubeMeterPerSec(flow):
    return flow.map(lambda x: x*0.001*0.000277777778)

def specificHeatkJPerKgK(temValue):
    return temValue.map(lambda x: 4.253264761904763 - 0.00470305*x)

def dfMultiplication(df1_p_hot, cp_df_hot, df1_p_cold, cp_df_cold, df_V,  Tin, Tout, timeStamp_tem):
    
    #df_V_litersPerH =  df_V.map(lambda x: x*1000*3600)
    #if df_V_litersPerH.iloc[-1] > 5:
    
    #Hot side p*V*Cp*T_hot in kj/sec, I will convert it to kwh by multiplying by timeStamp.Then to KJ
    #Finally because I need to divide teh net energy extraccted by total energy mstore*C*dT which is 
    #in kJ.
    #deltaT_df = Tout.subtract(Tin)
    l2df_timeStamp_df= pd.DataFrame(timeStamp_tem)
    #print ('type of timestamp object is:', type (l2df_timeStamp_df))
    pcp_df_hot = df1_p_hot.multiply( cp_df_hot)
    pVCp_df_hot = pcp_df_hot.multiply(df_V)
    pCpVT_df_hot = pVCp_df_hot.multiply(Tout)
    
    #Cold side pCpVT_df_cold is in kJ/s:
    # I am seperating hot from cold becasue density, Cp are funstion of temp.otherwise I would have
    # only done pVCp [Thot -Tcold] without any problem, however, p&Cp are function of Thot and Tcold
    #So I calculate them during hot and during cold side and just subtract them
    pcp_df_cold = df1_p_cold.multiply(cp_df_cold)
    pVCp_df_cold = pcp_df_cold.multiply(df_V)
    pCpVT_df_cold = pVCp_df_cold.multiply(Tin)
    
    pVCpDeltaT_df_kJPersec = pCpVT_df_hot.subtract( pCpVT_df_cold )
    #convert pandas series to pandas dataframe.otherwise it will not multiply with other PD series in
    #next step:
    pVCpDeltaT_df_kJPersec = pVCpDeltaT_df_kJPersec.to_frame()
    #print ('type of timestamp object is:', type (pVCpDeltaT_df_kJPersec))
    # convert the kJ/sec to kwH, as energy = power in time, 
    pVCpDeltaT_df_kWh = pVCpDeltaT_df_kJPersec.multiply(l2df_timeStamp_df, fill_value=0)
    #pVCpDeltaT_sum  = pVCpDeltaT_df.sum()
    pVCpDeltaT_df_kWh_sum  = pVCpDeltaT_df_kWh.sum()
    #convert kwh to kJ as I need to divide mstore * C *DeltaT = kJ to calculate teh discharge
    #efficiency, so energy taken out must be in kJ instead of kwh. To make sense 
    pVCpDeltaT_df_kJ_sum = pVCpDeltaT_df_kWh_sum*3600
    pVCpDeltaT_df_kJ_sum  = pd.to_numeric(pVCpDeltaT_df_kJ_sum)
    #print ('flow lools like this:',df_V)
    print ('Total sum discharge in kJ is :',pVCpDeltaT_df_kJ_sum )
    #print ('discharge in kJ/sec:',pVCpDeltaT_df_kJPersec ,'tiem df is',  l2df_timeStamp_df\
    #       , 'multiplied df is:', pVCpDeltaT_df_kWh)
    #print ('multiplied df is :', )
    #pVCpDeltaT = pVCp.multiply(deltaT_df)
    return pVCpDeltaT_df_kJ_sum

def TankVolumeDischarged(Lol,timeStamp):
    mLoad = Lol[3]
    #print ('len of Mload is:', len (mLoad))
    #print ('len of tiem stamp is:', len (timeStamp))
    litersDischarged = sum([x*y for x, y in zip (mLoad , timeStamp)])
    print ('liters discharged is :',litersDischarged )
    return litersDischarged

nDischargePlotterList = []
def nDicharge(df_conc_all, gross_DF):
    '''
    T_initial should be average tem of tank i.e. mean of 10 sensors just before the discharge
    initiates 

    '''
    df_flowGreaterThan5 = df_conc_all.loc[(df_conc_all['flowLoad']>0.5)&(df_conc_all['flowLoad']<5)]
    #print ('df for just before discharge starts is:', df_flowGreaterThan5['flowLoad'], df_flowGreaterThan5['id'] )
    df_flowGreaterThan5_temValues = df_flowGreaterThan5.iloc[-1, -12:-2]
    #print ('df for just before discharge starts is:', df_flowGreaterThan5_temValues, df_flowGreaterThan5.iloc[-1]['id'] )
    df_flowGreaterThan5_mean  = df_flowGreaterThan5_temValues.mean()
    T_inlet = df_conc_all['TbottomTestTankLoadCir']
    T_inlet_lastValue  =  T_inlet.iloc[-1]
    cP_kjPerkgK = 4.253264761904763 - 0.00470305*df_flowGreaterThan5_mean 
    p_LperH = 999.8473664794213 + 6.29265190e-02*df_flowGreaterThan5_mean - \
    8.42930922e-03*df_flowGreaterThan5_mean**2 + 6.77190849e-05*df_flowGreaterThan5_mean**3 \
 - 4.40840180e-07*df_flowGreaterThan5_mean**4 + 1.29302849e-09*df_flowGreaterThan5_mean**5 
    
    mcT_kJ = 0.397*p_LperH*cP_kjPerkgK*(df_flowGreaterThan5_mean-T_inlet_lastValue)
    #mcT_kJ shoudl be constant throught the discharge process, as its the energy content of tank 
    #from very begineening of tank.
    flowLoad  = df_conc_all['flowLoad']
    T_out  = df_conc_all['TTopTestTankLoadCir']
    #T_inlet = df_conc_all['TbottomTestTankLoadCir']
    if not abs(T_out.iloc[-1]-T_inlet.iloc[-1]) <  0.8*abs(df_flowGreaterThan5_mean-T_inlet.iloc[-1]):
        print ('OK ok oK oK ok if not small run ')

        numerator = dfMultiplication(densityFumction(gross_DF['TTopTestTankLoadCir']), \
                         specificHeatkJPerKgK(gross_DF['TTopTestTankLoadCir']), \
                         densityFumction(gross_DF['TbottomTestTankLoadCir']),\
                         specificHeatkJPerKgK(gross_DF['TbottomTestTankLoadCir']),\
                         flowCubeMeterPerSec(gross_DF ['flowLoad']), \
                         gross_DF['TbottomTestTankLoadCir'], \
                         gross_DF['TTopTestTankLoadCir'], timePeriod_tem)
        denominator = mcT_kJ
        dischargeEfficiency =  numerator/denominator
        dischargeEfficiency= dischargeEfficiency.to_numpy()[0]
        print('type of nDis now is ', dischargeEfficiency)
        #dischargeEfficiency = pd.to_numeric(dischargeEfficiency)
        nDischargePlotterList.append(dischargeEfficiency)
        print ('energy content of tank from the begineening of discharge in kJ, Inlet, mean, cp, p:' \
               , denominator, T_inlet_lastValue, df_flowGreaterThan5_mean, cP_kjPerkgK,p_LperH )
        #print ('energy content of tank from the begineening of discharge in kJ:', denominator)
        print ('energy/sec discharged from tank in kJ/sec:', numerator)
        print ('discharge efficiency is:', dischargeEfficiency)

        return dischargeEfficiency
        
###########################################
###########################################
#########Exergy calculation for discharge##
###########################################
###########################################


def mcTForExergyDischarging (l_load_kwh, time_stamp_tem):
    load_mCT_kW_l = [x*y for x,y in zip (l_load_kwh, time_stamp_tem )]
    load_kwh_total = sum(load_mCT_kW_l)
    load_kJ_total = load_kwh_total*3600
    print ('Discharging: load_kJ_total mul 3600:',load_kJ_total)
    return load_kJ_total


DisEntropyPlotter_SUMList_KjPerK = []
DisEntropyPlotter_SUMList_Kj = []
DisMCTPlotterList_TankEnergyKJ = []
def entropyDischarging(Df_conc):

    mL =Df_conc['flowLoad']
    T =Df_conc.iloc[: ,11:-2]
    T_Load_out_df =  Df_conc['TTopTestTankLoadCir']
    T_Load_in_df =  Df_conc['TbottomTestTankLoadCir']
    T = T[['T4', 'T3', 'T2', 'T1', 'T0', 'T9', 'T8', 'T7', 'T6', 'T5']]
    T = T.rename({'T4':'T0', 'T3':'T1', 'T2':'T2', 'T1':'T3', 'T0':'T4', 'T9':'T5', 'T8':'T6',\
              'T7':'T7','T6':'T8','T5':'T9'}, axis='columns')
    df_density_columns = ['d{}'.format(x) for x in range(0,10)]
    df_density = T.apply(lambda x: 999.8473664794213 + 6.29265190e-02*x - \
                         8.42930922e-03*x**2 + 6.77190849e-05*x**3 \
                         - 4.40840180e-07*x**4 + 1.29302849e-09*x**5)
    #0.397/10 is probably mass of each layer which are 10 layers
    #It is volume of each layer which multiply by density to give mass
    df_m_kg = df_density.multiply(0.397/10, axis =1) 
    df_heatCapacity_kJPerkgK = T.apply(lambda x: 4.253264761904763 - 0.00470305*x)
    #T0_ambient_df =pd.DataFrame([np.random.uniform(24, 26) for _ in range(T.shape[0])])
    T0_ambient_df = np.random.uniform(21, 22)
    #log [TinLoad/Ti(h)], Ti is the tanks stratified temperatures in height 
    df_Logvalues = T.apply(lambda x: np.log(T_Load_out_df/x))
    #cpxLog[Tinlet/Ti]
    lnT_Mul_Cp_df = df_Logvalues.multiply(df_heatCapacity_kJPerkgK, axis =1)
    #mcpln[Tinlet/Ti]
    mass_mul_lnT_and_cp_df = lnT_Mul_Cp_df.multiply(df_m_kg, axis =1)
    #Tambient*DeltaS
    entropy_df = mass_mul_lnT_and_cp_df.multiply(T0_ambient_df, axis =0)
    #entropy sum for all teh columns, This si not time wise, so each tiem has one single value of tank
    entropy_sum_heightWise = entropy_df.sum(axis = 1)
    #print ('Entropy sum whole height wise is  :', entropy_sum_heightWise )
    #print ('Entropy sum whole height wise is  :', entropy_sum_heightWise.iloc[0] )
    
    
    entropy_sum_kjPerK = mass_mul_lnT_and_cp_df.sum(axis = 1)
    entropyLastValue_kJPerK = entropy_sum_kjPerK.iloc[-1]
    DisEntropyPlotter_SUMList_KjPerK.append(entropyLastValue_kJPerK)
    #print ('entropy list kJ/k is :', DisEntropyPlotter_SUMList_KjPerK)
    
    DisEntropyPlotter_SUMList_Kj.append(entropy_sum_heightWise.iloc[-1])
    #print ('Entropy sum whole height wise is  :', entropy_sum_heightWise.iloc[-1] )
    #print ('Entropy appended list is  :',DisEntropyPlotter_SUMList_Kj )
    #print ('entropy list kJ is :',DisEntropyPlotter_SUMList_Kj)
    #print ('discharge: log values that shoudl be negative is:', df_Logvalues)
    #print ('discharge: entropy df is :', entropy_df)
    #print ('discharge: entropy_sum :', entropy_sum_heightWise)
    MCT_df = df_heatCapacity_kJPerkgK.multiply(T, axis =1).multiply(df_m_kg, axis=1).sum(axis = 1)
    #appned last value (current value of energy) as value- energy is decreasing as discharge goes on 
    DisMCTPlotterList_TankEnergyKJ.append(MCT_df.iloc[-1] )
    print ('Availability :Total energy of in Kj is :', MCT_df.iloc[-1])
    #print ('Availability whole df :Total energy of in Kj howle df :', MCT_df)
    return entropy_sum_heightWise

nStratDischragePlotterList = []
def StratEffDischarge(load_kJ_total_float, entropy_sum_height_float):
    #n1 = (load_kJ_total_float-entropy_sum_height_float)/ load_kJ_total_float
    n2 = (load_kJ_total_float-entropy_sum_height_float.iloc[0])/ load_kJ_total_float
    nStratDischragePlotterList.append(n2)
    #print ('Discharge: strat efficiency sum_DF :', n1)
    print ('Discharge: strat efficiency sum_float :', n2)
    #print ('nStratDischarge plotter list is :', nStratDischragePlotterList[-1])
    return n2


###################################
###Exergy calculation for charging
###################################


def mcTForExergyCharging(Lol, time_stamp_tem, time_stamp_watt):
    #this calculates the energy addiction per timestamp in the tank. and integrates it over whole charging
    
    mHP = Lol[2]
    T = flatten_tem(Lol)
    #mL = Lol[3]
    #watt_kW = Lol[4]
    #p_LperH = [999.8473664794213 + 6.29265190e-02*x[2] - 8.42930922e-03*x[2]**2 + 6.77190849e-05*x[2]**3 \
    #- 4.40840180e-07*x[2]**4 + 1.29302849e-09*x[2]**5 for x in T]
    p_LperH = [999.8473664794213 + 6.29265190e-02*x[3] - 8.42930922e-03*x[3]**2 + 6.77190849e-05*x[3]**3 \
 - 4.40840180e-07*x[3]**4 + 1.29302849e-09*x[3]**5 for x in T]
    mF_kgPerS =[ x*2.7777e-07*y for x, y in zip(p_LperH, mHP)]
    #cP_kjPerkgK = [4.253264761904763 - 0.00470305*b[2] for b in T]
    cP_kjPerkgK = [4.253264761904763 - 0.00470305*b[3] for b in T]
    mCT_kW = [c*a*(b[3]-b[4]) for c, a, b in zip(cP_kjPerkgK,mF_kgPerS, T)]
    mCT_kWh_l = [x*y for x,y in zip (time_stamp_tem, mCT_kW)]
    #mCT_kJ_l = pd.DataFrame(mCT_kWh_l).multiply(3600)
    mCT_kJ_l = pd.DataFrame(mCT_kWh_l)
    #mCT_kWh_total = sum(mCT_kWh_l)
    mCT_kWh_total = mCT_kJ_l.sum()
    mCT_KJ_total = mCT_kWh_total*3600
    #electricty consumed:
    #watt_kW_l = [x*y for x,y in zip (time_stamp_watt,  watt_kW)]
    #watt_kWh = sum(watt_kW_l)
    #cop 
    #cop =mCT_kWh/watt_kWh
    #copPlotterList.append(cop)
    #print ('cop of system is:', cop)
    #print ('kwh heat addition is :', mCT_kWh)
    print ('chanrging : whole kJ list is mul by 3600:', mCT_KJ_total)
    #print ('chanrging : df of mcT energy addition is:', mCT_kJ_l)
    #print ('electricity in khW is:', watt_kWh)
    
    #print ('electricity consumption kW :', watt_kW)
    return mCT_KJ_total

entropyPlotter_SUMList_KjPerK = []
entropyPlotter_SUMList_Kj = []
MCTPlotterList_TankEnergyKJ = []
def entropyCharging(Df_conc):
    mHP =Df_conc['flowHP']
    T =Df_conc.iloc[: ,11:-2]
    T_hp_out_df =  Df_conc['TtopTestTankHPCir']
    T_hp_in_df =  Df_conc['TbottomTestTankHpCir']
    T = T[['T4', 'T3', 'T2', 'T1', 'T0', 'T9', 'T8', 'T7', 'T6', 'T5']]
    T = T.rename({'T4':'T0', 'T3':'T1', 'T2':'T2', 'T1':'T3', 'T0':'T4', 'T9':'T5', 'T8':'T6',\
              'T7':'T7','T6':'T8','T5':'T9'}, axis='columns')
    df_density_columns = ['d{}'.format(x) for x in range(0,10)]
    df_density = T.apply(lambda x: 999.8473664794213 + 6.29265190e-02*x - \
                         8.42930922e-03*x**2 + 6.77190849e-05*x**3 \
                         - 4.40840180e-07*x**4 + 1.29302849e-09*x**5)
    #0.397/10 is probably mass of each layer which are 10 layers
    df_m_kg = df_density.multiply(0.397/10, axis =1) 
    df_heatCapacity_kJPerkgK = T.apply(lambda x: 4.253264761904763 - 0.00470305*x)
    #T0_ambient_df =pd.DataFrame([np.random.uniform(24, 26) for _ in range(T.shape[0])])
    T0_ambient_df = np.random.uniform(21, 22)
    df_Logvalues = T.apply(lambda x: np.log(T_hp_out_df /x))
    lnT_Mul_Cp_df = df_Logvalues.multiply(df_heatCapacity_kJPerkgK, axis =1)
    mass_mul_lnT_and_cp_df = lnT_Mul_Cp_df.multiply(df_m_kg, axis =1)

    entropy_df = mass_mul_lnT_and_cp_df.multiply(T0_ambient_df, axis =0)
    entropy_sum_heightWise = entropy_df.sum(axis = 1)
    
    #entropyLastValue_kJPerK = mass_mul_lnT_and_cp_df.iloc[-1]
    #appending entropy sum to entropyPlotter_SUMList_KjPerK
    #entropyLastValue_kJPerK = entropy_sum_heightWise.iloc[-1]
    
    #calculates kJ/K  first without multiplication with T0 =Tambient
    #and appends it to entropyPlotter_SUMList_KjPerK
    entropy_sum_kjPerK = mass_mul_lnT_and_cp_df.sum(axis = 1)
    entropyLastValue_kJPerK = entropy_sum_kjPerK.iloc[-1]
    entropyPlotter_SUMList_KjPerK.append(entropyLastValue_kJPerK)
    #print ('entropy list kJ/k is :', entropyPlotter_SUMList_KjPerK)
    
    #Now appned Kj Total of tank entropy, by multiplying it with To
    entropyPlotter_SUMList_Kj.append(entropy_sum_heightWise.iloc[-1])
    #print ('entropy list kJ is :',entropyPlotter_SUMList_Kj,)
    
    #saving entropy of each node in a numpy file.
    #print ('shape of entropy df is:', mass_mul_lnT_and_cp_df.shape)
    
    #Exporting to csv each node entropy:
    file_name = 'entropyNodeWise_{}'.format(datetime.datetime.now().strftime("%Y_%m_%d"))
    suffix = '.csv'
    filePath = os.path.join(os.getcwd(), file_name + suffix)
    #mass_mul_lnT_and_cp_df.to_csv(filePath, header=True, na_rep=np.nan)
    
    
    #Calculation of Totoal energy in tank for availability = Energy - Entropy
    #I have entropy in KJ i should calculate Totoal enegry to show, how much is lost in entropy 
    #just for comparison.
    
    MCT_df = df_heatCapacity_kJPerkgK.multiply(T, axis =1).multiply(df_m_kg, axis=1).sum(axis = 1)
    MCTPlotterList_TankEnergyKJ.append(MCT_df.iloc[-1] )
    print ('Availability :Total energy of in Kj is :', MCT_df.iloc[-1])
    
    
    return entropy_sum_heightWise

nStratPlotterList = []
def nStratCharging(mCT_kWh_total_l, entropy_sum_heightWise):
    nStart = (mCT_kWh_total_l - entropy_sum_heightWise.iloc[-1]) / mCT_kWh_total_l
    nStratPlotterList.append(nStart.iloc[-1])
    #print ('nStratCharging plotter list is :', nStratPlotterList)
    print ('Charging stratified Efficiency:', nStart)
    return nStart


while True:
    #c.execute("INSERT INTO flowReadings(flowHp, flowLoad) VALUES(?,?,?,?)", (chan2.voltage, chan1.voltage))
    #connection.commit()
    
    ###################################################################################
    ################################################
    ##Modbus connection for wattmeter readings in kW
    ##https://stackoverflow.com/questions/28186746/python-convert-2-ints-to-float
    ################################################
    
    c = ModbusClient(host="10.208.8.125", port=502, auto_open=True)
    
    #This reads the register address 19026 where all teh meteric(values of wattmeter) 
    #values are stored in a 16 bit values.county = 2, means read two values in the
    #same register address.Register is a column (like in spreadsheet). each register
    #store a 16 bit value, we read two 16 bit value and would convert those 2 16 bit 
    #value to a 32 bit floating point value by the formula
    regs = c.read_input_registers(19026, 2)
    #this is forst value of two counts
    a = regs[0]
    #This is second value of two counts
    b = regs[1]
    #This is how we convert two 16 bit value to a single 32 floating point number.
    #from stackoverflow
    mypack = pack('>HH',a,b)
    #print (mypack)
    fl = unpack('>f', mypack)
    #fl = struct.unpack('!f', bytes.fromhex('{0:02x}'.format(a) + '{0:02x}'.format(b)))
    #fl is a tuple (5.0186,) I need to unpack it index it with [0] 
    fl = fl[0]*10**-3
    #wattMeterKw.append(fl)
    #lol[3].append(fl)
    #print ('watter meter reaidngs are:', wattMeterKw)
    #print ('gross lol is:', lol)
    ####################################################################################
    
    chan1 = AnalogIn(ads, ADS.P0)
    chan2 = AnalogIn(ads, ADS.P1)

    chan1Vol = chan1.voltage
    chan1curr = chan1Vol/159.42

    chan2Vol = chan2.voltage
    chan2curr=chan2Vol/159.65
    #flow1 = ((chan1Vol/159.42)*1000 -4)/16*1000
    flow1 = ((chan1Vol/159.42)-0.003956)/0.0000159
    #flow2 = ((chan2Vol/159.65)*1000 -4)/16*4000 +20
    #flow2 = ((chan2Vol/159.65)- 0.0005468893873066417)/1.09561608e-05
    flow2 = ((chan2Vol/159.65)- 0.003973767754877122)/5.3038815e-06
    cL.execute("INSERT INTO flowReadings(flowHp, flowLoad, watt) VALUES(%s, %s, %s)", (flow2, flow1, fl))
    connectionL.commit()
    
    #cL =connectionL.cursor()
    cL.execute("SELECT * FROM flowReadings ORDER BY id DESC LIMIT 1")
    FlowFormDb = cL.fetchall()
    #print ('flow and watt from FlowWattDB is :',FlowFormDb[-1][2],FlowFormDb )
    #print ('Time period of flow load and watt is :',timePeriod_watt, [x* 3600 for x in timePeriod_watt])

    #c.execute("SELECT * from temSensor")
    #cR.execute("SELECT * FROM temSensor ORDER BY id DESC LIMIT 1")
    #result = cR.fetchall()
    
    #print('flow HP:',"{:>5}\t{:>5.3f}".format(chan2.value, chan2.voltage), '\n\n')
    #print('flow load:',"{:>5}\t{:>5.3f}".format(chan1.value, chan1.voltage, '\n\n'))
    print('flow rates load is = ',chan1Vol, chan1curr,flow1 )
    print('flow rates HP is = ',chan2Vol, chan2curr,flow2 )

    connectionR = db.Connection(host=HOST, port=PORT,user=USER, passwd=PASSWORD, db=DB)
    cR = connectionR.cursor()
    #c.execute("SELECT * from temSensor")
    cR.execute("SELECT * FROM temSensor ORDER BY id DESC LIMIT 1")
    result = cR.fetchall()
    print ('result is',result)
    #print ('result diagnoses is',result[0])
    id = result[0][0]
    id_flowWatt = FlowFormDb[0][0]
    flowHP  = FlowFormDb[-1][2]
    flowLoad  = FlowFormDb[-1][3]
    wattUsed = FlowFormDb[-1][4]
    #print ('flow HP, flow Load, watt is:' ,flowHP, flowLoad, wattUsed)
    #idGenerator(id, l_id)
    #print ('id is :', id)
    
    flowRateLoad.append(flow1)
    if lol[0] ==[] or id < lol[0][-1][0][0] :
        lol[0].append(result)
        #print (lol)
        if lol[1] ==[] or id_flowWatt < lol[1][-1][0][0]:
            lol[1].append(FlowFormDb)
            lol[2].append(flowHP)
            lol[3].append(flowLoad)
            lol[4].append(wattUsed)
            timeStampCreator_cop(lol)
            timeStampCreator_watt(lol)
            wattMeterKw.append(fl)
    elif lol[0] != [] and id > lol[0][-1][0][0]:
        lol[0].append(result)
        if lol[1] != [] and id > lol[1][-1][0][0]:
            lol[1].append(FlowFormDb)
            lol[2].append(flowHP)
            lol[3].append(flowLoad)
            lol[4].append(wattUsed)
            timeStampCreator_cop(lol)
            timeStampCreator_watt(lol)
            wattMeterKw.append(fl)
        
    print ('cop is:', Cop(lol, timePeriod_tem, timePeriod_watt ))
    
    df = tankStrat(dfs(lol))

    GrossDf = toCsv(dfs(lol), list2df(Load_kWh(lol, timePeriod_tem), 'Load_kW'), \
                    list2df(MCT_timeStamp(lol, timePeriod_tem),'Heat_Capacity_kW'),\
                    list2df(wattMeterKw, 'electrcity_kW'), list2df(copPlotterList, 'COP'), \
                   list2df(nDischargePlotterList, 'nDis'), \
                    list2df(timePeriod_tem, 'timeStamp_Temp'),\
                    list2df(timePeriod_watt, 'timeStamp_watt'),\
                   list2df(entropyPlotter_SUMList_KjPerK , 'entropy_kJ/K'), \
                   list2df(entropyPlotter_SUMList_Kj , 'entropy_kJ'),\
                   list2df(nStratPlotterList , 'nStratCharging'),\
                   list2df(MCTPlotterList_TankEnergyKJ, 'TotalTanksEnergyForAvailability_kJ'),\
                    list2df(DisEntropyPlotter_SUMList_KjPerK , 'DisEntropy_kj/K'),\
                   list2df(DisEntropyPlotter_SUMList_Kj , 'DisEntropy_kj'), \
                   list2df(nStratDischragePlotterList , 'nStratDischarge'), \
                   list2df(DisMCTPlotterList_TankEnergyKJ,  'DisTotalTanksEnergyForAvailability_kJ'))
    
    #print ('gorss DF is :',GrossDf.iloc[:, -10] )
    #GrossDf = toCsv(dfs(lol), list2df(Load_kWh(lol), 'Load_kW'), list2df(MCT_timeStamp(lol, timePeriod),'Heat_Capacity_kW'))
    #heatAddition_kwh, cop = MCT_timeStamp(lol, timePeriod)
    # Plot tem values as a seperate first fig

    fig, ax = plotObject(df, ax,  fig, alpha=0.7, scm=scm)
    #plot load_kW in different fig2 
    fig2, ax2 = plotObject_Load(GrossDf, ax2, fig2)
    #Plot heat_Capacity in the same fig as fig2 but as a subplot
    fig2, ax2_1 =plotObject_Heat_Capacity(GrossDf, ax2_1, fig2)
    #This plot the HP in and out and tmixL laod tem.
    fig, ax_1 = plotObject_Tem_HpAndLoad(GrossDf, ax_2, fig)
    
    #Thjis plot plots Entropy in kJ/K and kJ
    fig3, ax3 = plotObject_entropy(GrossDf, ax3,ax3_1, fig3)
    
    fig4, ax4 = plotObject_entropy_Discharge(GrossDf, ax4, ax4_1,  fig4)
    
    #fig4, ax4 = plotObject_entropy_Discharge(GrossDf, ax4, ax4_1,  fig4)

    #print ('fetch the flow load:', nDicharge(dfs(lol)))
    #nDicharge(dfs(lol))
    #print ('lol len and lol itself is :', len (lol[0]), lol[0])
    #print ('Density of df is :',densityFumction(GrossDf ['TbottomTestTankLoadCir']))
    #print ('fow in cubeic meter per sec  :',flowCubeMeterPerSec(GrossDf ['flowLoad']))
    #flowCubeMeterPerSec(flow)
    #print ('discharge mcdelta T is :',dfMultiplication(densityFumction(), df2_V, Tin, Tout), flowCubeMeterPerSec(GrossDf ['flowLoad']))
    #dfMultiplication(df1_p, df2_V, Tin, Tout)
    #print ('flow in m3/sec:', flowCubeMeterPerSec(GrossDf ['flowLoad']))
    #print ('hot water cp, cold water cp:', specificHeatkJPerKgK(GrossDf['TTopTestTankLoadCir']),specificHeatkJPerKgK(GrossDf['TbottomTestTankLoadCir']))
    #print ('how water density, cold water density:', densityFumction(GrossDf['TTopTestTankLoadCir']),densityFumction(GrossDf['TbottomTestTankLoadCir']))
    #nDicharge(dfs(lol), GrossDf)
    #print ('tiem perod is :', pd.DataFrame({'time_tem':timePeriod_tem}))
    #print ('nDis plottre list is:',nDischargePlotterList, len(nDischargePlotterList))
    #print ('nDis plotter df looks like:',list2df(nDischargePlotterList, 'nDis'))
    #if nDischargePlotterList
    #print (' conc df wiuth Nan is :',dfs(lol))
    #df_CONC = dfs(lol)
    #print ('TemStrat is:',df)
    #entropyCharging(dfs(lol))
    #entropyCharging(dfs(lol))
    #mcTForExergyCharging(lol,timePeriod_tem,timePeriod_watt)
    #print ('nDis df looks like thuis :',Nan2Zero(list2df(nDischargePlotterList, 'nDis')))
    #nStratCharging(mcTForExergyCharging(lol,timePeriod_tem,timePeriod_watt), entropyCharging(dfs(lol)))
    #print ('GRoss DF is :', GrossDf )
    if GrossDf ['flowLoad'].iloc[-1]>50:
        #print ('Highre discharge calculating Discharge Efficiency',GrossDf ['flowLoad'].iloc[-1] )
        nDicharge(dfs(lol), GrossDf)
        TankVolumeDischarged(lol,timePeriod_watt)
        StratEffDischarge(mcTForExergyDischarging (Load_kWh(lol, timePeriod_watt), timePeriod_watt), \
                          entropyDischarging(dfs(lol)))
        #creat discharge grasphs only when discharge
        
        #plotObject_entropy_Discharge(GrossDf, ax4, ax4_1,  fig4)
    
    elif GrossDf ['flowHP'].iloc[-1]>0.5:
        print ('charging is going on so I will calculate charging efficiency:==' )
        #entropyCharging(dfs(lol))
        #mcTForExergyCharging(lol,timePeriod_tem,timePeriod_watt)
        nStratCharging(mcTForExergyCharging(lol,timePeriod_tem,timePeriod_watt), entropyCharging(dfs(lol)))
        
    else : 
        #This else conditions fills the nDischargePlotterList list even when discharge is not going on
        #otehrwise its problem. 
        nDischargePlotterList.append(np.nan)

    '''
    dfMultiplication(densityFn in kwh is: 6.10671895076359umction(GrossDf['TTopTestTankLoadCir']), \
                     specificHeatkJPerKgK(GrossDf['TTopTestTankLoadCir']), \
                     densityFumction(GrossDf['TbottomTestTankLoadCir']),\
                     specificHeatkJPerKgK(GrossDf['TbottomTestTankLoadCir']),\
                     flowCubeMeterPerSec(GrossDf ['flowLoad']), \
                     GrossDf['TbottomTestTankLoadCir'], \
                     GrossDf['TTopTestTankLoadCir'], timePeriod_tem)
    '''
    
    print('________________________________________________________________')
    time.sleep(0.01)
# Out:
# table flowReadings deleted
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">
# <img src="data:image/png;base64,..." width="800">
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  0.6340193487350078 0.003971308166207377 -0.4637337145910134
# result is ((535, datetime.datetime(2021, 5, 24, 8, 35, 20), 21.812, 25.0916, 22.0486, 21.7782, 21.2038, 25.3284, 22.8936, 19.9201, 22.0824, 24.077, 23.8403, 23.2993, 23.0288, 22.6232, 25.6329, 25.6329, 25.3284, 24.7534, 24.449),)
# electricity in khW is: 3.2650499999999998e-06
# cop is: -0.27622632266725017
# Load in kWh is: 2.731679860287646e-06
# heat addition in kwh is: -9.01892754824705e-07
# ________________________________________________________________
# flow rates load is =  0.6380194708090458 0.004002129411673854 2.9012208599907954
# flow rates HP is =  0.6340193487350078 0.003971308166207377 -0.4637337145910134
# result is ((539, datetime.datetime(2021, 5, 24, 8, 35, 26), 21.812, 25.0578, 22.0486, 21.7782, 21.2038, 25.3284, 22.8598, 19.9539, 22.0486, 24.077, 23.8064, 23.3331, 22.995, 22.6232, 25.6329, 25.6667, 25.3284, 24.7534, 24.4152),)
# electricity in khW is: 1.24961e-05
# cop is: -0.2862907472648939
# Load in kWh is: 2.0888009025278304e-05
# heat addition in kwh is: -3.577517806896841e-06
# ________________________________________________________________
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  0.6340193487350078 0.003971308166207377 -0.4637337145910134
# result is ((542, datetime.datetime(2021, 5, 24, 8, 35, 31), 21.7782, 25.0578, 22.0486, 21.812, 21.2714, 25.3284, 22.8936, 19.9201, 22.0148, 24.077, 23.8064, 23.3331, 23.0288, 22.6232, 25.5991, 25.5991, 25.2946, 24.8548, 24.449),)
# electricity in khW is: 1.9750058333333334e-05
# cop is: -0.2940400288689804
# Load in kWh is: 2.785943107168091e-05
# heat addition in kwh is: -5.80730772249738e-06
# ________________________________________________________________
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  0.6400195318460646 0.004008891524247195 6.622276415880069
# result is ((546, datetime.datetime(2021, 5, 24, 8, 35, 37), 21.7782, 25.0578, 22.0486, 21.7106, 21.17, 25.3284, 22.826, 19.9539, 21.981, 24.0432, 23.8064, 23.2993, 23.0288, 22.6232, 25.5991, 25.6329, 25.2946, 24.8887, 24.3813),)
# electricity in khW is: 3.1376475e-05
# cop is: 1.0327255277006926
# Load in kWh is: 3.631047096477413e-05
# heat addition in kwh is: 3.2403286701762586e-05
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    0.116126
# dtype: float64
# Availability :Total energy of in Kj is : 39752.15657674412
# Charging stratified Efficiency: 0   -10007.688322
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6320192876979889 0.003964491830999805 0.5340774213713702
# flow rates HP is =  0.6380194708090458 0.003996363738233922 4.260273039056376
# result is ((550, datetime.datetime(2021, 5, 24, 8, 35, 44), 21.812, 25.0578, 22.0486, 21.812, 21.2376, 25.3284, 22.826, 19.9201, 22.0148, 24.077, 23.7726, 23.3331, 23.0288, 22.6232, 25.6667, 25.6667, 25.3284, 24.8887, 24.5843),)
# electricity in khW is: 4.150109166666667e-05
# cop is: 1.4717857835548875
# Load in kWh is: 4.025005864035188e-05
# heat addition in kwh is: 6.108071671700822e-05
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    0.218904
# dtype: float64
# Availability :Total energy of in Kj is : 39810.968785278434
# Charging stratified Efficiency: 0   -5109.0355
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6320192876979889 0.003964491830999805 0.5340774213713702
# flow rates HP is =  0.6360194097720268 0.003983835952220649 1.898269662232681
# result is ((554, datetime.datetime(2021, 5, 24, 8, 35, 50), 21.7782, 25.0916, 22.0486, 21.7782, 21.2376, 25.3284, 22.8936, 19.9201, 21.981, 24.0093, 23.7726, 23.2993, 23.0288, 22.6232, 25.7006, 25.6667, 25.2946, 24.821, 24.6181),)
# electricity in khW is: 5.3471966666666666e-05
# cop is: 1.3494318067725084
# Load in kWh is: 4.3661292633219964e-05
# heat addition in kwh is: 7.215677259067934e-05
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    0.258596
# dtype: float64
# Availability :Total energy of in Kj is : 39789.527759580764
# Charging stratified Efficiency: 0   -4515.063132
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  0.6340193487350078 0.003971308166207377 -0.4637337145910134
# result is ((558, datetime.datetime(2021, 5, 24, 8, 35, 57), 21.812, 25.0578, 22.0486, 21.7782, 21.2376, 25.3284, 22.7922, 19.9539, 22.0148, 24.077, 23.8064, 23.3331, 23.0288, 22.6232, 25.5652, 25.6667, 25.3284, 24.8548, 24.6519),)
# electricity in khW is: 6.227475e-05
# cop is: 1.1085586056937764
# Load in kWh is: 5.342128349818361e-05
# heat addition in kwh is: 6.903521002992851e-05
# ________________________________________________________________
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  0.6300192266609699 0.003946252594180832 -5.187740468238238
# result is ((561, datetime.datetime(2021, 5, 24, 8, 36, 2), 21.7782, 25.024, 22.0486, 21.7106, 21.17, 25.3284, 22.8598, 19.9201, 22.0148, 24.0432, 23.7726, 23.3331, 23.0288, 22.6232, 25.5652, 25.6667, 25.2946, 24.7872, 24.7196),)
# electricity in khW is: 7.164498333333335e-05
# cop is: 0.6193173697259546
# Load in kWh is: 6.0392705544586216e-05
# heat addition in kwh is: 4.4370982632059865e-05
# ________________________________________________________________
# flow rates load is =  0.6320192876979889 0.003964491830999805 0.5340774213713702
# flow rates HP is =  0.6340193487350078 0.003971308166207377 -0.4637337145910134
# result is ((565, datetime.datetime(2021, 5, 24, 8, 36, 8), 21.812, 25.0578, 22.0486, 21.7444, 21.2038, 25.3284, 22.7922, 19.9201, 22.0824, 24.0432, 23.7726, 23.2993, 23.0288, 22.6232, 25.5652, 25.7006, 25.3284, 24.821, 24.449),)
# electricity in khW is: 7.940671944444445e-05
# cop is: 0.5250860112557498
# Load in kWh is: 6.370060586747855e-05
# heat addition in kwh is: 4.169535757998773e-05
# ________________________________________________________________
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  0.8360255134739218 0.005236614553547897 238.09860734459755
# result is ((568, datetime.datetime(2021, 5, 24, 8, 36, 13), 21.7782, 25.024, 22.0486, 21.7444, 21.2714, 25.3284, 22.826, 19.9201, 21.981, 24.0432, 23.7726, 23.2993, 23.0288, 22.657, 25.6667, 25.6329, 25.3284, 24.7534, 24.4152),)
# electricity in khW is: 0.0005456283861111111
# cop is: 2.1510914432395145
# Load in kWh is: 7.07431391117229e-05
# heat addition in kwh is: 0.001173696552552197
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    4.20646
# dtype: float64
# Availability :Total energy of in Kj is : 39752.1472366332
# Charging stratified Efficiency: 0   -263.088155
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6380194708090458 0.004002129411673854 2.9012208599907954
# flow rates HP is =  1.2720388195440535 0.007967671904441299 753.0153434921531
# result is ((572, datetime.datetime(2021, 5, 24, 8, 36, 19), 21.812, 24.6519, 22.4542, 21.6093, 21.2038, 25.3623, 22.8936, 20.393, 22.0148, 24.077, 23.7726, 23.3331, 23.0288, 22.6232, 25.5991, 25.6667, 25.2946, 24.8887, 24.6857),)
# electricity in khW is: 0.0009726617194444444
# cop is: 4.46892198509137
# Load in kWh is: 8.927336377904738e-05
# heat addition in kwh is: 0.004346749342082052
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    15.58494
# dtype: float64
# Availability :Total energy of in Kj is : 39811.01339831501
# Charging stratified Efficiency: 0   -34.179513
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  1.380042115543077 0.008644172349158015 880.5635258406306
# result is ((575, datetime.datetime(2021, 5, 24, 8, 36, 24), 21.812, 24.1784, 22.6908, 21.5417, 21.2038, 25.3623, 22.826, 20.7646, 22.0486, 24.0432, 23.7726, 23.2993, 23.0288, 22.6232, 25.5652, 25.5991, 25.3284, 24.8548, 24.6519),)
# electricity in khW is: 0.0013939000527777778
# cop is: 4.619957080954257
# Load in kWh is: 9.624466574401612e-05
# heat addition in kwh is: 0.006439758418973207
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    23.095347
# dtype: float64
# Availability :Total energy of in Kj is : 39778.9148515243
# Charging stratified Efficiency: 0    5.683765
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  1.416043214209418 0.008869672497396917 923.0795866234558
# result is ((579, datetime.datetime(2021, 5, 24, 8, 36, 31), 21.7782, 23.3331, 22.8936, 21.4065, 21.2038, 25.3284, 22.8598, 20.9673, 22.0148, 24.0432, 23.8064, 23.3331, 22.995, 22.6232, 25.7006, 25.6667, 25.3623, 24.9225, 24.7196),)
# electricity in khW is: 0.0017441389416666666
# cop is: 4.212570176190917
# Load in kWh is: 0.00010600465660897976
# heat addition in kwh is: 0.0073473076887981895
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    26.355587
# dtype: float64
# Availability :Total energy of in Kj is : 39843.03673143459
# Charging stratified Efficiency: 0    55.893704
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6320192876979889 0.003964491830999805 0.5340774213713702
# flow rates HP is =  1.4260435193945127 0.00893231142746328 934.8896035075742
# result is ((583, datetime.datetime(2021, 5, 24, 8, 36, 37), 21.812, 23.0964, 22.9612, 21.3727, 21.2038, 25.3284, 22.8936, 21.1024, 21.981, 24.077, 23.8064, 23.3331, 23.0288, 22.6232, 25.7006, 25.6329, 25.3623, 24.8887, 24.4152),)
# electricity in khW is: 0.0021633006083333333
# cop is: 3.5083692710988794
# Load in kWh is: 0.00010941589060184785
# heat addition in kwh is: 0.007589657378426179
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    27.226516
# dtype: float64
# Availability :Total energy of in Kj is : 39794.935895660485
# Charging stratified Efficiency: 0    64.537213
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  1.4360438245796074 0.008994950357529643 946.6996203916924
# result is ((587, datetime.datetime(2021, 5, 24, 8, 36, 43), 21.7782, 23.0288, 22.995, 21.3727, 21.2038, 25.3623, 22.8936, 21.1362, 22.0486, 24.077, 23.8064, 23.2993, 23.0288, 22.6232, 25.5991, 25.4976, 25.2608, 24.9902, 24.4828),)
# electricity in khW is: 0.0026495225527777776
# cop is: 2.8876949850704663
# Load in kWh is: 0.00011778145295981034
# heat addition in kwh is: 0.0076510129884874885
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    27.44702
# dtype: float64
# Availability :Total energy of in Kj is : 39762.94238345292
# Charging stratified Efficiency: 0    66.554905
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6380194708090458 0.004002129411673854 2.9012208599907954
# flow rates HP is =  1.4360438245796074 0.008994950357529643 946.6996203916924
# result is ((590, datetime.datetime(2021, 5, 24, 8, 36, 48), 21.812, 23.0288, 23.0288, 21.2714, 21.2714, 25.3284, 22.8598, 21.1362, 22.0824, 24.1108, 23.8064, 23.3331, 23.0288, 22.6232, 25.4299, 25.4637, 25.2269, 25.0916, 24.5843),)
# electricity in khW is: 0.0030706375527777777
# cop is: 2.491669191489626
# Load in kWh is: 0.00013275580212478985
# heat addition in kwh is: 0.0076510129884874885
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    27.44702
# dtype: float64
# Availability :Total energy of in Kj is : 39768.354687546795
# Charging stratified Efficiency: 0    66.101325
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  1.4400439466536454 0.009020005929556188 951.4236271453399
# result is ((594, datetime.datetime(2021, 5, 24, 8, 36, 55), 21.812, 22.995, 23.0288, 21.2714, 21.2376, 25.3623, 22.8936, 21.1024, 22.0148, 24.077, 23.8403, 23.3331, 23.0626, 22.6232, 25.3961, 25.3623, 25.1931, 25.0578, 24.6181),)
# electricity in khW is: 0.0034861492194444444
# cop is: 2.1740542586409086
# Load in kWh is: 0.00014261517583358244
# heat addition in kwh is: 0.007579077556790874
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    27.18847
# dtype: float64
# Availability :Total energy of in Kj is : 39747.08542227208
# Charging stratified Efficiency: 0    67.594282
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  1.4360438245796074 0.008994950357529643 946.6996203916924
# result is ((599, datetime.datetime(2021, 5, 24, 8, 37, 3), 21.7782, 23.0288, 23.0288, 21.2038, 21.2038, 25.3623, 22.8598, 21.0348, 22.0824, 24.077, 23.8741, 23.3669, 23.0626, 22.6232, 25.4299, 25.2946, 25.0916, 24.9902, 24.5504),)
# electricity in khW is: 0.004397442275
# cop is: 1.723519510393317
# Load in kWh is: 0.00015365548645429088
# heat addition in kwh is: 0.007579077556790874
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    27.18847
# dtype: float64
# Availability :Total energy of in Kj is : 39715.04106599981
# Charging stratified Efficiency: 0    65.809138
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  1.4400439466536454 0.009020005929556188 951.4236271453399
# result is ((603, datetime.datetime(2021, 5, 24, 8, 37, 9), 21.7782, 23.4007, 23.0964, 21.1024, 21.2376, 25.3623, 22.8936, 20.6632, 22.0148, 24.1108, 23.8403, 23.4007, 23.0964, 22.6232, 25.2608, 25.1931, 24.9902, 24.9563, 24.9225),)
# electricity in khW is: 0.005676433941666666
# cop is: 1.4329799348344048
# Load in kWh is: 0.00016210637820468453
# heat addition in kwh is: 0.008134215939821303
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    29.182539
# dtype: float64
# Availability :Total energy of in Kj is : 39720.52705404269
# Charging stratified Efficiency: 0    42.085197
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  1.4360438245796074 0.008994950357529643 946.6996203916924
# result is ((607, datetime.datetime(2021, 5, 24, 8, 37, 16), 21.812, 24.077, 23.1302, 21.1362, 21.2038, 25.3284, 22.826, 20.0552, 22.0148, 24.2461, 23.9079, 23.3669, 23.0964, 22.6232, 25.2269, 25.1931, 24.9563, 24.9563, 24.8548),)
# electricity in khW is: 0.007717089497222222
# cop is: 1.3138702442831118
# Load in kWh is: 0.00017186636906964817
# heat addition in kwh is: 0.010139254262869997
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    36.378289
# dtype: float64
# Availability :Total energy of in Kj is : 39725.90092854949
# Charging stratified Efficiency: 0    6.880306
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  1.4360438245796074 0.008994950357529643 946.6996203916924
# result is ((610, datetime.datetime(2021, 5, 24, 8, 37, 21), 21.812, 24.6181, 23.1302, 21.0686, 21.2376, 25.3284, 22.826, 19.5148, 22.0486, 24.3475, 23.8741, 23.4007, 23.0964, 22.6232, 25.2269, 25.1255, 24.9563, 24.8887, 24.7872),)
# electricity in khW is: 0.009568006163888889
# cop is: 1.294931808812616
# Load in kWh is: 0.00017876667991820904
# heat addition in kwh is: 0.012389915528534898
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    44.449477
# dtype: float64
# Availability :Total energy of in Kj is : 39709.92044720564
# Charging stratified Efficiency: 0   -12.003086
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6300192266609699 0.003951945970775122 -0.25497039150178974
# flow rates HP is =  1.4360438245796074 0.008994950357529643 946.6996203916924
# result is ((614, datetime.datetime(2021, 5, 24, 8, 37, 27), 21.8458, 25.2269, 23.0964, 21.0686, 21.2376, 25.3284, 22.8598, 18.907, 22.0824, 24.4828, 23.9417, 23.4345, 23.1302, 22.6232, 25.1255, 25.1593, 24.9902, 24.9225, 24.9225),)
# electricity in khW is: 0.012438433941666667
# cop is: 1.3069941651983545
# Load in kWh is: 0.00017718747814519155
# heat addition in kwh is: 0.016256960585963504
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    58.306121
# dtype: float64
# Availability :Total energy of in Kj is : 39774.20170598969
# Charging stratified Efficiency: 0   -22.187674
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6300192266609699 0.003951945970775122 -0.25497039150178974
# flow rates HP is =  1.4380438856166264 0.009007478143542915 949.061623768516
# result is ((618, datetime.datetime(2021, 5, 24, 8, 37, 33), 21.812, 25.9036, 23.2317, 21.0011, 21.2376, 25.3284, 22.8936, 19.1096, 22.0824, 24.5166, 23.9079, 23.4345, 23.1302, 22.6232, 25.1255, 25.1931, 25.024, 24.8887, 24.821),)
# electricity in khW is: 0.014776483941666668
# cop is: 1.429231586943752
# Load in kWh is: 0.00017560827637217406
# heat addition in kwh is: 0.02111901759339712
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    75.71085
# dtype: float64
# Availability :Total energy of in Kj is : 39763.48482630687
# Charging stratified Efficiency: 0   -30.255698
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6320192876979889 0.003964491830999805 0.5340774213713702
# flow rates HP is =  1.4360438245796074 0.008994950357529643 946.6996203916924
# result is ((622, datetime.datetime(2021, 5, 24, 8, 37, 40), 21.812, 26.0051, 23.2655, 20.9335, 21.2714, 25.3284, 22.8598, 19.4473, 22.0148, 24.5843, 23.9755, 23.4683, 23.164, 22.6232, 25.0916, 25.1931, 25.1255, 25.024, 24.8548),)
# electricity in khW is: 0.01750185616388889
# cop is: 1.5381607616009236
# Load in kWh is: 0.0001795478640477518
# heat addition in kwh is: 0.02692066840647716
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    96.476086
# dtype: float64
# Availability :Total energy of in Kj is : 39833.04984840988
# Charging stratified Efficiency: 0   -23.54572
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  1.4360438245796074 0.008994950357529643 946.6996203916924
# result is ((625, datetime.datetime(2021, 5, 24, 8, 37, 45), 21.812, 25.6329, 23.1979, 20.9335, 21.2038, 25.2946, 22.9274, 19.346, 22.0824, 24.6857, 24.0432, 23.5021, 23.164, 22.6232, 25.0916, 25.2269, 25.1931, 24.9902, 25.0578),)
# electricity in khW is: 0.01947477283055556
# cop is: 1.5714665306761813
# Load in kWh is: 0.00018630627183341297
# heat addition in kwh is: 0.0306039536957399
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    109.666168
# dtype: float64
# Availability :Total energy of in Kj is : 39907.9326886099
# Charging stratified Efficiency: 0   -15.275708
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6300192266609699 0.003951945970775122 -0.25497039150178974
# flow rates HP is =  1.4360438245796074 0.008994950357529643 946.6996203916924
# result is ((629, datetime.datetime(2021, 5, 24, 8, 37, 51), 21.812, 25.5314, 23.2655, 20.9673, 21.2714, 25.3623, 22.826, 19.3122, 22.0824, 24.7196, 24.077, 23.5359, 23.1979, 22.5894, 25.1255, 25.2269, 25.1931, 24.9902, 25.0916),)
# electricity in khW is: 0.02223024505277778
# cop is: 1.561698959121572
# Load in kWh is: 0.00018471065311172915
# heat addition in kwh is: 0.034716950559940535
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    124.39717
# dtype: float64
# Availability :Total energy of in Kj is : 39934.71406548949
# Charging stratified Efficiency: 0   -12.600619
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6320192876979889 0.003964491830999805 0.5340774213713702
# flow rates HP is =  1.4320437025055697 0.008969894785503097 941.975613638045
# result is ((633, datetime.datetime(2021, 5, 24, 8, 37, 58), 21.812, 25.6329, 23.3331, 20.9335, 21.2376, 25.3284, 22.8598, 19.3122, 22.0824, 24.7534, 24.1108, 23.5698, 23.2317, 22.6232, 25.1255, 25.2269, 25.2269, 24.9902, 25.0916),)
# electricity in khW is: 0.024176842275000002
# cop is: 1.6363979183450028
# Load in kWh is: 0.00018856987015510355
# heat addition in kwh is: 0.03956293437096547
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    141.750951
# dtype: float64
# Availability :Total energy of in Kj is : 39966.88054182603
# Charging stratified Efficiency: 0   -11.657283
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  1.4360438245796074 0.008994950357529643 946.6996203916924
# result is ((637, datetime.datetime(2021, 5, 24, 8, 38, 4), 21.812, 25.8021, 23.4007, 20.8997, 21.3051, 25.3284, 22.8936, 19.3122, 22.0824, 24.7534, 24.1446, 23.6036, 23.2655, 22.6232, 25.0916, 25.2608, 25.2608, 25.0916, 25.0578),)
# electricity in khW is: 0.02687594505277778
# cop is: 1.6342453027401609
# Load in kWh is: 0.00019676490973596648
# heat addition in kwh is: 0.04392188695920475
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    157.356938
# dtype: float64
# Availability :Total energy of in Kj is : 39998.997648888675
# Charging stratified Efficiency: 0   -11.290633
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  1.4340437635425884 0.00898242257151637 944.3376170148686
# result is ((641, datetime.datetime(2021, 5, 24, 8, 38, 11), 21.8458, 25.9374, 23.3669, 20.8997, 21.2038, 25.3623, 22.8936, 19.2784, 22.0486, 24.821, 24.2122, 23.6036, 23.2993, 22.6232, 25.0916, 25.2608, 25.2269, 25.0916, 25.0578),)
# electricity in khW is: 0.029189028386111114
# cop is: 1.6907587032831108
# Load in kWh is: 0.0002065247324869227
# heat addition in kwh is: 0.04935160378419514
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    176.793691
# dtype: float64
# Availability :Total energy of in Kj is : 40020.40981200073
# Charging stratified Efficiency: 0   -10.883755
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6360194097720268 0.003989583551449171 2.1121730471176354
# flow rates HP is =  1.4380438856166264 0.009007478143542915 949.061623768516
# result is ((645, datetime.datetime(2021, 5, 24, 8, 38, 17), 21.812, 26.0051, 23.4345, 20.8997, 21.2038, 25.3623, 22.9274, 19.2109, 22.0486, 24.8548, 24.3137, 23.6712, 23.2993, 22.657, 25.0578, 25.1931, 25.2608, 25.0916, 25.1255),)
# electricity in khW is: 0.03188640060833334
# cop is: 1.69443161124985
# Load in kWh is: 0.00021987904373798467
# heat addition in kwh is: 0.054029325159736456
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    193.536165
# dtype: float64
# Availability :Total energy of in Kj is : 40057.94860783871
# Charging stratified Efficiency: 0   -10.09605
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6300192266609699 0.003951945970775122 -0.25497039150178974
# flow rates HP is =  1.4360438245796074 0.008994950357529643 946.6996203916924
# result is ((649, datetime.datetime(2021, 5, 24, 8, 38, 23), 21.812, 26.0728, 23.4345, 20.9335, 21.2038, 25.3623, 22.826, 19.1771, 22.0824, 24.8887, 24.3475, 23.6712, 23.3331, 22.657, 25.0916, 25.3284, 25.2608, 25.1255, 25.1255),)
# electricity in khW is: 0.034197667275
# cop is: 1.7199504100233831
# Load in kWh is: 0.00021828342501630085
# heat addition in kwh is: 0.058818291851479486
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    210.675177
# dtype: float64
# Availability :Total energy of in Kj is : 40106.0789085918
# Charging stratified Efficiency: 0   -9.478064
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6300192266609699 0.003951945970775122 -0.25497039150178974
# flow rates HP is =  1.4340437635425884 0.00898242257151637 944.3376170148686
# result is ((653, datetime.datetime(2021, 5, 24, 8, 38, 30), 21.8458, 26.2081, 23.5359, 20.8659, 21.17, 25.3623, 22.826, 19.1096, 22.1162, 24.9225, 24.5166, 23.6712, 23.3669, 22.6232, 25.024, 25.2608, 25.2946, 25.1255, 25.1255),)
# electricity in khW is: 0.03650553394166667
# cop is: 1.7658372468906394
# Load in kWh is: 0.000216441053524934
# heat addition in kwh is: 0.06446283155182546
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    230.873241
# dtype: float64
# Availability :Total energy of in Kj is : 40122.159784257616
# Charging stratified Efficiency: 0   -9.38774
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6320192876979889 0.003964491830999805 0.5340774213713702
# flow rates HP is =  1.4360438245796074 0.008994950357529643 946.6996203916924
# result is ((657, datetime.datetime(2021, 5, 24, 8, 38, 36), 21.812, 26.3096, 23.5021, 20.8321, 21.2376, 25.3623, 22.826, 19.0758, 22.0824, 24.9225, 24.6519, 23.7388, 23.4007, 22.657, 25.0916, 25.2946, 25.3284, 25.1255, 25.1593),)
# electricity in khW is: 0.03918120616388889
# cop is: 1.7753135253843002
# Load in kWh is: 0.00021978334187266405
# heat addition in kwh is: 0.06955892524362266
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    249.105337
# dtype: float64
# Availability :Total energy of in Kj is : 40191.72116964857
# Charging stratified Efficiency: 0   -8.97803
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6320192876979889 0.003964491830999805 0.5340774213713702
# flow rates HP is =  1.4360438245796074 0.008994950357529643 946.6996203916924
# result is ((661, datetime.datetime(2021, 5, 24, 8, 38, 43), 21.8458, 26.445, 23.5698, 20.8659, 21.2038, 25.3623, 22.8598, 19.0083, 22.0824, 24.9563, 24.7534, 23.7726, 23.4345, 22.6908, 25.1255, 25.3284, 25.3623, 25.1255, 24.9902),)
# electricity in khW is: 0.041464389497222226
# cop is: 1.8243957637794537
# Load in kWh is: 0.00022368267827834913
# heat addition in kwh is: 0.0756474565464335
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    270.884883
# dtype: float64
# Availability :Total energy of in Kj is : 40218.54870503327
# Charging stratified Efficiency: 0   -8.774224
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  1.4360438245796074 0.008994950357529643 946.6996203916924
# result is ((664, datetime.datetime(2021, 5, 24, 8, 38, 48), 21.812, 26.5127, 23.5698, 20.7983, 21.2376, 25.3623, 22.8936, 18.9745, 22.0824, 24.9902, 24.7872, 23.8064, 23.4683, 22.6908, 25.1255, 25.3623, 25.3623, 25.2608, 25.0916),)
# electricity in khW is: 0.043361903386111116
# cop is: 1.8472208753256965
# Load in kWh is: 0.0002305828724162919
# heat addition in kwh is: 0.08009901312868045
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    286.806484
# dtype: float64
# Availability :Total energy of in Kj is : 40282.70835676264
# Charging stratified Efficiency: 0   -8.158263
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6320192876979889 0.003964491830999805 0.5340774213713702
# flow rates HP is =  1.4360438245796074 0.008994950357529643 946.6996203916924
# result is ((668, datetime.datetime(2021, 5, 24, 8, 38, 54), 21.812, 26.6142, 23.6712, 20.8321, 21.2376, 25.3961, 22.826, 18.8732, 22.0486, 24.9902, 24.8548, 23.8741, 23.4683, 22.6908, 25.0578, 25.4299, 25.3961, 25.1931, 25.024),)
# electricity in khW is: 0.04601369783055556
# cop is: 1.8568614689293426
# Load in kWh is: 0.00023399388534957216
# heat addition in kwh is: 0.0854410625445163
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    305.910317
# dtype: float64
# Availability :Total energy of in Kj is : 40288.07037429088
# Charging stratified Efficiency: 0   -8.042536
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6360194097720268 0.003989583551449171 2.1121730471176354
# flow rates HP is =  1.4380438856166264 0.009007478143542915 949.061623768516
# result is ((671, datetime.datetime(2021, 5, 24, 8, 38, 59), 21.812, 26.6819, 23.6712, 20.7646, 21.2038, 25.3961, 22.9274, 18.8732, 22.1162, 25.024, 24.8887, 23.9417, 23.5021, 22.657, 25.1255, 25.3623, 25.4637, 25.1931, 25.024),)
# electricity in khW is: 0.047909281163888894
# cop is: 1.8786868965360686
# Load in kWh is: 0.00024500844480522397
# heat addition in kwh is: 0.09000653874506036
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    322.235467
# dtype: float64
# Availability :Total energy of in Kj is : 40320.16421827934
# Charging stratified Efficiency: 0   -7.899322
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6320192876979889 0.003964491830999805 0.5340774213713702
# flow rates HP is =  1.4380438856166264 0.009007478143542915 949.061623768516
# result is ((675, datetime.datetime(2021, 5, 24, 8, 39, 5), 21.812, 26.8172, 23.6712, 20.7983, 21.2714, 25.3623, 22.7922, 18.7719, 22.0486, 24.9902, 24.8887, 24.0093, 23.5698, 22.6908, 25.1255, 25.4976, 25.4976, 25.2608, 24.9902),)
# electricity in khW is: 0.050538831163888895
# cop is: 1.8942130916030266
# Load in kWh is: 0.00024838517607687037
# heat addition in kwh is: 0.09573131562495338
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    342.70211
# dtype: float64
# Availability :Total energy of in Kj is : 40373.70688137867
# Charging stratified Efficiency: 0   -7.875931
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  1.4360438245796074 0.008994950357529643 946.6996203916924
# result is ((678, datetime.datetime(2021, 5, 24, 8, 39, 10), 21.8458, 26.8511, 23.6712, 20.7308, 21.2714, 25.3961, 22.8598, 18.7382, 22.0824, 25.024, 24.8887, 24.0432, 23.5698, 22.7246, 25.1255, 25.4299, 25.4637, 25.2608, 25.0916),)
# electricity in khW is: 0.052411608941666674
# cop is: 1.9182992029657273
# Load in kWh is: 0.0002553561484755366
# heat addition in kwh is: 0.10054114765895057
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    359.897699
# dtype: float64
# Availability :Total energy of in Kj is : 40389.787384376075
# Charging stratified Efficiency: 0   -7.516121
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6300192266609699 0.003951945970775122 -0.25497039150178974
# flow rates HP is =  1.4340437635425884 0.00898242257151637 944.3376170148686
# result is ((682, datetime.datetime(2021, 5, 24, 8, 39, 17), 21.8458, 26.9865, 23.7726, 20.697, 21.2714, 25.3623, 22.8598, 18.7044, 22.0824, 24.9563, 24.9563, 24.1108, 23.6374, 22.7584, 25.1593, 25.4637, 25.5314, 25.2946, 25.0916),)
# electricity in khW is: 0.054648308941666675
# cop is: 1.964011930400862
# Load in kWh is: 0.0002534945933002388
# heat addition in kwh is: 0.10732993073766546
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    384.163569
# dtype: float64
# Availability :Total energy of in Kj is : 40443.27535950061
# Charging stratified Efficiency: 0   -7.305833
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6300192266609699 0.003951945970775122 -0.25497039150178974
# flow rates HP is =  1.4360438245796074 0.008994950357529643 946.6996203916924
# result is ((685, datetime.datetime(2021, 5, 24, 8, 39, 22), 21.812, 27.0542, 23.7388, 20.7646, 21.17, 25.3961, 22.826, 18.6706, 22.0824, 24.9563, 24.9563, 24.2122, 23.6036, 22.7584, 25.2269, 25.4637, 25.5314, 25.3623, 25.1593),)
# electricity in khW is: 0.056505295052777786
# cop is: 1.9882198061063154
# Load in kWh is: 0.0002521512719089258
# heat addition in kwh is: 0.112344946773814
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    402.086733
# dtype: float64
# Availability :Total energy of in Kj is : 40486.0262159312
# Charging stratified Efficiency: 0   -6.893637
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  1.4360438245796074 0.008994950357529643 946.6996203916924
# result is ((689, datetime.datetime(2021, 5, 24, 8, 39, 28), 21.8458, 27.1219, 23.8741, 20.697, 21.2714, 25.3961, 22.9274, 18.6369, 22.0824, 24.9902, 24.9902, 24.2461, 23.6712, 22.7922, 25.1931, 25.5652, 25.5314, 25.3623, 25.2946),)
# electricity in khW is: 0.05873181171944445
# cop is: 2.0132188371264714
# Load in kWh is: 0.00026051643878732524
# heat addition in kwh is: 0.11823998969215083
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    423.153971
# dtype: float64
# Availability :Total energy of in Kj is : 40550.2464630475
# Charging stratified Efficiency: 0   -6.473292
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6320192876979889 0.003964491830999805 0.5340774213713702
# flow rates HP is =  1.4380438856166264 0.009007478143542915 949.061623768516
# result is ((693, datetime.datetime(2021, 5, 24, 8, 39, 35), 21.8458, 27.1896, 23.7388, 20.697, 21.17, 25.3961, 22.9274, 18.5694, 22.0148, 25.024, 25.024, 24.2461, 23.7388, 22.7922, 25.2269, 25.5652, 25.5991, 25.3961, 25.3961),)
# electricity in khW is: 0.06131588116388889
# cop is: 2.0478486588408367
# Load in kWh is: 0.00026453613538772875
# heat addition in kwh is: 0.12556564500711398
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    449.331305
# dtype: float64
# Availability :Total energy of in Kj is : 40609.01741858008
# Charging stratified Efficiency: 0   -6.230444
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6280191656239509 0.003939400110550439 -1.0440182043749497
# flow rates HP is =  1.4380438856166264 0.009007478143542915 949.061623768516
# result is ((697, datetime.datetime(2021, 5, 24, 8, 39, 41), 21.8458, 27.2573, 23.7726, 20.6294, 21.2714, 25.3961, 22.826, 18.5694, 22.0486, 25.024, 25.024, 24.3137, 23.7726, 22.8598, 25.2608, 25.6329, 25.6667, 25.4299, 25.0916),)
# electricity in khW is: 0.0638969561638889
# cop is: 2.0643622334724157
# Load in kWh is: 0.0002578682471944471
# heat addition in kwh is: 0.1319064631385747
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    471.987268
# dtype: float64
# Availability :Total energy of in Kj is : 40619.783176766396
# Charging stratified Efficiency: 0   -6.154201
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  1.4380438856166264 0.009007478143542915 949.061623768516
# result is ((701, datetime.datetime(2021, 5, 24, 8, 39, 48), 21.8458, 27.325, 23.8403, 20.5957, 21.2714, 25.4299, 22.9274, 18.4681, 22.0824, 25.0916, 25.0578, 24.4152, 23.8403, 22.8598, 25.3961, 25.6329, 25.7006, 25.4637, 25.1593),)
# electricity in khW is: 0.06574166449722223
# cop is: 2.118961930114069
# Load in kWh is: 0.0002677266886041543
# heat addition in kwh is: 0.13930408429194557
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    498.416685
# dtype: float64
# Availability :Total energy of in Kj is : 40705.32984863832
# Charging stratified Efficiency: 0   -5.716833
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6300192266609699 0.003951945970775122 -0.25497039150178974
# flow rates HP is =  1.4380438856166264 0.009007478143542915 949.061623768516
# result is ((705, datetime.datetime(2021, 5, 24, 8, 39, 54), 21.812, 27.3588, 24.0093, 20.6294, 21.2714, 25.4299, 22.8936, 18.5018, 22.0148, 25.0916, 25.024, 24.449, 23.9079, 22.9274, 25.3961, 25.7344, 25.6667, 25.4976, 25.2269),)
# electricity in khW is: 0.068322467275
# cop is: 2.1281311399452485
# Load in kWh is: 0.0002660654543524616
# heat addition in kwh is: 0.1453991701658177
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    520.190501
# dtype: float64
# Availability :Total energy of in Kj is : 40753.48776397213
# Charging stratified Efficiency: 0   -5.351333
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  1.4400439466536454 0.009020005929556188 951.4236271453399
# result is ((708, datetime.datetime(2021, 5, 24, 8, 39, 59), 21.8458, 27.3927, 24.1108, 20.5619, 21.17, 25.4299, 22.8936, 18.4343, 22.0486, 25.1255, 25.0916, 24.5166, 23.9755, 22.8936, 25.4976, 25.6667, 25.6329, 25.4976, 25.3623),)
# electricity in khW is: 0.07018359227500001
# cop is: 2.1427808205068843
# Load in kWh is: 0.00027317829931963175
# heat addition in kwh is: 0.15038805544114517
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    538.012535
# dtype: float64
# Availability :Total energy of in Kj is : 40806.943860017156
# Charging stratified Efficiency: 0   -5.188605
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  1.4420440076906644 0.00903253371556946 953.7856305221634
# result is ((712, datetime.datetime(2021, 5, 24, 8, 40, 5), 21.8458, 27.4942, 24.2461, 20.5619, 21.2038, 25.4299, 22.9274, 18.4006, 22.0148, 25.1931, 25.0578, 24.5166, 24.0093, 22.9274, 25.4637, 25.7682, 25.7344, 25.5314, 25.3623),)
# electricity in khW is: 0.07206746727500002
# cop is: 2.1691864160166476
# Load in kWh is: 0.00028179903460394824
# heat addition in kwh is: 0.15632777104965434
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    559.228206
# dtype: float64
# Availability :Total energy of in Kj is : 40854.99820804874
# Charging stratified Efficiency: 0   -5.014573
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  1.4380438856166264 0.009007478143542915 949.061623768516
# result is ((716, datetime.datetime(2021, 5, 24, 8, 40, 12), 21.8458, 27.6296, 24.2122, 20.5281, 21.17, 25.4299, 22.8598, 18.333, 22.0486, 25.1593, 25.0916, 24.5843, 24.077, 22.9274, 25.4976, 25.8021, 25.8021, 25.5652, 25.3623),)
# electricity in khW is: 0.07475451449722224
# cop is: 2.1882627834514614
# Load in kWh is: 0.00029175701755798644
# heat addition in kwh is: 0.16358252196925419
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    585.135974
# dtype: float64
# Availability :Total energy of in Kj is : 40903.13181463459
# Charging stratified Efficiency: 0   -5.188572
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  1.4400439466536454 0.009020005929556188 951.4236271453399
# result is ((720, datetime.datetime(2021, 5, 24, 8, 40, 18), 21.812, 27.765, 24.3137, 20.5281, 21.2714, 25.4299, 22.8598, 18.2993, 21.981, 25.2269, 25.1255, 24.5843, 24.077, 22.9274, 25.5652, 25.8359, 25.8697, 25.6329, 25.4976),)
# electricity in khW is: 0.0774829589416667
# cop is: 2.1924625229260766
# Load in kWh is: 0.00030046307416601523
# heat addition in kwh is: 0.16987848364502417
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    607.614401
# dtype: float64
# Availability :Total energy of in Kj is : 40977.82609356433
# Charging stratified Efficiency: 0   -5.099219
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  1.4380438856166264 0.009007478143542915 949.061623768516
# result is ((723, datetime.datetime(2021, 5, 24, 8, 40, 23), 21.8458, 27.8327, 24.2799, 20.4943, 21.2376, 25.3961, 22.9274, 18.2993, 22.0148, 25.2269, 25.1255, 24.6181, 24.1446, 22.9274, 25.5991, 25.8697, 25.9036, 25.7006, 25.5991),)
# electricity in khW is: 0.07946773671944447
# cop is: 2.2054958305668513
# Load in kWh is: 0.0003075762554955291
# heat addition in kwh is: 0.17526576199931906
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    626.847591
# dtype: float64
# Availability :Total energy of in Kj is : 41036.57941309715
# Charging stratified Efficiency: 0   -4.944808
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6380194708090458 0.004002129411673854 2.9012208599907954
# flow rates HP is =  1.4380438856166264 0.009007478143542915 949.061623768516
# result is ((728, datetime.datetime(2021, 5, 24, 8, 40, 31), 21.812, 28.002, 24.4152, 20.4605, 21.2038, 25.4299, 22.8936, 18.1642, 22.0148, 25.2946, 25.1593, 24.6857, 24.2461, 22.9274, 25.6329, 25.8697, 25.9036, 25.7006, 25.3623),)
# electricity in khW is: 0.08228486727500003
# cop is: 2.235748837000966
# Load in kWh is: 0.0003327797750504881
# heat addition in kwh is: 0.18396829631286019
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    657.907691
# dtype: float64
# Availability :Total energy of in Kj is : 41047.346582959944
# Charging stratified Efficiency: 0   -5.039625
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  1.4360438245796074 0.008994950357529643 946.6996203916924
# result is ((732, datetime.datetime(2021, 5, 24, 8, 40, 38), 21.812, 28.1374, 24.6519, 20.393, 21.2038, 25.3961, 22.826, 18.063, 21.981, 25.3961, 25.1931, 24.7196, 24.3137, 22.995, 25.6329, 25.9374, 25.9036, 25.7006, 25.3623),)
# electricity in khW is: 0.08516101171944448
# cop is: 2.2469148224449693
# Load in kWh is: 0.00034283777516340083
# heat addition in kwh is: 0.19134953952682954
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    684.246898
# dtype: float64
# Availability :Total energy of in Kj is : 41106.182561582486
# Charging stratified Efficiency: 0   -4.922285
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6300192266609699 0.003951945970775122 -0.25497039150178974
# flow rates HP is =  1.4380438856166264 0.009007478143542915 949.061623768516
# result is ((736, datetime.datetime(2021, 5, 24, 8, 40, 44), 21.8458, 28.2052, 24.3813, 20.4267, 21.2714, 25.3961, 22.8598, 18.0292, 22.0148, 25.3961, 25.2269, 24.7196, 24.3813, 23.0288, 25.7006, 25.8697, 25.9036, 25.7344, 25.6667),)
# electricity in khW is: 0.08803046727500004
# cop is: 2.2527151992232133
# Load in kWh is: 0.00034119290473320625
# heat addition in kwh is: 0.19830757162511425
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    709.074655
# dtype: float64
# Availability :Total energy of in Kj is : 41180.94721653452
# Charging stratified Efficiency: 0   -4.817804
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  1.4340437635425884 0.00898242257151637 944.3376170148686
# result is ((740, datetime.datetime(2021, 5, 24, 8, 40, 50), 21.8458, 28.3406, 24.1784, 20.393, 21.2376, 25.4637, 22.9612, 17.9617, 22.0486, 25.4299, 25.2608, 24.7534, 24.449, 23.1302, 25.7344, 25.8697, 25.9374, 25.7682, 25.7006),)
# electricity in khW is: 0.09052391727500003
# cop is: 2.273912665796005
# Load in kWh is: 0.00034981323225970955
# heat addition in kwh is: 0.20584348204909236
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    735.959202
# dtype: float64
# Availability :Total energy of in Kj is : 41245.13445161667
# Charging stratified Efficiency: 0   -4.660668
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6320192876979889 0.003964491830999805 0.5340774213713702
# flow rates HP is =  1.4380438856166264 0.009007478143542915 949.061623768516
# result is ((743, datetime.datetime(2021, 5, 24, 8, 40, 55), 21.8458, 28.3406, 23.9417, 20.3254, 21.2714, 25.4299, 22.9612, 17.9955, 22.0486, 25.4299, 25.2608, 24.7872, 24.5166, 23.0964, 25.7344, 26.0728, 26.0389, 25.8021, 25.6329),)
# electricity in khW is: 0.09261457005277782
# cop is: 2.294603771884645
# Load in kWh is: 0.00035268430834560537
# heat addition in kwh is: 0.21251374177457868
# charging is going on so I will calculate charging efficiency:==
# chanrging : whole kJ list is mul by 3600: 0    759.755518
# dtype: float64
# Availability :Total energy of in Kj is : 41298.451652886215
# Charging stratified Efficiency: 0   -4.350494
# dtype: float64
# ________________________________________________________________
# flow rates load is =  0.6340193487350078 0.0039770376912244875 1.3231252342444757
# flow rates HP is =  1.4340437635425884 0.00898242257151637 944.3376170148686
# result is ((747, datetime.datetime(2021, 5, 24, 8, 41, 2), 21.8458, 28.4422, 24.2461, 20.3254, 21.2038, 25.3961, 22.8936, 17.8942, 21.981, 25.4637, 25.2946, 24.821, 24.5504, 23.1302, 25.7682, 26.1404, 26.1404, 25.8697, 25.8021),)
# electricity in khW is: 0.09516467005277782
# cop is: 2.326254530925854
# Load in kWh is: 0.0003627423084585181
# ...
# result is ((5629, datetime.datetime(2021, 5, 24, 10, 52, 26), 23.7726, 30.3728, 23.8741, 19.8188, 31.7283, 47.424, 35.798, 16.2744, 29.8985, 24.2122, 24.3137, 24.1784, 24.1784, 22.2176, 47.0835, 26.0051, 24.6857, 24.3813, 24.6181),)
# electricity in khW is: 3.085608582911111
# cop is: 1.8854834739944681
# Load in kWh is: 10.480647163576732
# heat addition in kwh is: 5.81786399029439
# OK ok oK oK ok if not small run
# Total sum discharge in kJ is : 0    35746.785852
# dtype: float64
# type of nDis now is  1.0937640270884175
# energy content of tank from the begineening of discharge in kJ, Inlet, mean, cp, p: 32682.356492729392 29.8985 50.656909999999996 4.015022781329263 987.7357135559447
# energy/sec discharged from tank in kJ/sec: 0    35746.785852
# dtype: float64
# discharge efficiency is: 1.0937640270884175
# liters discharged is : 335.3960146758335
# Load in kWh is: 10.481982736493292
# Discharging: load_kJ_total mul 3600: 37735.13785137585
# Availability :Total energy of in Kj is : 43305.0114462153
# Discharge: strat efficiency sum_float : 0.9599370931850693
# ________________________________________________________________
# flow rates load is =  1.292039429914243 0.00810462570514517 260.91985566950757
# flow rates HP is =  0.6340193487350078 0.003971308166207377 -0.4637337145910134
# result is ((5633, datetime.datetime(2021, 5, 24, 10, 52, 33), 23.7726, 30.3389, 23.9079, 19.7512, 31.7283, 47.2878, 35.798, 16.2406, 29.9324, 24.2461, 24.3475, 24.1784, 24.1784, 22.2514, 47.1175, 26.0051, 24.6857, 24.5166, 24.5843),)
# electricity in khW is: 3.0856174390277777
# cop is: 1.885475906205679
# Load in kWh is: 10.490399785600614
# heat addition in kwh is: 5.817857337054946
# OK ok oK oK ok if not small run
# Total sum discharge in kJ is : 0    35779.689632
# dtype: float64
# type of nDis now is  1.0965615672474678
# energy content of tank from the begineening of discharge in kJ, Inlet, mean, cp, p: 32628.983817023323 29.9324 50.656909999999996 4.015022781329263 987.7357135559447
# energy/sec discharged from tank in kJ/sec: 0    35779.689632
# dtype: float64
# discharge efficiency is: 1.0965615672474678
# liters discharged is : 335.83088134250016
# Load in kWh is: 10.490342126799476
# Discharging: load_kJ_total mul 3600: 37765.231656478114
# Availability :Total energy of in Kj is : 43342.161419917946
# Discharge: strat efficiency sum_float : 0.9596905728466287
# ________________________________________________________________
# flow rates load is =  1.296039551988281 0.008129717425594537 262.49795129525387
# flow rates HP is =  0.6340193487350078 0.003971308166207377 -0.4637337145910134
# result is ((5637, datetime.datetime(2021, 5, 24, 10, 52, 39), 23.7726, 30.2711, 24.0432, 19.785, 31.7961, 47.0494, 35.7641, 16.2406, 29.8646, 24.2799, 24.3475, 24.1446, 24.2122, 22.2514, 46.8792, 25.8359, 24.6857, 24.449, 24.449),)
# electricity in khW is: 3.0856300262722223
# cop is: 1.8854664249584598
# Load in kWh is: 10.498730250166982
# heat addition in kwh is: 5.817851814379965
# OK ok oK oK ok if not small run
# Total sum discharge in kJ is : 0    35807.806071
# dtype: float64
# type of nDis now is  1.0938447678078704
# energy content of tank from the begineening of discharge in kJ, Inlet, mean, cp, p: 32735.729168435453 29.8646 50.656909999999996 4.015022781329263 987.7357135559447
# energy/sec discharged from tank in kJ/sec: 0    35807.806071
# dtype: float64
# discharge efficiency is: 1.0938447678078704
# liters discharged is : 336.41421023138906
# Load in kWh is: 10.501449412887967
# Discharging: load_kJ_total mul 3600: 37805.21788639668
# Availability :Total energy of in Kj is : 43253.853534690315
# Discharge: strat efficiency sum_float : 0.9598956530568656
# ________________________________________________________________
# flow rates load is =  1.294039490951262 0.008117171565369855 261.7089034823808
# flow rates HP is =  0.6300192266609699 0.003946252594180832 -5.187740468238238
# result is ((5641, datetime.datetime(2021, 5, 24, 10, 52, 46), 23.7726, 30.2373, 23.8403, 19.785, 31.83, 46.9473, 35.798, 16.3081, 29.9662, 24.2461, 24.3137, 24.1446, 24.2461, 22.2852, 46.8792, 25.8359, 24.6857, 24.4152, 24.449),)
# electricity in khW is: 3.085635748388889
# cop is: 1.8854389348697358
# Load in kWh is: 10.50830662408658
# heat addition in kwh is: 5.817777778838327
# OK ok oK oK ok if not small run
# Total sum discharge in kJ is : 0    35840.123118
# dtype: float64
# type of nDis now is  1.1002080588584886
# energy content of tank from the begineening of discharge in kJ, Inlet, mean, cp, p: 32575.768582838515 29.9662 50.656909999999996 4.015022781329263 987.7357135559447
# energy/sec discharged from tank in kJ/sec: 0    35840.123118
# dtype: float64
# discharge efficiency is: 1.1002080588584886
# liters discharged is : 336.8503918980557
# Load in kWh is: 10.50965773339048
# Discharging: load_kJ_total mul 3600: 37834.76784020573
# Availability :Total energy of in Kj is : 43248.554210370006
# Discharge: strat efficiency sum_float : 0.9596589225364967
# ________________________________________________________________
# flow rates load is =  1.2980396130252998 0.00814226328581922 263.28699910812696
# flow rates HP is =  0.6360194097720268 0.003983835952220649 1.898269662232681
# result is ((5646, datetime.datetime(2021, 5, 24, 10, 52, 54), 23.7726, 30.2034, 23.9755, 19.785, 31.7622, 46.6409, 35.7641, 16.2406, 29.9324, 24.2799, 24.4152, 24.2122, 24.2122, 22.319, 46.5728, 25.7682, 24.7196, 24.4828, 24.3475),)
# electricity in khW is: 3.0856450837000002
# cop is: 1.8854429992393065
# Load in kWh is: 10.519145607402733
# heat addition in kwh is: 5.817807921199349
# OK ok oK oK ok if not small run
# Total sum discharge in kJ is : 0    35876.714455
# dtype: float64
# type of nDis now is  1.0995351450877968
# energy content of tank from the begineening of discharge in kJ, Inlet, mean, cp, p: 32628.983817023323 29.9324 50.656909999999996 4.015022781329263 987.7357135559447
# energy/sec discharged from tank in kJ/sec: 0    35876.714455
# dtype: float64
# discharge efficiency is: 1.0995351450877968
# liters discharged is : 337.43547412027795
# Load in kWh is: 10.520496716706631
# Discharging: load_kJ_total mul 3600: 37873.78818014387
# Availability :Total energy of in Kj is : 43225.10637698088
# Discharge: strat efficiency sum_float : 0.9585311618264226
# ________________________________________________________________
# flow rates load is =  1.296039551988281 0.008129717425594537 262.49795129525387
# flow rates HP is =  0.6340193487350078 0.003971308166207377 -0.4637337145910134
# result is ((5650, datetime.datetime(2021, 5, 24, 10, 53), 23.7726, 30.1356, 23.8403, 19.785, 31.83, 46.1983, 35.7301, 16.2406, 29.8646, 24.3137, 24.4152, 24.1784, 24.2122, 22.319, 46.3345, 25.7006, 24.6857, 24.4828, 24.5843),)
# electricity in khW is: 3.0856543057000003
# cop is: 1.885435555113714
# Load in kWh is: 10.527074284522714
# heat addition in kwh is: 5.817802338756502
# liters discharged is : 337.8729707869446
# Load in kWh is: 10.528425393826613
# Discharging: load_kJ_total mul 3600: 37902.33141777581
# Availability :Total energy of in Kj is : 43211.59447092632
# Discharge: strat efficiency sum_float : 0.958803296023478
# ________________________________________________________________
# flow rates load is =  1.3000396740623188 0.008154809146043902 264.07604692100006
# flow rates HP is =  0.6320192876979889 0.003958780380194105 -2.825737091414544
# result is ((5655, datetime.datetime(2021, 5, 24, 10, 53, 8), 23.7726, 30.0679, 23.8403, 19.7512, 31.8638, 46.1302, 35.6623, 16.2069, 29.9324, 24.2799, 24.4152, 24.2122, 24.2122, 22.319, 46.0281, 25.5991, 24.7196, 24.449, 24.3475),)
# electricity in khW is: 3.0856662366944447
# cop is: 1.8854137243385598
# Load in kWh is: 10.537622064649419
# heat addition in kwh is: 5.817757471391821
# liters discharged is : 338.3864518980557
# Load in kWh is: 10.53765470143748
# Discharging: load_kJ_total mul 3600: 37935.55692517493
# Availability :Total energy of in Kj is : 43113.12054063701
# Discharge: strat efficiency sum_float : 0.9596719765537978
# ________________________________________________________________
# flow rates load is =  1.3020397350993378 0.008167355006268586 264.8650947338733
# flow rates HP is =  0.6340193487350078 0.003971308166207377 -0.4637337145910134
# result is ((5659, datetime.datetime(2021, 5, 24, 10, 53, 15), 23.7726, 30.034, 23.9755, 19.785, 31.8638, 46.1983, 35.6962, 16.2744, 29.8985, 24.3475, 24.4152, 24.2461, 24.2461, 22.2852, 45.9941, 25.5991, 24.6857, 24.449, 24.4152),)
# electricity in khW is: 3.0856747218500002
# cop is: 1.8854065084465719
# Load in kWh is: 10.546936226865462
# heat addition in kwh is: 5.817751203525056
# liters discharged is : 338.9750407869446
# Load in kWh is: 10.548299458255816
# Discharging: load_kJ_total mul 3600: 37973.87804972094
# Availability :Total energy of in Kj is : 43129.53523772244
# Discharge: strat efficiency sum_float : 0.9597022372202465
# ________________________________________________________________
# flow rates load is =  1.3040397961363568 0.008179900866493268 265.6541425467464
# flow rates HP is =  0.6300192266609699 0.003946252594180832 -5.187740468238238
# result is ((5663, datetime.datetime(2021, 5, 24, 10, 53, 21), 23.7726, 29.9662, 23.8741, 19.7512, 31.83, 45.926, 35.6623, 16.2744, 29.9324, 24.3137, 24.4828, 24.2461, 24.2461, 22.2852, 45.96, 25.5991, 24.7196, 24.5166, 24.4828),)
# electricity in khW is: 3.0856846987333335
# cop is: 1.8853808269922845
# Load in kWh is: 10.554796568213714
# heat addition in kwh is: 5.81769076913529
# liters discharged is : 339.41779745361123
# Load in kWh is: 10.556159799604067
# Discharging: load_kJ_total mul 3600: 38002.17527857464
# Availability :Total energy of in Kj is : 43156.62737621336
# Discharge: strat efficiency sum_float : 0.9600123048010197
# ________________________________________________________________
# flow rates load is =  1.3060398571733758 0.008192446726717952 266.4431903596196
# flow rates HP is =  0.6320192876979889 0.003958780380194105 -2.825737091414544
# result is ((5668, datetime.datetime(2021, 5, 24, 10, 53, 29), 23.7726, 29.9324, 23.9755, 19.7512, 31.8638, 45.6197, 35.6283, 16.2744, 29.8985, 24.3475, 24.4828, 24.2799, 24.2461, 22.2852, 45.926, 25.4637, 24.7196, 24.5504, 24.449),)
# electricity in khW is: 3.085696877955556
# cop is: 1.885359477017147
# Load in kWh is: 10.565134161682842
# heat addition in kwh is: 5.81764785205573
# liters discharged is : 340.0098930091668
# Load in kWh is: 10.566497393073195
# Discharging: load_kJ_total mul 3600: 38039.3906150635
# Availability :Total energy of in Kj is : 43140.974344861505
# Discharge: strat efficiency sum_float : 0.9598337641102789
# ________________________________________________________________
# flow rates load is =  1.3080399182103946 0.008204992586942633 267.2322381724926
# flow rates HP is =  0.6340193487350078 0.003971308166207377 -0.4637337145910134
# result is ((5672, datetime.datetime(2021, 5, 24, 10, 53, 36), 23.7726, 29.8985, 24.077, 19.7174, 31.8638, 45.4835, 35.5605, 16.2406, 29.9324, 24.3813, 24.4828, 24.2799, 24.2799, 22.2852, 45.7218, 25.3961, 24.6857, 24.5843, 24.5843),)
# electricity in khW is: 3.0857080724333334
# cop is: 1.8853506854235278
# Load in kWh is: 10.574110127262983
# heat addition in kwh is: 5.817641829379098
# liters discharged is : 340.52951078694457
# Load in kWh is: 10.575473358653337
# Discharging: load_kJ_total mul 3600: 38071.704091152016
# Availability :Total energy of in Kj is : 43132.38720290607
# Discharge: strat efficiency sum_float : 0.9602463619572762
# ________________________________________________________________
# flow rates load is =  1.3080399182103946 0.008204992586942633 267.2322381724926
# flow rates HP is =  0.6360194097720268 0.003983835952220649 1.898269662232681
# result is ((5677, datetime.datetime(2021, 5, 24, 10, 53, 44), 23.7726, 29.8646, 23.9755, 19.7512, 31.9316, 45.3134, 35.4926, 16.3081, 30.0001, 24.3813, 24.4828, 24.2799, 24.2799, 22.2852, 45.4835, 25.3284, 24.6857, 24.5504, 24.7872),)
# electricity in khW is: 3.085719081177778
# cop is: 1.885353196106339
# Load in kWh is: 10.584214241253939
# heat addition in kwh is: 5.817670331984839
# liters discharged is : 341.04912856472237
# Load in kWh is: 10.584314458395424
# Discharging: load_kJ_total mul 3600: 38103.532050223526
# Availability :Total energy of in Kj is : 43113.34819474372
# Discharge: strat efficiency sum_float : 0.959966730541215
# ________________________________________________________________
# flow rates load is =  1.3180402233954893 0.008267721888066048 271.17747723685835
# flow rates HP is =  0.6320192876979889 0.003958780380194105 -2.825737091414544
# result is ((5681, datetime.datetime(2021, 5, 24, 10, 53, 50), 23.7726, 29.8307, 23.9755, 19.7512, 31.9316, 45.1092, 35.4587, 16.3081, 29.9662, 24.3813, 24.5166, 24.2799, 24.2799, 22.2514, 45.2113, 25.3284, 24.6857, 24.449, 24.5166),)
# electricity in khW is: 3.0857295611777777
# cop is: 1.8853365398247988
# Load in kWh is: 10.59182114389463
# heat addition in kwh is: 5.817638693706006
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-f026a8142d9f> in <module>
#     985
#     986     #Thjis plot plots Entropy in kJ/K and kJ
# --> 987     fig3, ax3 = plotObject_entropy(GrossDf, ax3,ax3_1, fig3)
#     988
#     989     fig4, ax4 = plotObject_entropy_Discharge(GrossDf, ax4, ax4_1,  fig4)
#
# <ipython-input-3-f026a8142d9f> in plotObject_entropy(df, ax3, ax3_1, fig3)
#     522     ax3.legend(bbox_to_anchor=(0.4,0.8))
#     523     ax3Twin.legend(bbox_to_anchor=(0.4,0.8))
# --> 524     ax3.legend()
#     525     #Plot strt eff on first fig object of fig3
#     526
#
# ~/.local/lib/python3.7/site-packages/matplotlib/axes/_axes.py in legend(self, *args, **kwargs)
#     415         if len(extra_args):
#     416             raise TypeError('legend only accepts two non-keyword arguments')
# --> 417         self.legend_ = mlegend.Legend(self, handles, labels, **kwargs)
#     418         self.legend_._remove_method = self._remove_legend
#     419         return self.legend_
#
# ~/.local/lib/python3.7/site-packages/matplotlib/legend.py in __init__(self, parent, handles, labels, loc, numpoints, markerscale, markerfirst, scatterpoints, scatteryoffsets, prop, fontsize, labelcolor, borderpad, labelspacing, handlelength, handleheight, handletextpad, borderaxespad, columnspacing, ncol, mode, fancybox, shadow, title, title_fontsize, framealpha, edgecolor, facecolor, bbox_to_anchor, bbox_transform, frameon, handler_map)
#     501
#     502         # init with null renderer
# --> 503         self._init_legend_box(handles, labels, markerfirst)
#     504
#     505         tmp = self._loc_used_default
#
# ~/.local/lib/python3.7/site-packages/matplotlib/legend.py in _init_legend_box(self, handles, labels, markerfirst)
#     765                 # original artist/handle.
#     766                 handle_list.append(handler.legend_artist(self, orig_handle,
# --> 767                                                          fontsize, handlebox))
#     768                 handles_and_labels.append((handlebox, textbox))
#     769
#
# ~/.local/lib/python3.7/site-packages/matplotlib/legend_handler.py in legend_artist(self, legend, orig_handle, fontsize, handlebox)
#     115         artists = self.create_artists(legend, orig_handle,
#     116                                       xdescent, ydescent, width, height,
# --> 117                                       fontsize, handlebox.get_transform())
#     118
#     119         # create_artists will return a list of artists.
#
# ~/.local/lib/python3.7/site-packages/matplotlib/legend_handler.py in create_artists(self, legend, orig_handle, xdescent, ydescent, width, height, fontsize, trans)
#     234                                              width, height, fontsize)
#     235
# --> 236         ydata = np.full_like(xdata, ((height - ydescent) / 2))
#     237         legline = Line2D(xdata, ydata)
#     238
#
# /usr/lib/python3/dist-packages/numpy/core/numeric.py in full_like(a, fill_value, dtype, order, subok)
#     395
#     396     """
# --> 397     res = empty_like(a, dtype=dtype, order=order, subok=subok)
#     398     multiarray.copyto(res, fill_value, casting='unsafe')
#     399     return res
#
# KeyboardInterrupt:
